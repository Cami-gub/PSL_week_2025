# %% [markdown]
# # RSA

# %% [markdown]
# ***Key Generation In RSA :***
#
# + Choose 2 primes p,q using gmpy
# + n = p*q and $ \phi (n) = (p-1)*(q-1) $
# + Choose $ e $ in $ [2,\phi(n)-2] $ such that $ e $ and $ \phi(n) $ are coprimes i.e their gcd is 1
# + Choose $ d = e^{-1} mod(\phi(n)) $
# + Return ***Public keys :*** $ (n,e) $
# + Return ***Private key :*** $ (d) $

# %%
# !pip install gmpy2
# Out:
# Collecting gmpy2
#   Downloading gmpy2-2.2.1-cp313-cp313-win_amd64.whl.metadata (2.9 kB)
# Downloading gmpy2-2.2.1-cp313-cp313-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    ----------------- ---------------------- 0.5/1.2 MB 735.6 kB/s eta 0:00:01
#    -------------------------- ------------- 0.8/1.2 MB 756.7 kB/s eta 0:00:01
#    -------------------------- ------------- 0.8/1.2 MB 756.7 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 739.4 kB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 750.2 kB/s eta 0:00:00
# Installing collected packages: gmpy2
# Successfully installed gmpy2-2.2.1
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\guben\venv\lib\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\guben\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\guben\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 212.8 kB/s eta 0:00:52
#    - -------------------------------------- 0.5/11.5 MB 212.8 kB/s eta 0:00:52
#    - -------------------------------------- 0.5/11.5 MB 212.8 kB/s eta 0:00:52
#    - -------------------------------------- 0.5/11.5 MB 212.8 kB/s eta 0:00:52
#    - -------------------------------------- 0.5/11.5 MB 212.8 kB/s eta 0:00:52
#    - -------------------------------------- 0.5/11.5 MB 212.8 kB/s eta 0:00:52
#    - -------------------------------------- 0.5/11.5 MB 212.8 kB/s eta 0:00:52
#    -- ------------------------------------- 0.8/11.5 MB 183.9 kB/s eta 0:00:59
#    -- ------------------------------------- 0.8/11.5 MB 183.9 kB/s eta 0:00:59
#    -- ------------------------------------- 0.8/11.5 MB 183.9 kB/s eta 0:00:59
#    -- ------------------------------------- 0.8/11.5 MB 183.9 kB/s eta 0:00:59
#    -- ------------------------------------- 0.8/11.5 MB 183.9 kB/s eta 0:00:59
#    -- ------------------------------------- 0.8/11.5 MB 183.9 kB/s eta 0:00:59
#    -- ------------------------------------- 0.8/11.5 MB 183.9 kB/s eta 0:00:59
#    --- ------------------------------------ 1.0/11.5 MB 185.8 kB/s eta 0:00:57
#    --- ------------------------------------ 1.0/11.5 MB 185.8 kB/s eta 0:00:57
#    --- ------------------------------------ 1.0/11.5 MB 185.8 kB/s eta 0:00:57
#    --- ------------------------------------ 1.0/11.5 MB 185.8 kB/s eta 0:00:57
#    --- ------------------------------------ 1.0/11.5 MB 185.8 kB/s eta 0:00:57
#    ---- ----------------------------------- 1.3/11.5 MB 199.4 kB/s eta 0:00:52
#    ---- ----------------------------------- 1.3/11.5 MB 199.4 kB/s eta 0:00:52
#    ---- ----------------------------------- 1.3/11.5 MB 199.4 kB/s eta 0:00:52
#    ----- ---------------------------------- 1.6/11.5 MB 221.6 kB/s eta 0:00:45
#    ----- ---------------------------------- 1.6/11.5 MB 221.6 kB/s eta 0:00:45
#    ----- ---------------------------------- 1.6/11.5 MB 221.6 kB/s eta 0:00:45
#    ------ --------------------------------- 1.8/11.5 MB 239.6 kB/s eta 0:00:41
#    ------ --------------------------------- 1.8/11.5 MB 239.6 kB/s eta 0:00:41
#    ------ --------------------------------- 1.8/11.5 MB 239.6 kB/s eta 0:00:41
#    ------- -------------------------------- 2.1/11.5 MB 258.6 kB/s eta 0:00:37
#    ------- -------------------------------- 2.1/11.5 MB 258.6 kB/s eta 0:00:37
#    -------- ------------------------------- 2.4/11.5 MB 276.4 kB/s eta 0:00:34
#    -------- ------------------------------- 2.4/11.5 MB 276.4 kB/s eta 0:00:34
#    -------- ------------------------------- 2.4/11.5 MB 276.4 kB/s eta 0:00:34
#    --------- ------------------------------ 2.6/11.5 MB 289.6 kB/s eta 0:00:31
#    ---------- ----------------------------- 2.9/11.5 MB 308.5 kB/s eta 0:00:28
#    ---------- ----------------------------- 2.9/11.5 MB 308.5 kB/s eta 0:00:28
#    ---------- ----------------------------- 3.1/11.5 MB 322.2 kB/s eta 0:00:26
#    ---------- ----------------------------- 3.1/11.5 MB 322.2 kB/s eta 0:00:26
#    ---------- ----------------------------- 3.1/11.5 MB 322.2 kB/s eta 0:00:26
#    ----------- ---------------------------- 3.4/11.5 MB 332.6 kB/s eta 0:00:25
#    ----------- ---------------------------- 3.4/11.5 MB 332.6 kB/s eta 0:00:25
#    ------------ --------------------------- 3.7/11.5 MB 340.3 kB/s eta 0:00:23
#    ------------ --------------------------- 3.7/11.5 MB 340.3 kB/s eta 0:00:23
#    ------------ --------------------------- 3.7/11.5 MB 340.3 kB/s eta 0:00:23
#    ------------- -------------------------- 3.9/11.5 MB 350.5 kB/s eta 0:00:22
#    ------------- -------------------------- 3.9/11.5 MB 350.5 kB/s eta 0:00:22
#    -------------- ------------------------- 4.2/11.5 MB 356.3 kB/s eta 0:00:21
#    -------------- ------------------------- 4.2/11.5 MB 356.3 kB/s eta 0:00:21
#    -------------- ------------------------- 4.2/11.5 MB 356.3 kB/s eta 0:00:21
#    --------------- ------------------------ 4.5/11.5 MB 364.1 kB/s eta 0:00:20
#    --------------- ------------------------ 4.5/11.5 MB 364.1 kB/s eta 0:00:20
#    --------------- ------------------------ 4.5/11.5 MB 364.1 kB/s eta 0:00:20
#    ---------------- ----------------------- 4.7/11.5 MB 366.1 kB/s eta 0:00:19
#    ---------------- ----------------------- 4.7/11.5 MB 366.1 kB/s eta 0:00:19
#    ---------------- ----------------------- 4.7/11.5 MB 366.1 kB/s eta 0:00:19
#    ----------------- ---------------------- 5.0/11.5 MB 370.0 kB/s eta 0:00:18
#    ----------------- ---------------------- 5.0/11.5 MB 370.0 kB/s eta 0:00:18
#    ------------------ --------------------- 5.2/11.5 MB 372.5 kB/s eta 0:00:17
#    ------------------ --------------------- 5.2/11.5 MB 372.5 kB/s eta 0:00:17
#    ------------------ --------------------- 5.2/11.5 MB 372.5 kB/s eta 0:00:17
#    ------------------ --------------------- 5.2/11.5 MB 372.5 kB/s eta 0:00:17
#    ------------------ --------------------- 5.2/11.5 MB 372.5 kB/s eta 0:00:17
#    ------------------ --------------------- 5.2/11.5 MB 372.5 kB/s eta 0:00:17
#    ------------------- -------------------- 5.5/11.5 MB 361.3 kB/s eta 0:00:17
#    ------------------- -------------------- 5.5/11.5 MB 361.3 kB/s eta 0:00:17
#    ------------------- -------------------- 5.5/11.5 MB 361.3 kB/s eta 0:00:17
#    ------------------- -------------------- 5.5/11.5 MB 361.3 kB/s eta 0:00:17
#    ------------------- -------------------- 5.5/11.5 MB 361.3 kB/s eta 0:00:17
#    -------------------- ------------------- 5.8/11.5 MB 354.7 kB/s eta 0:00:17
#    -------------------- ------------------- 5.8/11.5 MB 354.7 kB/s eta 0:00:17
#    -------------------- ------------------- 5.8/11.5 MB 354.7 kB/s eta 0:00:17
#    -------------------- ------------------- 5.8/11.5 MB 354.7 kB/s eta 0:00:17
#    -------------------- ------------------- 5.8/11.5 MB 354.7 kB/s eta 0:00:17
#    -------------------- ------------------- 5.8/11.5 MB 354.7 kB/s eta 0:00:17
#    -------------------- ------------------- 5.8/11.5 MB 354.7 kB/s eta 0:00:17
#    -------------------- ------------------- 5.8/11.5 MB 354.7 kB/s eta 0:00:17
#    --------------------- ------------------ 6.0/11.5 MB 334.1 kB/s eta 0:00:17
#    --------------------- ------------------ 6.0/11.5 MB 334.1 kB/s eta 0:00:17
#    --------------------- ------------------ 6.0/11.5 MB 334.1 kB/s eta 0:00:17
#    --------------------- ------------------ 6.0/11.5 MB 334.1 kB/s eta 0:00:17
#    --------------------- ------------------ 6.0/11.5 MB 334.1 kB/s eta 0:00:17
#    --------------------- ------------------ 6.3/11.5 MB 328.0 kB/s eta 0:00:16
#    --------------------- ------------------ 6.3/11.5 MB 328.0 kB/s eta 0:00:16
#    --------------------- ------------------ 6.3/11.5 MB 328.0 kB/s eta 0:00:16
#    --------------------- ------------------ 6.3/11.5 MB 328.0 kB/s eta 0:00:16
#    --------------------- ------------------ 6.3/11.5 MB 328.0 kB/s eta 0:00:16
#    --------------------- ------------------ 6.3/11.5 MB 328.0 kB/s eta 0:00:16
#    ---------------------- ----------------- 6.6/11.5 MB 319.6 kB/s eta 0:00:16
#    ---------------------- ----------------- 6.6/11.5 MB 319.6 kB/s eta 0:00:16
#    ---------------------- ----------------- 6.6/11.5 MB 319.6 kB/s eta 0:00:16
#    ---------------------- ----------------- 6.6/11.5 MB 319.6 kB/s eta 0:00:16
#    ---------------------- ----------------- 6.6/11.5 MB 319.6 kB/s eta 0:00:16
#    ----------------------- ---------------- 6.8/11.5 MB 318.9 kB/s eta 0:00:15
#    ----------------------- ---------------- 6.8/11.5 MB 318.9 kB/s eta 0:00:15
#    ----------------------- ---------------- 6.8/11.5 MB 318.9 kB/s eta 0:00:15
#    ------------------------ --------------- 7.1/11.5 MB 321.8 kB/s eta 0:00:14
#    ------------------------ --------------- 7.1/11.5 MB 321.8 kB/s eta 0:00:14
#    ------------------------- -------------- 7.3/11.5 MB 326.5 kB/s eta 0:00:13
#    ------------------------- -------------- 7.3/11.5 MB 326.5 kB/s eta 0:00:13
#    -------------------------- ------------- 7.6/11.5 MB 331.6 kB/s eta 0:00:12
#    -------------------------- ------------- 7.6/11.5 MB 331.6 kB/s eta 0:00:12
#    -------------------------- ------------- 7.6/11.5 MB 331.6 kB/s eta 0:00:12
#    --------------------------- ------------ 7.9/11.5 MB 335.0 kB/s eta 0:00:11
#    --------------------------- ------------ 7.9/11.5 MB 335.0 kB/s eta 0:00:11
#    --------------------------- ------------ 7.9/11.5 MB 335.0 kB/s eta 0:00:11
#    ---------------------------- ----------- 8.1/11.5 MB 335.6 kB/s eta 0:00:10
#    ---------------------------- ----------- 8.1/11.5 MB 335.6 kB/s eta 0:00:10
#    ---------------------------- ----------- 8.1/11.5 MB 335.6 kB/s eta 0:00:10
#    ---------------------------- ----------- 8.1/11.5 MB 335.6 kB/s eta 0:00:10
#    ----------------------------- ---------- 8.4/11.5 MB 335.7 kB/s eta 0:00:10
#    ----------------------------- ---------- 8.4/11.5 MB 335.7 kB/s eta 0:00:10
#    ------------------------------ --------- 8.7/11.5 MB 340.2 kB/s eta 0:00:09
#    ------------------------------ --------- 8.7/11.5 MB 340.2 kB/s eta 0:00:09
#    ------------------------------ --------- 8.7/11.5 MB 340.2 kB/s eta 0:00:09
#    ------------------------------ --------- 8.7/11.5 MB 340.2 kB/s eta 0:00:09
#    ------------------------------- -------- 8.9/11.5 MB 340.9 kB/s eta 0:00:08
#    ------------------------------- -------- 8.9/11.5 MB 340.9 kB/s eta 0:00:08
#    ------------------------------- -------- 8.9/11.5 MB 340.9 kB/s eta 0:00:08
#    ------------------------------- -------- 8.9/11.5 MB 340.9 kB/s eta 0:00:08
#    ------------------------------- -------- 8.9/11.5 MB 340.9 kB/s eta 0:00:08
#    ------------------------------- -------- 8.9/11.5 MB 340.9 kB/s eta 0:00:08
#    ------------------------------- -------- 9.2/11.5 MB 334.4 kB/s eta 0:00:07
#    ------------------------------- -------- 9.2/11.5 MB 334.4 kB/s eta 0:00:07
#    ------------------------------- -------- 9.2/11.5 MB 334.4 kB/s eta 0:00:07
#    -------------------------------- ------- 9.4/11.5 MB 336.4 kB/s eta 0:00:07
#    --------------------------------- ------ 9.7/11.5 MB 341.6 kB/s eta 0:00:06
#    --------------------------------- ------ 9.7/11.5 MB 341.6 kB/s eta 0:00:06
#    ---------------------------------- ----- 10.0/11.5 MB 347.2 kB/s eta 0:00:05
#    ---------------------------------- ----- 10.0/11.5 MB 347.2 kB/s eta 0:00:05
#    ----------------------------------- ---- 10.2/11.5 MB 351.7 kB/s eta 0:00:04
#    ------------------------------------ --- 10.5/11.5 MB 356.5 kB/s eta 0:00:03
#    ------------------------------------ --- 10.5/11.5 MB 356.5 kB/s eta 0:00:03
#    ------------------------------------- -- 10.7/11.5 MB 361.4 kB/s eta 0:00:03
#    ------------------------------------- -- 10.7/11.5 MB 361.4 kB/s eta 0:00:03
#    ------------------------------------- -- 10.7/11.5 MB 361.4 kB/s eta 0:00:03
#    -------------------------------------- - 11.0/11.5 MB 361.3 kB/s eta 0:00:02
#    -------------------------------------- - 11.0/11.5 MB 361.3 kB/s eta 0:00:02
#    -------------------------------------- - 11.0/11.5 MB 361.3 kB/s eta 0:00:02
#    -------------------------------------- - 11.0/11.5 MB 361.3 kB/s eta 0:00:02
#    -------------------------------------- - 11.0/11.5 MB 361.3 kB/s eta 0:00:02
#    -------------------------------------- - 11.0/11.5 MB 361.3 kB/s eta 0:00:02
#    ---------------------------------------  11.3/11.5 MB 362.3 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 362.3 kB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 376.8 kB/s eta 0:00:00
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2025.1 tzdata-2025.1
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from qiskit_aer import AerSimulator
import gmpy2 # You need to install this package
from qiskit_ibm_runtime import Options, Session, SamplerV2 as Sampler
backend_sim = AerSimulator()
simulator = AerSimulator()

#Import an estimator, this time from qiskit (we import from Runtime for real hardware)
from qiskit.primitives import BackendSampler
sampler = BackendSampler(backend = backend_sim)
import numpy as np
from qiskit.visualization import plot_bloch_vector, plot_histogram, plot_bloch_multivector
import matplotlib.pyplot as plt

from qiskit.circuit import QuantumRegister, ClassicalRegister, QuantumCircuit, Parameter
from qiskit import QuantumCircuit, transpile
from qiskit.result import marginal_counts
from qiskit.circuit.library import QFT
from numpy import pi
import math
import pandas as pd
from fractions import Fraction
from random import randint
# Out:
# C:\Users\guben\AppData\Local\Temp\ipykernel_17276\3302930460.py:9: DeprecationWarning: The class ``qiskit.primitives.backend_sampler.BackendSampler`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseSamplerV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `BackendSampler` class is `BackendSamplerV2`.
#   sampler = BackendSampler(backend = backend_sim)

# %% [markdown]
# # 1. Generate RSA Keys

# %%
import gmpy2
import numpy as np

def generate_keys():
    random1 = np.random.randint(3, 40)
    random2 = np.random.randint(3, 40)
    p = int(gmpy2.next_prime(random1))
    q = int(gmpy2.next_prime(random2))
    n = p * q
    phi = (p - 1) * (q - 1)
    e = 2
    while gmpy2.gcd(phi, e) != 1:
        e += 1
    d = gmpy2.invert(e, phi)
    return n, e, d, p, q

def secret_key_from_prime(prime1,prime2, e):
    phi = (prime1 - 1) * (prime2 - 1)
    d = gmpy2.invert(e, phi)
    return d

# %% [markdown]
# # 2. Encrypting plain_text blocks
# ***Encyption in RSA :***
#
# ***Input :*** $ Plain Text = [p_1,p_2,p_3,..........,p_k] $
#
# ***Output :*** $ Cipher Text = [c_1,c_2,c_3,..........,c_k] $
#
# where
#
# $ c_{i} = p_{i}^e mod (n) $

# %%
# in order for this to work aldso with small numbers, we will encode our ASCII values in 3 octal digits, and encode them one by one
def string_to_flattened_bitstring(text):
    flattened_bitstring = []
    
    for char in text:
        # Get the ASCII value of the character
        ascii_value = ord(char)
        
        # Convert ASCII to octal and ensure it's a 3-digit number (pad with zeros if necessary)
        octal_value = oct(ascii_value)[2:].zfill(3)  # remove '0o' prefix and pad to 3 digits
        
        # Add each digit of the octal representation to the flattened bitstring
        flattened_bitstring.extend([int(digit) for digit in octal_value])
    
    return flattened_bitstring


def encrypt(flattened_bitstring, public_keys):
    n, e = public_keys
    cipher_bitstring = []
    for bit in flattened_bitstring:
        cipher_bit = gmpy2.powmod(bit, e, n)
        cipher_bitstring.append(cipher_bit)
    return cipher_bitstring

# %% [markdown]
# # 3. Decrypting cipher_text

# %% [markdown]
# ***Decryption in RSA :***
#
# ***Input :*** $ Cipher Text = [c_1,c_2,c_3,..........,c_k] $
#
# ***Output :*** $ Plain Text = [p_1,p_2,p_3,..........,p_k] $
#
# $ p_{i} = c_{i}^d mod (n) $

# %%
def decrypt(cipher_bitstring, secret_key, p, q):
    n = p * q
    d = secret_key
    decrypted_bitstring = []
    for cipher_bit in cipher_bitstring:
        plain_bit = gmpy2.powmod(cipher_bit, d, n)
        decrypted_bitstring.append(plain_bit)
    return decrypted_bitstring


# Reformatting the Decrypted Bitstring
def reformat_decrypted_bitstring(decrypted_bitstring):
    # Reformat the decrypted bitstring back to 3-digit octal chunks
    char_octal = [decrypted_bitstring[i:i+3] for i in range(0, len(decrypted_bitstring), 3)]
    
    # Convert each 3-digit octal chunk back to ASCII character
    text = ''
    for octal in char_octal:
        # Convert the 3-digit octal block to its decimal (ASCII) equivalent
        octal_value = ''.join(map(str, octal))
        ascii_value = int(octal_value, 8)  # Convert from octal to decimal (ASCII)
        text += chr(ascii_value)
    
    return text

# %%
# Example Usage
# Generate RSA keys
n, e, d, p, q = generate_keys()
public_keys = (n, e)
secret_key = d

print("Public Keys (n, e):", public_keys)
print("Secret Key (d):", secret_key)

# Input text
text = "Sensitive information"

# Step 2: Encode the text to flattened bitstring
flattened_bitstring = string_to_flattened_bitstring(text)
print("Flattened Bitstring:", flattened_bitstring)

# Step 3: Encrypt the flattened bitstring
encrypted_bitstring = encrypt(flattened_bitstring, public_keys)
print("Encrypted Bitstring:", encrypted_bitstring)


# Step 4: Decrypt the encrypted bitstring and check it matches the original
decrypted_bitstring = decrypt(encrypted_bitstring, secret_key, p, q)
print("Decrypted Bitstring:", decrypted_bitstring)


# Step 5: Reconstruct the text from the decrypted bitstring
reconstructed_text = reformat_decrypted_bitstring(decrypted_bitstring)
print("Reconstructed Text:", reconstructed_text)
# Out:
# Public Keys (n, e): (703, 5)
# Secret Key (d): 389
# Flattened Bitstring: [1, 2, 3, 1, 4, 5, 1, 5, 6, 1, 6, 3, 1, 5, 1, 1, 6, 4, 1, 5, 1, 1, 6, 6, 1, 4, 5, 0, 4, 0, 1, 5, 1, 1, 5, 6, 1, 4, 6, 1, 5, 7, 1, 6, 2, 1, 5, 5, 1, 4, 1, 1, 6, 4, 1, 5, 1, 1, 5, 7, 1, 5, 6]
# Encrypted Bitstring: [mpz(1), mpz(32), mpz(243), mpz(1), mpz(321), mpz(313), mpz(1), mpz(313), mpz(43), mpz(1), mpz(43), mpz(243), mpz(1), mpz(313), mpz(1), mpz(1), mpz(43), mpz(321), mpz(1), mpz(313), mpz(1), mpz(1), mpz(43), mpz(43), mpz(1), mpz(321), mpz(313), mpz(0), mpz(321), mpz(0), mpz(1), mpz(313), mpz(1), mpz(1), mpz(313), mpz(43), mpz(1), mpz(321), mpz(43), mpz(1), mpz(313), mpz(638), mpz(1), mpz(43), mpz(32), mpz(1), mpz(313), mpz(313), mpz(1), mpz(321), mpz(1), mpz(1), mpz(43), mpz(321), mpz(1), mpz(313), mpz(1), mpz(1), mpz(313), mpz(638), mpz(1), mpz(313), mpz(43)]
# Decrypted Bitstring: [mpz(1), mpz(2), mpz(3), mpz(1), mpz(4), mpz(5), mpz(1), mpz(5), mpz(6), mpz(1), mpz(6), mpz(3), mpz(1), mpz(5), mpz(1), mpz(1), mpz(6), mpz(4), mpz(1), mpz(5), mpz(1), mpz(1), mpz(6), mpz(6), mpz(1), mpz(4), mpz(5), mpz(0), mpz(4), mpz(0), mpz(1), mpz(5), mpz(1), mpz(1), mpz(5), mpz(6), mpz(1), mpz(4), mpz(6), mpz(1), mpz(5), mpz(7), mpz(1), mpz(6), mpz(2), mpz(1), mpz(5), mpz(5), mpz(1), mpz(4), mpz(1), mpz(1), mpz(6), mpz(4), mpz(1), mpz(5), mpz(1), mpz(1), mpz(5), mpz(7), mpz(1), mpz(5), mpz(6)]
# Reconstructed Text: Sensitive information

# %% [markdown]
# # Shor's Algorithm

# %% [markdown]
# Shor’s algorithm is famous for factoring integers in polynomial time. Since the best-known classical algorithm requires superpolynomial time to factor the product of two primes, the widely used cryptosystem, RSA, relies on factoring being impossible for large enough integers.
#
# In this chapter we will focus on the quantum part of Shor’s algorithm, which actually solves the problem of _period finding_. Since a factoring problem can be turned into a period finding problem in polynomial time, an efficient period finding algorithm can be used to factor integers efficiently too. For now its enough to show that if we can compute the period of $a^x\bmod N$ efficiently, then we can also efficiently factor. Since period finding is a worthy problem in its own right, we will first solve this, then discuss how this can be used to factor in section 5.

# %%
from qiskit_aer import AerSimulator
from qiskit_ibm_runtime import Options, Session, SamplerV2 as Sampler
backend_sim = AerSimulator()
simulator = AerSimulator()

#Import an estimator, this time from qiskit (we import from Runtime for real hardware)
from qiskit.primitives import BackendSampler
sampler = BackendSampler(backend = backend_sim)
import numpy as np
from qiskit.visualization import plot_bloch_vector, plot_histogram, plot_bloch_multivector
import matplotlib.pyplot as plt

from qiskit.circuit import QuantumRegister, ClassicalRegister, QuantumCircuit, Parameter
from qiskit import QuantumCircuit, transpile
from qiskit.result import marginal_counts
from qiskit.circuit.library import QFT
from numpy import pi
import math
import pandas as pd
from fractions import Fraction
from random import randint
# Out:
# C:\Users\guben\AppData\Local\Temp\ipykernel_17276\268835736.py:8: DeprecationWarning: The class ``qiskit.primitives.backend_sampler.BackendSampler`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseSamplerV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `BackendSampler` class is `BackendSamplerV2`.
#   sampler = BackendSampler(backend = backend_sim)

# %% [markdown]
# ## 1. The Problem: Period Finding
#
# Let’s look at the periodic function:
#
# $$ f(x) = a^x \bmod{N}$$
#
# <details>
#     <summary>Reminder: Modulo &amp; Modular Arithmetic (Click here to expand)</summary>
#
# The modulo operation (abbreviated to 'mod') simply means to find the remainder when dividing one number by another. For example:
#
# $$ 17 \bmod 5 = 2 $$
#
# Since $17 \div 5 = 3$ with remainder $2$. (i.e. $17 = (3\times 5) + 2$). In Python, the modulo operation is denoted through the <code>%</code> symbol.
#
# This behaviour is used in <a href="https://en.wikipedia.org/wiki/Modular_arithmetic">modular arithmetic</a>, where numbers 'wrap round' after reaching a certain value (the modulus). Using modular arithmetic, we could write:
#
# $$ 17 = 2 \pmod 5$$
#
# Note that here the $\pmod 5$ applies to the entire equation (since it is in parenthesis), unlike the equation above where it only applied to the left-hand side of the equation.
# </details>
#
# where $a$ and $N$ are positive integers, $a$ is less than $N$, and they have no common factors. The period, or order ($r$), is the smallest (non-zero) integer such that:
#
# $$a^r \bmod N = 1 $$
#
# We can see an example of this function plotted on the graph below. Note that the lines between points are to help see the periodicity and do not represent the intermediate values between the x-markers.

# %%
N = 35
a = 3

# Calculate the plotting data
xvals = np.arange(35)
yvals = [np.mod(a**x, N) for x in xvals]

# Use matplotlib to display it nicely
fig, ax = plt.subplots()
ax.plot(xvals, yvals, linewidth=1, linestyle='dotted', marker='x')
ax.set(xlabel='$x$', ylabel='$%i^x$ mod $%i$' % (a, N),
       title="Example of Periodic Function in Shor's Algorithm")
try: # plot r on the graph
    r = yvals[1:].index(1) +1 
    plt.annotate('', xy=(0,1), xytext=(r,1), arrowprops=dict(arrowstyle='<->'))
    plt.annotate('$r=%i$' % r, xy=(r/3,1.5))
except ValueError:
    print('Could not find period, check a < N and have no common factors.')

# %% [markdown]
# ## 2. The Solution
#
# Shor’s solution was to use quantum phase estimation on the unitary operator:
#
# $$ U|y\rangle \equiv |ay \bmod N \rangle $$
#
# To see how this is helpful, let’s work out what an eigenstate of U might look like. If we started in the state $|1\rangle$, we can see that each successive application of U will multiply the state of our register by $a \pmod N$, and after $r$ applications we will arrive at the state $|1\rangle$ again. For example with $a = 3$ and $N = 35$:
#
# $$\begin{aligned}
# U|1\rangle &= |3\rangle & \\
# U^2|1\rangle &= |9\rangle \\
# U^3|1\rangle &= |27\rangle \\
# & \vdots \\
# U^{(r-1)}|1\rangle &= |12\rangle \\
# U^r|1\rangle &= |1\rangle
# \end{aligned}$$

# %%
ax.set(xlabel='Number of applications of U', ylabel='End state of register',
       title="Effect of Successive Applications of U")
fig

# %% [markdown]
# So a superposition of the states in this cycle ($|u_0\rangle$) would be an eigenstate of $U$:
#
# $$|u_0\rangle = \tfrac{1}{\sqrt{r}}\sum_{k=0}^{r-1}{|a^k \bmod N\rangle} $$
#
#
# <details>
#     <summary>Click to Expand: Example with $a = 3$ and $N=35$</summary>
#
# $$\begin{aligned}
# |u_0\rangle &= \tfrac{1}{\sqrt{12}}(|1\rangle + |3\rangle + |9\rangle \dots + |4\rangle + |12\rangle) \\[10pt]
# U|u_0\rangle &= \tfrac{1}{\sqrt{12}}(U|1\rangle + U|3\rangle + U|9\rangle \dots + U|4\rangle + U|12\rangle) \\[10pt]
#  &= \tfrac{1}{\sqrt{12}}(|3\rangle + |9\rangle + |27\rangle \dots + |12\rangle + |1\rangle) \\[10pt]
#  &= |u_0\rangle
# \end{aligned}$$
# </details>
#
#
# This eigenstate has an eigenvalue of 1, which isn’t very interesting. A more interesting eigenstate could be one in which the phase is different for each of these computational basis states. Specifically, let’s look at the case in which the phase of the $k$th state is proportional to $k$:
#
# $$\begin{aligned}
# |u_1\rangle &= \tfrac{1}{\sqrt{r}}\sum_{k=0}^{r-1}{e^{-\tfrac{2\pi i k}{r}}|a^k \bmod N\rangle}\\[10pt]
# U|u_1\rangle &= e^{\tfrac{2\pi i}{r}}|u_1\rangle
# \end{aligned}
# $$
#
# <details>
#     <summary>Click to Expand: Example with $a = 3$ and $N=35$</summary>
#
# $$\begin{aligned}
# |u_1\rangle &= \tfrac{1}{\sqrt{12}}(|1\rangle + e^{-\tfrac{2\pi i}{12}}|3\rangle + e^{-\tfrac{4\pi i}{12}}|9\rangle \dots + e^{-\tfrac{20\pi i}{12}}|4\rangle + e^{-\tfrac{22\pi i}{12}}|12\rangle) \\[10pt]
# U|u_1\rangle &= \tfrac{1}{\sqrt{12}}(|3\rangle + e^{-\tfrac{2\pi i}{12}}|9\rangle + e^{-\tfrac{4\pi i}{12}}|27\rangle \dots + e^{-\tfrac{20\pi i}{12}}|12\rangle + e^{-\tfrac{22\pi i}{12}}|1\rangle) \\[10pt]
# U|u_1\rangle &= e^{\tfrac{2\pi i}{12}}\cdot\tfrac{1}{\sqrt{12}}(e^{\tfrac{-2\pi i}{12}}|3\rangle + e^{-\tfrac{4\pi i}{12}}|9\rangle + e^{-\tfrac{6\pi i}{12}}|27\rangle \dots + e^{-\tfrac{22\pi i}{12}}|12\rangle + e^{-\tfrac{24\pi i}{12}}|1\rangle) \\[10pt]
# U|u_1\rangle &= e^{\tfrac{2\pi i}{12}}|u_1\rangle
# \end{aligned}$$
#
# (We can see $r = 12$ appears in the denominator of the phase.)
# </details>
#
# This is a particularly interesting eigenvalue as it contains $r$. In fact, $r$ has to be included to make sure the phase differences between the $r$ computational basis states are equal. This is not the only eigenstate with this behaviour; to generalise this further, we can multiply an integer, $s$, to this phase difference, which will show up in our eigenvalue:
#
# $$\begin{aligned}
# |u_s\rangle &= \tfrac{1}{\sqrt{r}}\sum_{k=0}^{r-1}{e^{-\tfrac{2\pi i s k}{r}}|a^k \bmod N\rangle}\\[10pt]
# U|u_s\rangle &= e^{\tfrac{2\pi i s}{r}}|u_s\rangle
# \end{aligned}
# $$
#
# <details>
#     <summary>Click to Expand: Example with $a = 3$ and $N=35$</summary>
#
# $$\begin{aligned}
# |u_s\rangle &= \tfrac{1}{\sqrt{12}}(|1\rangle + e^{-\tfrac{2\pi i s}{12}}|3\rangle + e^{-\tfrac{4\pi i s}{12}}|9\rangle \dots + e^{-\tfrac{20\pi i s}{12}}|4\rangle + e^{-\tfrac{22\pi i s}{12}}|12\rangle) \\[10pt]
# U|u_s\rangle &= \tfrac{1}{\sqrt{12}}(|3\rangle + e^{-\tfrac{2\pi i s}{12}}|9\rangle + e^{-\tfrac{4\pi i s}{12}}|27\rangle \dots + e^{-\tfrac{20\pi i s}{12}}|12\rangle + e^{-\tfrac{22\pi i s}{12}}|1\rangle) \\[10pt]
# U|u_s\rangle &= e^{\tfrac{2\pi i s}{12}}\cdot\tfrac{1}{\sqrt{12}}(e^{-\tfrac{2\pi i s}{12}}|3\rangle + e^{-\tfrac{4\pi i s}{12}}|9\rangle + e^{-\tfrac{6\pi i s}{12}}|27\rangle \dots + e^{-\tfrac{22\pi i s}{12}}|12\rangle + e^{-\tfrac{24\pi i s}{12}}|1\rangle) \\[10pt]
# U|u_s\rangle &= e^{\tfrac{2\pi i s}{12}}|u_s\rangle
# \end{aligned}$$
#
# </details>
#
# We now have a unique eigenstate for each integer value of $s$ where $$0 \leq s \leq r-1.$$ Very conveniently, if we sum up all these eigenstates, the different phases cancel out all computational basis states except $|1\rangle$:
#
# $$ \tfrac{1}{\sqrt{r}}\sum_{s=0}^{r-1} |u_s\rangle = |1\rangle$$
#
# <details>
#     <summary>Click to Expand: Example with $a = 7$ and $N=15$</summary>
#
# For this, we will look at a smaller example where $a = 7$ and $N=15$. In this case $r=4$:
#
# $$\begin{aligned}
# \tfrac{1}{2}(\quad|u_0\rangle &= \tfrac{1}{2}(|1\rangle \hphantom{e^{-\tfrac{2\pi i}{12}}}+ |7\rangle \hphantom{e^{-\tfrac{12\pi i}{12}}} + |4\rangle \hphantom{e^{-\tfrac{12\pi i}{12}}} + |13\rangle)\dots \\[10pt]
# + |u_1\rangle &= \tfrac{1}{2}(|1\rangle + e^{-\tfrac{2\pi i}{4}}|7\rangle + e^{-\tfrac{\hphantom{1}4\pi i}{4}}|4\rangle + e^{-\tfrac{\hphantom{1}6\pi i}{4}}|13\rangle)\dots \\[10pt]
# + |u_2\rangle &= \tfrac{1}{2}(|1\rangle + e^{-\tfrac{4\pi i}{4}}|7\rangle + e^{-\tfrac{\hphantom{1}8\pi i}{4}}|4\rangle + e^{-\tfrac{12\pi i}{4}}|13\rangle)\dots \\[10pt]
# + |u_3\rangle &= \tfrac{1}{2}(|1\rangle + e^{-\tfrac{6\pi i}{4}}|7\rangle + e^{-\tfrac{12\pi i}{4}}|4\rangle + e^{-\tfrac{18\pi i}{4}}|13\rangle)\quad) = |1\rangle \\[10pt]
# \end{aligned}$$
#
# </details>
#
# Since the computational basis state $|1\rangle$ is a superposition of these eigenstates, which means if we do QPE on $U$ using the state $|1\rangle$, we will measure a phase:
#
# $$\phi = \frac{s}{r}$$
#
# Where $s$ is a random integer between $0$ and $r-1$. We finally use the [continued fractions](https://en.wikipedia.org/wiki/Continued_fraction) algorithm on $\phi$ to find $r$. The circuit diagram looks like this (note that this diagram uses Qiskit's qubit ordering convention):
#
# <img src="images/shor_circuit_1.svg">
#
# We will next demonstrate Shor’s algorithm using Qiskit’s simulators. For this demonstration we will provide the circuits for $U$ without explanation, but in section 4 we will discuss how circuits for $U^{2^j}$ can be constructed efficiently.

# %% [markdown]
# ## 3. Qiskit Implementation
#
# In this example we will solve the period finding problem for $a=7$ and $N=15$. We provide the circuits for $U$ where:
#
# $$U|y\rangle = |ay\bmod 15\rangle $$
#
# without explanation. To create $U^x$, we will simply repeat the circuit $x$ times. In the next section we will discuss a general method for creating these circuits efficiently. The function `c_amod15` returns the controlled-U gate for `a`, repeated `power` times.

# %%
def c_amod15(a, power):
    """Controlled multiplication by a mod 15"""
    if a not in [2,4,7,8,11,13]:
        raise ValueError("'a' must be 2,4,7,8,11 or 13")
    U = QuantumCircuit(4)        
    for iteration in range(power):
        if a in [2,13]:
            U.swap(2,3)
            U.swap(1,2)
            U.swap(0,1)
        if a in [7,8]:
            U.swap(0,1)
            U.swap(1,2)
            U.swap(2,3)
        if a in [4, 11]:
            U.swap(1,3)
            U.swap(0,2)
        if a in [7,11,13]:
            for q in range(4):
                U.x(q)
    U = U.to_gate()
    U.name = "%i^%i mod 15" % (a, power)
    c_U = U.control()
    return c_U

# %%
qc = QuantumCircuit(5)

qc.append(c_amod15(2, 5),[0,1,2,3,4])
qc.draw('mpl')

# %% [markdown]
# We will use 8 counting qubits:

# %%
# Specify variables
n_count = 8  # number of counting qubits
a = 7

# %% [markdown]
# We also import the circuit for the QFT (you can read more about the QFT in the [quantum Fourier transform chapter](./quantum-fourier-transform.html#generalqft)):

# %%
def qft_dagger(n):
    """n-qubit QFTdagger the first n qubits in circ"""
    qc = QuantumCircuit(n)
    # Don't forget the Swaps!
    for qubit in range(n//2):
        qc.swap(qubit, n-qubit-1)
    for j in range(n):
        for m in range(j):
            qc.cp(-np.pi/float(2**(j-m)), m, j)
        qc.h(j)
    qc.name = "QFT†"
    return qc

# %% [markdown]
# With these building blocks we can easily construct the circuit for Shor's algorithm:

# %%
# Create QuantumCircuit with n_count counting qubits
# plus 4 qubits for U to act on
qc = QuantumCircuit(n_count + 4, n_count)

# Initialize counting qubits
# in state |+>
for q in range(n_count):
    qc.h(q)
    
# And auxiliary register in state |1>
qc.x(n_count)

# Do controlled-U operations
for q in range(n_count):
    qc.append(c_amod15(a, 2**q), 
             [q] + [i+n_count for i in range(4)])

# Do inverse-QFT
qc.append(qft_dagger(n_count), range(n_count))

# Measure circuit
qc.measure(range(n_count), range(n_count))
qc.draw('mpl', fold=-1)  # -1 means 'do not fold'

# %% [markdown]
# Let's see what results we measure:

# %%
aer_sim = AerSimulator()
t_qc = transpile(qc, aer_sim)
results = aer_sim.run(t_qc).result()
counts = results.get_counts()
plot_histogram(counts)

# %% [markdown]
# Since we have 8 qubits, these results correspond to measured phases of:

# %%
rows, measured_phases = [], []
for output in counts:
    decimal = int(output, 2)  # Convert (base 2) string to decimal
    phase = decimal/(2**n_count)  # Find corresponding eigenvalue
    measured_phases.append(phase)
    # Add these values to the rows in our table:
    rows.append([f"{output}(bin) = {decimal:>3}(dec)", 
                 f"{decimal}/{2**n_count} = {phase:.2f}"])
# Print the rows in a table
headers=["Register Output", "Phase"]
df = pd.DataFrame(rows, columns=headers)
print(df)
# Out:
#             Register Output           Phase
# 0  11000000(bin) = 192(dec)  192/256 = 0.75
# 1  00000000(bin) =   0(dec)    0/256 = 0.00
# 2  10000000(bin) = 128(dec)  128/256 = 0.50
# 3  01000000(bin) =  64(dec)   64/256 = 0.25

# %% [markdown]
# We can now use the continued fractions algorithm to attempt to find $s$ and $r$. Python has this functionality built in: We can use the `fractions` module to turn a float into a `Fraction` object, for example:

# %%
Fraction(0.666)

# Exercise: Implement yourself the continuous fraction algorithm
# Out:
# Fraction(5998794703657501, 9007199254740992)

# %% [markdown]
# Because this gives fractions that return the result exactly (in this case, `0.6660000...`), this can give gnarly results like the one above. We can use the `.limit_denominator()` method to get the fraction that most closely resembles our float, with denominator below a certain value:

# %%
# Get fraction that most closely resembles 0.666
# with denominator < 15
Fraction(0.666).limit_denominator(15)
# Out:
# Fraction(2, 3)

# %% [markdown]
# Much nicer! The order (r) must be less than N, so we will set the maximum denominator to be `15`:

# %%
rows = []
for phase in measured_phases:
    frac = Fraction(phase).limit_denominator(15)
    rows.append([phase, f"{frac.numerator}/{frac.denominator}", frac.denominator])
# Print as a table
headers=["Phase", "Fraction", "Guess for r"]
df = pd.DataFrame(rows, columns=headers)
print(df)
# Out:
#    Phase Fraction  Guess for r
# 0   0.75      3/4            4
# 1   0.00      0/1            1
# 2   0.50      1/2            2
# 3   0.25      1/4            4

# %% [markdown]
# We can see that two of the measured eigenvalues provided us with the correct result: $r=4$, and we can see that Shor’s algorithm has a chance of failing. These bad results are because $s = 0$, or because $s$ and $r$ are not coprime and instead of $r$ we are given a factor of $r$. The easiest solution to this is to simply repeat the experiment until we get a satisfying result for $r$.
#
# ### Quick Exercise
#
# - Modify the circuit above for values of $a = 2, 8, 11$ and $13$. What results do you get and why?

# %% [markdown]
# ## 4. Modular Exponentiation
#
# You may have noticed that the method of creating the $U^{2^j}$ gates by repeating $U$ grows exponentially with $j$ and will not result in a polynomial time algorithm. We want a way to create the operator:
#
# $$ U^{2^j}|y\rangle = |a^{2^j}y \bmod N \rangle $$
#
# that grows polynomially with $j$. Fortunately, calculating:
#
# $$ a^{2^j} \bmod N$$
#
# efficiently is possible. Classical computers can use an algorithm known as _repeated squaring_ to calculate an exponential. In our case, since we are only dealing with exponentials of the form $2^j$, the repeated squaring algorithm becomes very simple:

# %%
def a2jmodN(a, j, N):
    """Compute a^{2^j} (mod N) by repeated squaring"""
    for i in range(j):
        a = np.mod(a**2, N)
    return a

# %%
a2jmodN(7, 2049, 53)
# Out:
# np.int64(47)

# %% [markdown]
# If an efficient algorithm is possible in Python, then we can use the same algorithm on a quantum computer. Unfortunately, despite scaling polynomially with $j$, modular exponentiation circuits are not straightforward and are the bottleneck in Shor’s algorithm. A beginner-friendly implementation can be found in reference [1].
#
# ## 5. Factoring from Period Finding
#
# Not all factoring problems are difficult; we can spot an even number instantly and know that one of its factors is 2. In fact, there are [specific criteria](https://nvlpubs.nist.gov/nistpubs/FIPS/NIST.FIPS.186-4.pdf#%5B%7B%22num%22%3A127%2C%22gen%22%3A0%7D%2C%7B%22name%22%3A%22XYZ%22%7D%2C70%2C223%2C0%5D) for choosing numbers that are difficult to factor, but the basic idea is to choose the product of two large prime numbers.
#
# A general factoring algorithm will first check to see if there is a shortcut to factoring the integer (is the number even? Is the number of the form $N = a^b$?), before using Shor’s period finding for the worst-case scenario. Since we aim to focus on the quantum part of the algorithm, we will jump straight to the case in which N is the product of two primes.
#
# ### Example: Factoring 15
#
# To see an example of factoring on a small number of qubits, we will factor 15, which we all know is the product of the not-so-large prime numbers 3 and 5.

# %%
N = 15

# %% [markdown]
# The first step is to choose a random number, $a$, between $1$ and $N-1$:

# %%
np.random.seed(1) # This is to make sure we get reproduceable results
a = np.random.randint(2, 15)
print(a)
# Out:
# 7

# %% [markdown]
# Next we quickly check it isn't already a non-trivial factor of $N$:

# %%
from math import gcd # greatest common divisor
gcd(a, N)
# Out:
# 1

# %% [markdown]
# Great. Next, we do Shor's order finding algorithm for `a = 7` and `N = 15`. Remember that the phase we measure will be $s/r$ where:
#
# $$ a^r \bmod N = 1 $$
#
# and $s$ is a random integer between 0 and $r-1$.

# %%
def qpe_amod15(a):
    n_count = 8
    qc = QuantumCircuit(4+n_count, n_count)
    for q in range(n_count):
        qc.h(q)     # Initialize counting qubits in state |+>
    qc.x(3+n_count) # And auxiliary register in state |1>
    for q in range(n_count): # Do controlled-U operations
        qc.append(c_amod15(a, 2**q), 
                 [q] + [i+n_count for i in range(4)])
    qc.append(qft_dagger(n_count), range(n_count)) # Do inverse-QFT
    #display(qc.draw('mpl'))
    qc.measure(range(n_count), range(n_count))
    # Simulate Results
    aer_sim = AerSimulator()
    # Setting memory=True below allows us to see a list of each sequential reading
    t_qc = transpile(qc, aer_sim)
    result = aer_sim.run(t_qc,shots=1, memory=True).result()
    readings = result.get_memory()
    print("Register Reading: " + readings[0])
    phase = int(readings[0],2)/(2**n_count)
    print("Corresponding Phase: %f" % phase)
    return phase

# %% [markdown]
# From this phase, we can easily find a guess for $r$:

# %%
phase = qpe_amod15(a) # Phase = s/r
Fraction(phase).limit_denominator(15) # Denominator should (hopefully!) tell us r
# Out:
# Register Reading: 10000000
# Corresponding Phase: 0.500000
# Fraction(1, 2)

# %%
frac = Fraction(phase).limit_denominator(15)
s, r = frac.numerator, frac.denominator
print(r)
# Out:
# 4

# %% [markdown]
# Now we have $r$, we might be able to use this to find a factor of $N$. Since:
#
# $$a^r \bmod N = 1 $$
#
# then:
#
# $$(a^r - 1) \bmod N = 0 $$
#
# which means $N$ must divide $a^r-1$. And if $r$ is also even, then we can write:
#
# $$a^r -1 = (a^{r/2}-1)(a^{r/2}+1)$$
#
# (if $r$ is not even, we cannot go further and must try again with a different value for $a$). There is then a high probability that the greatest common divisor of $N$ and either $a^{r/2}-1$, or $a^{r/2}+1$ is a proper factor of $N$ [2]:

# %%
guesses = [gcd(a**(r//2)-1, N), gcd(a**(r//2)+1, N)]
print(guesses)
# Out:
# [3, 5]

# %% [markdown]
# The cell below repeats the algorithm until at least one factor of 15 is found. You should try re-running the cell a few times to see how it behaves.

# %%
N = 15
a = 7
factor_found = False
attempt = 0
while not factor_found:
    attempt += 1
    print("\nAttempt %i:" % attempt)
    phase = qpe_amod15(a) # Phase = s/r
    frac = Fraction(phase).limit_denominator(N) # Denominator should (hopefully!) tell us r
    r = frac.denominator
    print("Result: r = %i" % r)
    if phase != 0:
        # Guesses for factors are gcd(x^{r/2} ±1 , 15)
        guesses = [gcd(a**(r//2)-1, N), gcd(a**(r//2)+1, N)]
        print("Guessed Factors: %i and %i" % (guesses[0], guesses[1]))
        for guess in guesses:
            if guess not in [1,N] and (N % guess) == 0: # Check to see if guess is a factor
                print("*** Non-trivial factor found: %i ***" % guess)
                factor_found = True
# Out:
# Attempt 1:
# Register Reading: 00000000
# Corresponding Phase: 0.000000
# Result: r = 1
#
# Attempt 2:
# Register Reading: 10000000
# Corresponding Phase: 0.500000
# Result: r = 2
# Guessed Factors: 3 and 1
# *** Non-trivial factor found: 3 ***

# %% [markdown]
# ### Run it now on an actual quantum computer

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(channel='ibm_quantum')
backend = service.least_busy()
print(backend.name)
sampler = Sampler(mode=backend)
sampler.options.default_shots = 100

# transpiling the circuits
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
pm = generate_preset_pass_manager(optimization_level=3, backend=backend)
# Out:
# ibm_sherbrooke

# %%
#we are taking bits of the function, but without the simulation
a = 7
n_count = 8
qc = QuantumCircuit(4+n_count, n_count)
for q in range(n_count):
    qc.h(q)     # Initialize counting qubits in state |+>
qc.x(3+n_count) # And auxiliary register in state |1>
for q in range(n_count): # Do controlled-U operations
    qc.append(c_amod15(a, 2**q), 
            [q] + [i+n_count for i in range(4)])
qc.append(qft_dagger(n_count), range(n_count)) # Do inverse-QFT
qc.measure(range(n_count), range(n_count))

qc_transpiled = pm.run(qc)                                
job = sampler.run([qc_transpiled], shots=1_000)

# %%
print(f">>> Job ID: {job.job_id()}")
print(f">>> Job Status: {job.status()}")
# Out:
# >>> Job ID: cz4w1c5p6030008cgccg
# >>> Job Status: QUEUED

# %%
print(f">>> Job Status: {job.status()}")
# Out:
# >>> Job Status: QUEUED

# %%
counts = jpn.result()[0].data.c.get_counts()
plot_histogram(counts)

# %%
import pickle
#load it back

with open('encrypted_msg.pkl', 'rb') as f:
    loaded_msg = pickle.load(f)

loaded_msg
# Out:
# [mpz(1),
#  mpz(13),
#  mpz(13),
#  mpz(12),
#  mpz(13),
#  mpz(13),
#  mpz(1),
#  mpz(8),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(8),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(8),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(4),
#  mpz(12),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(0),
#  mpz(13),
#  mpz(1),
#  mpz(6),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(4),
#  mpz(8),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(1),
#  mpz(4),
#  mpz(13),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(0),
#  mpz(8),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(12),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(4),
#  mpz(6),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(8),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(0),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(4),
#  mpz(6),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(8),
#  mpz(13),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(0),
#  mpz(1),
#  mpz(8),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(0),
#  mpz(1),
#  mpz(8),
#  mpz(1),
#  mpz(8),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(4),
#  mpz(8),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(12),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(6),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(4),
#  mpz(6),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(13),
#  mpz(1),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(13),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(8),
#  mpz(5),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(4),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(8),
#  mpz(12),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(4),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(8),
#  mpz(1),
#  mpz(5),
#  mpz(5),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(4),
#  mpz(6),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(1),
#  mpz(5),
#  mpz(4),
#  mpz(1),
#  mpz(4),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(12),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(4),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(1),
#  mpz(5),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(5),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(4),
#  mpz(12),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(0),
#  mpz(1),
#  mpz(8),
#  mpz(1),
#  mpz(6),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(6),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(0),
#  mpz(5),
#  mpz(6),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(12),
#  mpz(1),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(6),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(5),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(1),
#  mpz(13),
#  mpz(1),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(12),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(6),
#  mpz(0),
#  mpz(1),
#  mpz(13),
#  mpz(1),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(0),
#  mpz(5),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(6),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(13),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(1),
#  mpz(13),
#  mpz(1),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(5),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(5),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(4),
#  mpz(4),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(1),
#  mpz(5),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(0),
#  mpz(1),
#  mpz(8),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(4),
#  mpz(6),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(8),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(8),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(4),
#  mpz(12),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(0),
#  mpz(13),
#  mpz(1),
#  mpz(6),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(4),
#  mpz(8),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(1),
#  mpz(4),
#  mpz(13),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(1),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(4),
#  mpz(12),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(4),
#  mpz(12),
#  mpz(1),
#  mpz(5),
#  mpz(4),
#  mpz(1),
#  mpz(6),
#  mpz(5),
#  mpz(1),
#  mpz(4),
#  mpz(4),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(4),
#  mpz(4),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(6),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(6),
#  mpz(12),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(4),
#  mpz(5),
#  mpz(1),
#  mpz(4),
#  mpz(8),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(12),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(6),
#  mpz(8),
#  mpz(0),
#  mpz(4),
#  mpz(0),
#  mpz(1),
#  mpz(5),
#  mpz(13),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  mpz(5),
#  mpz(4),
#  mpz(1),
#  mpz(5),
#  mpz(1),
#  mpz(1),
#  mpz(5),
#  mpz(6),
#  mpz(1),
#  ...]

# %%
d = secret_key_from_prime(3,5,3)
d
# Out:
# mpz(3)

# %%
# Step 4: Decrypt the encrypted bitstring and check it matches the original
decrypted_bitstring = decrypt(loaded_msg, d, 3 ,5)
print("Decrypted Bitstring:", decrypted_bitstring)


# Step 5: Reconstruct the text from the decrypted bitstring
reconstructed_text = reformat_decrypted_bitstring(decrypted_bitstring)
print("Reconstructed Text:", reconstructed_text)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Reconstructed Text: ÿThe Project Gutenberg eBook of The Art of War
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: The Art of War
#
# Author: active 6th century B.C. Sunzi
#
# Translator: Lionel Giles
#
# Release date: May 1, 1994 [eBook #132]
#                 Most recently updated: October 29, 2024
#
# Language: English
#
# Original publication: , 1910
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK THE ART OF WAR ***
# Sun Tzŭ
# on
# The Art of War
#
# THE OLDEST MILITARY TREATISE IN THE WORLD
# Translated from the Chinese with Introduction and Critical Notes
#
# BY
# LIONEL GILES, M.A.
#
# Assistant in the Department of Oriental Printed Books and MSS.
# in the British Museum
#
#
#
#
# 1910
#
#
#
# To my brother
# Captain Valentine Giles, R.G.
# in the hope that
# a work 2400 years old
# may yet contain lessons worth consideration
# by the soldier of today
# this translation
# is affectionately dedicated.
#
#
#
# Contents
#
#
#  Preface to the Project Gutenberg Etext
#  Preface by Lionel Giles
#  INTRODUCTION
#  Sun Wu and his Book
#  The Text of Sun Tzŭ
#  The Commentators
#  Appreciations of Sun Tzŭ
#  Apologies for War
#  Bibliography
#  Chapter I. Laying plans
#  Chapter II. Waging War
#  Chapter III. Attack by Stratagem
#  Chapter IV. Tactical Dispositions
#  Chapter V. Energy
#  Chapter VI. Weak Points and Strong
#  Chapter VII Manœuvring
#  Chapter VIII. Variation of Tactics
#  Chapter IX. The Army on the March
#  Chapter X. Terrain
#  Chapter XI. The Nine Situations
#  Chapter XII. The Attack by Fire
#  Chapter XIII. The Use of Spies
#
#
#
# Preface to the Project Gutenberg Etext
#
# ǌƄčńǈNĄÅƄ	ǌƄčŁČNČŎŌčNčMǍƎÄd numerous mistakes corrected¡đƩƠāűĩƸQĩƑƑŹƑƘāƹĩƑĨāęƑĩĉơĩĠāŉŰāơŁĨāƁƑŹęĩƙƘŰā!ƐŰā9ŉšĩƘŠāŉŰāőƩƙơŉıǉŉűĸāŁŉƘQơƑĉűƙšĉơŉŹŰŠāƹƑŹơĨǐĀđIƠāƹĉƘāűŹƠāƩűġĩƑơĉřĩŰāŹƩƠāŹİāĉűǈāŉűıšĉơĩĠāĩƙơŉũĉơĨQŹİāũǈāŹƹŰāƁŹƹĩƑƘǘāđƩƠāHāęŹƩšĠāűŹƠāŁĩšƀāıĩĩšŉűĸāơŁĉƠāƩŰā¡ǕŨāġĩƙĩƑƱĩĠāĈQđĩơơĩƐāıĉơĨāơŁĉŰāŁĉĠāđĩıĉššĩŰāŁŉŨŠāĉűĠāHāřűĩƸāơŁĉƠŠāĉƠāĉűǈāƑĉơĨŠāHQęŹƩšĠāŁĉƑġšǈāıĉŉŠāơŸāŉũƁƑŹƱĨāŹŰāơŁĨāƹŹƑŘāŹİāũǈāƁƑĩġĩęĩƙƙŹƑƘŰĐPQšĩĉƑšǈŠā!ƐŰā9ŉšĩƚDǍǎÄŎÎČLčNÍŌĄŸā)űĹšŉƙŀāƹĉƘāƁƩđšŉƙŁĩĠāŉŰĀƈǈƀƨāŉŰā¡ŹřǉŸāđǈQĉƁƠŰā(Űā0ŰāĉšơŁƑŹƀŠāű0ŰāAŹƹĩƱĩƐŠāơŁŉƘāơƑĉűƙšĉơŉŹŰāŉƘŠāŉŰāơŁĨāƹŹƑġƘQŹİā!ƐŰā9ŉšĩƘŠĀđĩǁęĩƙƙŉƱĩšǈāđĉĠŰĐāAĨāĹŹĩƘāıƩƑơŁĩƐāŉŰāơŁŉƘāęƑŉơŉęŉƙŨǐĀđIƠQŉƘāűŹƠāũĩƑĩšǈāĈāƉƩĩƙơŉŹŰāŹİāġŹƹűƑŉĹŁƠāđšƩűġĩƑƘŠāıƑŹŨāƹŁŉęŀāűŹűĨāęĉŰQŁŹƁĨāơŸāđĨāƹŁŹššǈāĩǁĩũƁƠŰāyũŉƙƙŉŹűƘāƹĩƑĨāıƑĩƉƩĩűƠǘāŁĉƑĠāƁĉƙƙĉĹĩƘāƹĩƑĨQƹŉššıƩššǈāġŉƙơŹƑơĩĠāŹƐāƙšƩƑƑĩĠāŹƱĩƐŰāƩęŀāŹııĩűƙĩƘāĉƑĨāšĩƙƘāƁĉƑġŹűĉđšĨŰQ¡ŁĩǈāƹŹƩšĠāűŹƠāđĨāơŹšĩƑĉơĩĠāŉŰāĉűǈāĩġŉơŉŹŰāŹİāĈāaĉơŉŰāŹƐā9ƑĩĩŘāęšĉƙƙŉĘŠQĉűĠāĈāƙŉũŉšĉƐāƙơĉűġĉƑĠāŹİāŁŹűĩƙơǈāŹƩĹŁƠāơŸāđĨāŉűƙŉƙơĩĠāƩƁŹŰāŉŰQơƑĉűƙšĉơŉŹűƘāıƑŹŨāŁŉűĩƙĨŰĐāIŰĀƈǈƀǀāĈāűĩƸāĩġŉơŉŹŰāŹİāĉƁƠŰāĉšơŁƑŹƂNÁĎMƎÍČNčMǍƄǌNÄŌčNÍŌĄ
# NƌńŏMōMƌŌćÄĎǍǄƌŌNĎŎǍMČŎÐ
# edited translation and notes, the other two present the same basic
# information from the ancient Chinese commentators found in the Giles
# ǎčŎĎMƎÍČNčMǍƅƁčǍMČŎÐ edition of the _Art of War_, as stated above, was aĨāƑĩĉġĩƐāĉŰāŉűęƑĩġŉđšĨāĉũŹƩűƠāŹİāŉűıŹƑũĉơŉŹŰāęŹűęĩƑűŉűĸāƩŰQ¡ǕŪNÄČŏąĄ
# scholarly work. Dr. Giles was a leading sinologue at the time and an
# assistant in the Department of Oriental Printed Books and Manuscripts
# in the British Museum. Apparently he wanted to produce a definitive
# edition, superior to anything else that existed and perhaps something
# that would become a standard translation. It was the best translation
# available for 50 years. But apparently there was not much interest in
# Sun Tzŭ in English-speaking countries since it took the start of the
# Second World War to renew interest in his work. Several people
# published unsatisfactory English translations of Sun Tzŭ. In 1944, Dr.
# GilesÈāơƑĉűƙšĉơŉŹŰāƹĉƘāĩġŉơĩĠāĉűĠāƁƩđšŉƙŁĩĠāŉŰāơŁĨā©űŉơĩĠāơĉơĩƘāŉŰāĈQƙĩƑŉĩƘāŹİāũŉšŉơĉƑǈāƙęŉĩűęĨāđŹŹřƘŰāƩƠāŉƠāƹĉƙŲNĄōƎčMĄGFƆÄčNĄDǍǍǌāōƌǍčNÍĎMƎÍČNčMǍƄD
# MƄMƎąDǌNÁŌčNÍŌĄčNĄǌNÄMƄŎNŌMĄčǍMČŎÐ translation. While this
# ǌƄČŎƍǎČŌĄčǄčŁNĄid than Dr. GilesÈāơƑĉűƙšĉơŉŹŰŠāŉƠāšĉęřƘāŁŉƘQęŹƁŉŹƩƘāűŹơĩƘāơŁĉƠāũĉřĨāŁŉƘāƙŸāŉűơĩƑĩƙơŉűĸŰPQ!ƐŰā9ŉšĩƘāƁƑŹġƩęĩĠāĈāƹŹƑŘāƁƑŉũĉƑŉšǈāŉűơĩűġĩĠāıŹƐāƙęŁŹšĉƑƘāŹİāơŁĨQŁŉűĩƙĨāęŉƱŉšŉǑĉơŉŹŰāĉűĠāšĉűĹƩĉĹĨŰāIƠāęŹűơĉŉűƘāơŁĨāŁŉűĩƙĨāơĩǁƠāŹİāƩŰQ¡ǕŨŠāơŁĨā)űĹšŉƙŀāơƑĉűƙšĉơŉŹŰŠāĉűĠāƱŹšƩũŉűŹƩƘāűŹơĩƘāĉšŹűĸāƹŉơŀāűƩũĩƑŹƩƘQıŹŹơűŹơĩƘŰā©űıŹƑơƩűĉơĩšǈŠāƙŹũĨāŹİāŁŉƘāűŹơĩƘāĉűĠāıŹŹơűŹơĩƘāęŹűơĉŉŰQŁŉűĩƙĨāęŁĉƑĉęơĩƑƘǘāƙŹũĨāĉƑĨāęŹũƁšĩơĩšǈāŁŉűĩƙĨŰā¡ŁƩƘŠāĈāęŹűƱĩƑƙŉŹŰāơŸQĈāaĉơŉŰāĉšƁŁĉđĩƠāĩơĩǁƠāƹĉƘāġŉııŉęƩšƠŰāHāġŉĠāơŁĨāęŹűƱĩƑƙŉŹŰāŉŰāęŹũƁšĩơĨQŉĹűŹƑĉűęĨāŹİāŁŉűĩƙĨĀŁĩǁęĩƁƠāıŹƐāƹŁĉƠāHāšĩĉƑűĩĠāƹŁŉšĨāġŹŉűĸāơŁĨQęŹűƱĩƑƙŉŹŰňŰā¡ŁƩƘŠāHāıĉęĩĠāơŁĨāġŉııŉęƩšƠāơĉƙŘāŹİāƁĉƑĉƁŁƑĉƙŉűĸāŉƠāƹŁŉšĨQƑĩơĉŉűŉűĸāĉƘāũƩęŀāŹİāơŁĨāŉũƁŹƑơĉűƠāơĩǁƠāĉƘāHāęŹƩšĠŰā)ƱĩƑǈāƁĉƑĉƁŁƑĉƙĨQƑĩƁƑĩƙĩűơƘāĈāšŹƙƘǘāơŁƩƘāHāġŉĠāƹŁĉƠāHāęŹƩšĠāơŸāƑĩơĉŉŰāĉƘāũƩęŀāŹİāơŁĨQơĩǁƠāĉƘāƁŹƙƙŉđšĨŰāĩęĉƩƙĨāơŁĨĀƈǈƈƀāơĩǁƠāęŹűơĉŉűƘāĈāŁŉűĩƙĨāęŹűęŹƑġĉűęĨŠQHāƹĉƘāĉđšĨāơŸāơƑĉűƙšŉơĩƑĉơĨāƁƑŹƁĩƐāűĉũĩƘŠāđŹŹřƘŠāĉűĠāơŁĨāšŉřĨāĉƠāơŁĨQƑŉƙŘāŹİāũĉřŉűĸāơŁĨāơĩǁƠāũŹƑĨāŹđƙęƩƑĨŰāAŹƹĩƱĩƐŠāơŁĨāơĩǁƠŠāŹŰāơŁĨāƹŁŹšĨŠQŉƘāƉƩŉơĨāƙĉơŉƙıĉęơŹƑǈāıŹƐāơŁĨāęĉƙƩĉŠāƑĩĉġĩƐŠāĈāơƑĉűƙıŹƑũĉơŉŹŰāũĉġĨQƁŹƙƙŉđšĨāđǈāęŹűƱĩƑƙŉŹŰāơŸāĉŰāĩơĩǁƠŰāAŹƹĩƱĩƐŠāHāęŹũĨāĉƹĉǈāıƑŹŨāơŁŉƘāơĉƙŘQƹŉơŀāơŁĨāıĩĩšŉűĸāŹİāšŹƙƘāđĩęĉƩƙĨāHāřűŹƸāơŁĉƠāƙŹũĩŹűĨāƹŉơŀāĈāđĉęřĹƑŹƩűĠQŉŰāŁŉűĩƙĨāęĉŰāġŸāĈāđĩơơĩƐāőŹĐāơŁĉŰāHāġŉĠǘāĉűǈāƙƩęŀāĉơơĩũƁƠāƹŹƩšĠāđĨQƹĩšęŹũĩĠŰPQŹĐāƩơơŹŰPPPQƑĩıĉęĨāđǈāaŉŹűĩŠā9ŉšĩƘPQ¡ŁĨāƙĩƱĩűơŀāƱŹšƩũĨāŹİāùkŉũŹŉƑĩƘāęŹűęĩƑűĉűƠāŢM
# ǎčŎĎŌNčNÌŎÅĄLes Treize Articles
# Đhabileté dans le gouvernement des Troupes._ Sun-tse dit : AyezƙĩƁŀQ	ũŉŹƠŰāŁƑĨā	ũŉŹƠāĉƁƁĩĉƑƘāơŸāŁĉƱĨāĩűőŹǉĩĠāűŸāƙũĉšŠāƑĩƁƩơĉơŉŹŰāĉƘāĈQƙŉűŹšŹĹƩĨāŉŰāŁŉƘāġĉǈŠāĉűĠāơŁĨāıŉĩšĠāŹİāŁŉƘāšĉđŹƩƑƘāƹĉƘāęĩƑơĉŉűšǈQĩǁơĩűƙŉƱĨŰāƩƠāŁŉƘāƙŸũęĉššĩĠāơƑĉűƙšĉơŉŹŰāŹİāơŁĨāƩŰā¡ǕŨŠāŉİāƁšĉęĩĠāƙŉġĨQđǈāƙŉġĨāƹŉơŀāơŁĨāŹƑŉĹŉűĉŠŠāŉƘāƙĩĩŰāĉƠāŹűęĨāơŸāđĨāšŉơơšĨāđĩơơĩƐāơŁĉŰāĉŰQŉũƁŹƙơƩƑĨŰāIƠāęŹűơĉŉűƘāĈāĹƑĩĉƠāġĩĉŠāơŁĉƠāƩŰā¡ǕŨāġŉĠāűŹƠāƹƑŉơĨŠāĉűĠQƱĩƑǈāšŉơơšĨāŉűġĩĩĠāŹİāƹŁĉƠāŁĨāġŉĠŰāAĩƑĨāŉƘāĈāıĉŉƐāƙƁĩęŉũĩŰŠāơĉřĩŰāıƑŹŨQơŁĨāŹƁĩűŉűĸāƙĩűơĩűęĩƘāŹİāęŁĉƁơĩƐĀƨǒāǈČń
# les noms de tous les Officiers tant généraux que subalternes;
# inscrivez-les dans un catalogue à part, avec la note des talents & de
# Đennemi doivent être comme des pierres que vousǎŎÄƌŎŏNƌMƌÌŎÍǍƎĎńQšŹƑƙƉƩĨāŢMǌÌÌNÍMǍƄōƄÌŎDƌōƎŌŅƌMNČŎÄōƄÍǎČńNŌńčǎŎÄÌŎŏNŌŁƍǎŎÄČŎƌŏÍǍōŌMƌČŎÍǍLōƎĄŎÎŌLĝNÄNŌńƍǎĎńMƌÍNMČńNĎČōƎčMǍƁŎÎĄČń
# ŌMNÄÍǏLŏƌMMƎNŌŎŎōƄÌŌÎŎąƄous à lÉĩűűĩũňāŉŠāűĨāġŹŉƠāǈāĉƱŹŉƐQĢLNŎĎńčLƌƝNōƌÌńNŌńÌōčČńĎńƍǎĄNńƌMLČŅĄĎńƍLČńNń
# Đhabileté & toute la perfection même du
# gouvernement des troupes.
#
#
# Throughout the nineteenth century, which saw a wonderful development in
# the study of Chinese literature, no translator ventured to tackle Sun
# Tzŭ, although his work was known to be highly valued in China as by far
# the oldest and best compendium of military science. It was not until
# the year 1905 that the first English translation, by Capt. E.F.
# ǌƄlthrop. R.F.A., appeared at Tokyo under the title áŹűƙŁŊŅčŁNMƌŎÌńƍǎń
# ÎōƄ
# ď­ŅEƄ
# NĄǌNÄŎƍLČōƎĄčNĄčŁĎMƎÍČNčǎs knowledge of Chinese was far too scanty to fit him to
# grapple with the manifold difficulties of Sun Tzŭ. He himself plainly
# acknowledges that without the aid of two Japanese gentlemen áơŁĨQĉęęŹũƁĉűǉŉűĸāơƑĉűƙšĉơŉŹŰāƹŹƩšĠāŁĉƱĨāđĩĩŰāŉũƁŹƙƙŉđšĨŲń
# ǎƌŎƄŎŌĄǌŎÁǌŎńǍMČƎōčďDčNÎčǎČŌĄ
# ČŎÎÁNčǍƌLČŅƄ
# ōĎƌŌōčMƌǄčNĄĄǌƄĄčńŎÌōƎāĎMƎÍČNčMǍƄ
# ÎōƄ
# ŏDŌČŌÌŎÎÍǎÅƄDNČŅĄ	AÍǎōČĄ
# ǌÌNąÌMĎčǎsčMǍƄ
# translation was published in London, this time, however, without any
# allusion to his Japanese collaborators. My first three chapters were
# ǌƄ	NMƌŎÌńÍǍōŌōƎČNčǎÐ on Sun TzŭŠāƙŸāơŁĉƠāơŁĨāęƑŉơŉęŉƙũƘāŹİāĉƁƠŰQĉšơŁƑŹƀāơŁĩƑĩŉŰāęŹűơĉŉűĩĠāũƩƙƠāđĨāƩűġĩƑƙơŹŹĠāĉƘāƑĩıĩƑƑŉűĸāơŸāŁŉƘQĩĉƑšŉĩƐāĩġŉơŉŹŰŰā¡ŁŉƘāŉƘāŹŰāơŁĨāƹŁŹšĨāĉŰāŉũƁƑŹƱĩũĩűƠāŹŰāơŁĨāŹơŁĩƐŠQơŁŹƩĹŁƠāơŁĩƑĨāƙơŉšŠāƑĩũĉŉűƘāũƩęŀāơŁĉƠāęĉűűŹƠāƁĉƙƘāũƩƙơĩƐŰāŹũĨāŹİāơŁĨQĹƑŹƙƙĩƐāđšƩűġĩƑƘāŁĉƱĨāđĩĩŰāƑĩęơŉıŉĩĠāĉűĠāšĉęƩűĉĨāıŉššĩĠāƩƀŠāđƩƠāŹŰāơŁĨQŹơŁĩƐāŁĉűĠāĈāęĩƑơĉŉŰāűƩũđĩƐāŹİāűĩƸāũŉƙơĉřĩƘāĉƁƁĩĉƐŰā¡ŁĨāƱĩƑǈāıŉƑƙƠQƙĩűơĩűęĨāŹİāơŁĨāŉűơƑŹġƩęơŉŹŰāŉƘāƙơĉƑơšŉűĹšǈāŉűĉęęƩƑĉơĨǘāĉűĠāšĉơĩƐāŹŰŠQƹŁŉšĨāũĩűơŉŹŰāŉƘāũĉġĨāŹİĂČMƄNŏD
# (who are these, by the way?), not a word is vouchsafed about the
# Chinese commentators, who nevertheless, I venture to assert, form a
# ǌƄÎĎŌČōƎĎÁǌōƌŎMčďEƄÎǎÎÅŎŌƌŎōƌÌńMƌĄƍǎčńÍǍƎƌōƍLōƌÌńƌŎǄÎŌÍLMĄƌŌNĎŎŎÄ
# ǌƄńčNƍNÍMǍƄƍǍččǎǎÄǌLčďDčNĄ
# ÎōƄ	ÍMƌǅŏLōƐs
# edition; but I have sometimes found it desirable to join two or more of
# his paragraphs into one. In quoting from other works, Chinese writers
# seldom give more than the bare title by way of reference, and the task
# of research is apt to be seriously hampered in consequence. With a view
# to obviating this difficulty so far as Sun Tzŭ is concerned, I have
# also appended a complete concordance of Chinese characters, following
# in this the admirable example of Legge, though an alphabetical
# arrangement has been preferred to the distribution under radicals which
# MƎČŎŎÎąƄDǄŎÌōƎĄńÎŌMńčǄǍfrom á¡ŁĨāŁŉűĩƙĨāšĉƙƙŉęƚń
# ǌƄčńƍLŎǅĄŎƌōƄƎǍŁčńōƄńĎMƎÍČNČŌąDÌÌNč
# ǌƄŎÄmere translations,èāƹŹƩšĠQűŹƠŠāHāũƩƙƠāęŹűıĩƙƘŠāđĨāĉšơŹĹĩơŁĩƐāƩűƹĩšęŹũĨŰā1ŹƐŠāĉıơĩƐāĉšŠŠāơŁĨāƹŹƑƙƠQıĉơĨāHāƙŁĉšŠāŁĉƱĨāơŸāġƑĩĉĠāŉƘāơŁĉƠāƹŁŉęŀāđĩıĩšŠāơŁĨāŉűĹĩűŉŹƩƘāƁĉƑĉġŹǁĩƘQŹİā9ĩŹƑĹĨāŉŰāù¡ŁĨā±ŉęĉƐāŹİā¹ĉřĩıŉĩšġøŰPPPQIq¡y!©¡IypPQƩŰā¹ƨāĉűĠāŁŉƘāŹŹŘPQƙƨũũĈāłMLōƄǍNƌŎÄčńƍǍččǎǍMƌǄMǌǎN
# ÎōƄ
# ď­ŇÆKŁÎōƄ
# ď­ń
# ǌƄčÍi State. His _Art of War_ brought him
# to the notice of Ho Lu, [2] King of Wu. Ho Lu said to him:
#
# "I have carefully perused your 13 chapters. May I submit your theory of
# managing soldiers to a slight test?"
#
# Sun Tzŭ replied: "You may."
#
# Ho Lu asked: "May the test be applied to women?"
#
# The answer was again in the affirmative, so arrangements were made to
# bring 180 ladies out of the Palace. Sun Tzŭ divided them into two
# ƍǎĄŁōŌLČŌąƄÎōƄčĄe of the KingÉƘāıĉƱŹƩƑŉơĨāęŹűęƩđŉűĩƘāĉƠāơŁĨāŁĩĉĠQŹİāĩĉęŀŰāAĨāơŁĩŰāđĉġĨāơŁĩŨāĉšŠāơĉřĨāƙƁĩĉƑƘāŉŰāơŁĩŉƐāŁĉűġƘŠāĉűĠQĉġġƑĩƙƙĩĠāơŁĩŨāơŁƩƘǐĀđHāƁƑĩƙƩũĨāǉŹƨāřűŹƸāơŁĨāġŉııĩƑĩűęĨāđĩơƹĩĩŰāıƑŹűƠQĉűĠāđĉęŘŠāƑŉĹŁƠāŁĉűĠāĉűĠāšĩıƠāŁĉűĠǸĐPQ¡ŁĨāĹŉƑšƘāƑĩƁšŉĩĠǐāÉĩƘŰPQƩŰā¡ǕŨāƹĩűƠāŹŰǐĀđ¹ŁĩŰāHāƙĉǈĀđ)ǉĩƘāıƑŹűƠŠĐāǉŹƨāũƩƙƠāšŹŹŘāƙơƑĉŉĹŁƠQĉŁĩĉĠŰā¹ŁĩŰāHāƙĉǈĀđaĩıƠāơƩƑŰŠĐāǉŹƨāũƩƙƠāıĉęĨāơŹƹĉƑġƘāǉŹƩƐāšĩıƠāŁĉűĠŰQ¹ŁĩŰāHāƙĉǈĀđŉĹŁƠāơƩƑŰŠĐāǉŹƨāũƩƙƠāıĉęĨāơŹƹĉƑġƘāǉŹƩƐāƑŉĹŁƠāŁĉűĠŰā¹ŁĩŰāHQƙĉǈĀđ	đŹƩƠāơƩƑŰŠĐāǉŹƨāũƩƙƠāıĉęĨāƑŉĹŁƠāƑŹƩűĠāơŹƹĉƑġƘāǉŹƩƐāđĉęŘŰĐPQ	ĹĉŉŰāơŁĨāĹŉƑšƘāĉƙƙĩűơĩĠŰā¡ŁĨāƹŹƑġƘāŹİāęŹũũĉűĠāŁĉƱŉűĸāđĩĩŰāơŁƩƘQĩǁƁšĉŉűĩĠŠāŁĨāƙĩƠāƩƀāơŁĨāŁĉšđĩƑġƘāĉűĠāđĉơơšĨũĉǁĩƘāŉŰāŹƑġĩƐāơŸāđĩĹŉŰāơŁĨQġƑŉšŠŰā¡ŁĩŰŠāơŸāơŁĨāƙŹƩűĠāŹİāġƑƩũƘŠāŁĨāĹĉƱĨāơŁĨāŹƑġĩƐĀđŉĹŁƠāơƩƑŰŰĐāƩƠQơŁĨāĹŉƑšƘāŹűšǈāđƩƑƙƠāŹƩƠāšĉƩĹŁŉűĸŰāƩŰā¡ǕŨāƙĉŉĠǐĀđIİāƹŹƑġƘāŹİāęŹũũĉűĠQĉƑĨāűŹƠāęšĩĉƐāĉűĠāġŉƙơŉűęƠŠāŉİāŹƑġĩƑƘāĉƑĨāűŹƠāơŁŹƑŹƩĹŁšǈāƩűġĩƑƙơŹŹĠŠQơŁĩŰāơŁĨāĹĩűĩƑĉŠāŉƘāơŸāđšĉũĨŰĐPQŸāŁĨāƙơĉƑơĩĠāġƑŉššŉűĸāơŁĩŨāĉĹĉŉŰŠāĉűĠāơŁŉƘāơŉũĨāĹĉƱĨāơŁĨāŹƑġĩƐĀđaĩıƠQơƩƑŰŠĐāƹŁĩƑĩƩƁŹŰāơŁĨāĹŉƑšƘāŹűęĨāũŹƑĨāđƩƑƙƠāŉűơŸāıŉơƘāŹİāšĉƩĹŁơĩƐŰāƩŰQ¡ǕŨǐĀđIİāƹŹƑġƘāŹİāęŹũũĉűĠāĉƑĨāűŹƠāęšĩĉƐāĉűĠāġŉƙơŉűęƠŠāŉİāŹƑġĩƑƘāĉƑĨāűŹƠQơŁŹƑŹƩĹŁšǈāƩűġĩƑƙơŹŹĠŠāơŁĨāĹĩűĩƑĉŠāŉƘāơŸāđšĉũĨŰāƩƠāŉİāŁŉƘāŹƑġĩƑƘāùĉƑĩøQęšĩĉƐŠāĉűĠāơŁĨāƙŹšġŉĩƑƘāűĩƱĩƑơŁĩšĩƙƘāġŉƙŹđĩǈŠāơŁĩŰāŉƠāŉƘāơŁĨāıĉƩšƠāŹİQơŁĩŉƐāŹııŉęĩƑƘŰĐPQŸāƙĉǉŉűĸŠāŁĨāŹƑġĩƑĩĠāơŁĨāšĩĉġĩƑƘāŹİāơŁĨāơƹŸāęŹũƁĉűŉĩƘāơŸāđĨāđĩŁĩĉġĩĠŰQqŹƸāơŁĨāřŉűĸāŹİā¹ƨāƹĉƘāƹĉơęŁŉűĸāơŁĨāƙęĩűĨāıƑŹŨāơŁĨāơŹƀāŹİāĈāƑĉŉƙĩĠQƁĉƱŉšŉŹŰǘāĉűĠāƹŁĩŰāŁĨāƙĉƸāơŁĉƠāŁŉƘāıĉƱŹƩƑŉơĨāęŹűęƩđŉűĩƘāƹĩƑĨāĉđŹƩƠāơŸāđĨQĩǁĩęƩơĩĠŠāŁĨāƹĉƘāĹƑĩĉơšǈāĉšĉƑũĩĠāĉűĠāŁƩƑƑŉĩġšǈāƙĩűƠāġŹƹŰāơŁĨāıŹššŹƹŉűĸQũĩƙƙĉĹĨǐĀđ¹ĨāĉƑĨāűŹƸāƉƩŉơĨāƙĉơŉƙıŉĩĠāĉƘāơŸāŹƩƐāĹĩűĩƑĉŢNÄLMčNďDčǁMƌčČńĎǍǎÅƄ	LƄǌńNńŎŌƎĄ
# NÄ	ŌMŎÎďPs commission to be
# the general of his forces, there are certain commands of His Majesty
# which, acting in that capacity, I am unable to accept."
#
# Accordingly, he had the two leaders beheaded, and straightway installed
# the pair next in order as leaders in their place. When this had been
# done, the drum was sounded for the drill once more; and the girls went
# through all the evolutions, turning to the right or to the left,
# marching ahead or wheeling back, kneeling or standing, with perfect
# accuracy and precision, not venturing to utter a sound. Then Sun Tzŭ
# sent a messenger to the King saying: "Your soldiers, Sire, are now
# properly drilled and disciplined, and ready for your majestyÉƘQŉűƙƁĩęơŉŹŰŰā¡ŁĩǈāęĉŰāđĨāƁƩƠāơŸāĉűǈāƩƙĨāơŁĉƠāơŁĩŉƐāƙŹƱĩƑĩŉĹŰāũĉǈāġĩƙŉƑĨǘQđŉĠāơŁĩŨāĹŸāơŁƑŹƩĹŀāıŉƑĨāĉűĠāƹĉơĩƐŠāĉűĠāơŁĩǈāƹŉšŠāűŹƠāġŉƙŹđĩǈŰĐPQƩƠāơŁĨāYŉűĸāƑĩƁšŉĩĠǐĀđaĩƠāŹƩƐāĹĩűĩƑĉŠāęĩĉƙĨāġƑŉššŉűĸāĉűĠāƑĩơƩƑŰāơŸQęĉũƀŰā	ƘāıŹƐāƩƘŠā¹ĨāŁĉƱĨāűŸāƹŉƙŀāơŸāęŹũĨāġŹƹŰāĉűĠāŉűƙƁĩęƠāơŁĨāơƑŹŹƁƘŰĐPQ¡ŁĩƑĩƩƁŹŰāƩŰā¡ǕŨāƙĉŉĠǐĀđ¡ŁĨāYŉűĸāŉƘāŹűšǈāıŹűĠāŹİāƹŹƑġƘŠāĉűĠāęĉűűŹƠQơƑĉűƙšĉơĨāơŁĩŨāŉűơŸāġĩĩġƘŰĐPQ	ıơĩƐāơŁĉƠŠāAŸāaƨāƙĉƸāơŁĉƠāƩŰā¡ǕŨāƹĉƘāŹűĨāƹŁŸāřűĩƸāŁŹƸāơŸāŁĉűġšĨāĉŰQĉƑũǈŠāĉűĠāıŉűĉššǈāĉƁƁŹŉűơĩĠāŁŉŨāĹĩűĩƑĉŠŰāIŰāơŁĨāƹĩƙƠŠāŁĨāġĩıĩĉơĩĠāơŁĨQłNń
# MƎčǄčńŌNńńÌN
# ǌÍi and Chin, and spread his fame abroad
# amongst the feudal princes. And Sun Tzŭ shared in the might of the
# King.
#
# NÄčMŌŅƄǌōƍNŎÄimself this is all that Ssu-ma ChÉŉĩŰāŁĉƘāơŸāơĩšŠāƩƘāŉŰQơŁŉƘāęŁĉƁơĩƐŰāƩƠāŁĨāƁƑŹęĩĩġƘāơŸāĹŉƱĨāĈāđŉŹĹƑĉƁŁǈāŹİāŁŉƘāġĩƙęĩűġĉűƠŠQƩŰāŉŰŠāđŹƑŰāĉđŹƩƠāĈāŁƩűġƑĩĠāǉĩĉƑƘāĉıơĩƐāŁŉƘāıĉũŹƩƘāĉűęĩƙơŹƒNÄČŌNčāMƌĄMĎÍǄčń
# MńčǍǄNÄÎŌMÎÄ
# ÎōƄ
# NÄŌƌLÌńǌńŌLćÎōƄ
# ǎČŎčǄLÌÍǎōƎĄƍǎčŁƌMŌŅƄDǌNÄńNĄ
# NÁĎŌLÍŎǎŎÄNƌMĄ
# ang Chuan, will be found briefly related in Chapter
# V. § 19, note.
#
# To return to the elder Sun Tzŭ. He is mentioned in two other passages
# of the _Shih Chi:_ PQIŰāơŁĨāơŁŉƑĠāǉĩĉƐāŹİāŁŉƘāƑĩŉĹŰāØƨƈƐāűűèāAŸāaƨŠāřŉűĸāŹİā¹ƨŠāơŹŹŘāơŁĨQıŉĩšĠāƹŉơŀā¡ǕŨũŁƙƨāÙňűĨŰā¹ƨāÉƩĉűèāĉűĠāŸāLōEĄMƌĄNĎČLÍÌŌÍu. He
# Ǆ	ĎńLČĎŎÎÌŌĄƈÅƋŅĄ	ÍMƌǄ	 slew the two princeÉƘāƙŹűƘāƹŁŸāŁĉĠQıŹƑũĩƑšǈāđĩĩŰāĹĩűĩƑĉšƘāŹİā¹ƨŰāAĨāƹĉƘāơŁĩŰāũĩġŉơĉơŉűĸāĈāġĩƙęĩűƠāŹŰāÉŉűĸQÙơŁĨāęĉƁŉơĉšèǘāđƩƠāơŁĨāĹĩűĩƑĉŠāƩŰā¹ƨāƙĉŉĠǐĀđ¡ŁĨāĉƑũǈāŉƘāĩǁŁĉƩƙơĩĠŰāIƠQŉƘāűŹƠāǉĩƠāƁŹƙƙŉđšĨŰā¹ĨāũƩƙƠāƹĉŉƠĒƅƄÈLƎČŎƎŎčŎÎŌÌÌŎÎÌƎōāƍLǍčMƌǅċńMƄčń
# ǎŁď­ŅōÎńMƌĄ
# ÎōƄ
# ƍǎǇǄČńƍǎŎÄčǄōƎČŎMMƌǅƄ	NÄčńčMŌńNń
# ǌƄǄMƌĄÍǎƌŎčǎŎÅĄMƌāčńMƌÌŎÄǅĄÆċń
# Đang and TsÉĉňāđŹơŀāŁĉƱĨāĈāĹƑƩġĹĨāĉĹĉŉűƙƠāŁŉŨŰāIİāÉŹƩƐQiĉőĩƙơǈāŁĉƘāƑĩƙŹšƱĩĠāơŸāũĉřĨāĈāĹƑĉűĠāĉơơĉęŘŠāǉŹƨāũƩƙƠāƹŉŰāŹƱĩƐā¢LMƌǁMƌĄ
# ĎÐai, and then you may succeed." Ho Lu followed this advice, [beat
# ChÉƨāŉŰāıŉƱĨāƁŉơęŁĩĠāđĉơơšĩƘāĉűĠāũĉƑęŁĩĠāŉűơŸāÉŉűĸűèāØƩèPPQ¡ŁŉƘāŉƘāơŁĨāšĉơĩƙƠāġĉơĨāĉƠāƹŁŉęŀāĉűǉơŁŉűĸāŉƘāƑĩęŹƑġĩĠāŹİāƩŰā¹ƨŰāAĨQġŹĩƘāűŹƠāĉƁƁĩĉƐāơŸāŁĉƱĨāƙƩƑƱŉƱĩĠāŁŉƘāƁĉơƑŹŰŠāƹŁŸāġŉĩĠāıƑŹŨāơŁĨāĩııĩęơƘQŹİāĈāƹŹƩűĠāŉŰĀƠǈưŰāIŰāĉűŹơŁĩƐāęŁĉƁơĩƐāơŁĩƑĨāŹęęƩƑƘāơŁŉƘāƁĉƙƙĉĹĨǑØƱèPQ1ƑŹŨāơŁŉƘāơŉũĨāŹűƹĉƑĠŠāĈāűƩũđĩƐāŹİāıĉũŹƩƘāƙŹšġŉĩƑƘāĉƑŹƙĨŠāŹűĨāĉıơĩƐāơŁĨQŹơŁĩƐǐāYĉŸũıĉŰŠāØƹèāƹŁŸāƹĉƘāĩũƁšŹǉĩĠāđǈāơŁĨāŁŉŰāơĉơĨǘā¹ĉűĸũơǑƨŠāØǁèQŉŰāơŁĨāƙĩƑƱŉęĨāŹİāłMGÄMƌĄ
# ÎōƄ
# ǌƄčńÌŎƍLÌń
# ǎŅƄ
# ǌƍMǎŎÄōƍǎŌǍčNĄŎǄ
# ÎÎŅōŌÍien at least had no doubt about the
# reality of Sun Wu as an historical personage; and with one exception,
# to be noticed presently, he is by far the most important authority on
# the period in question. It will not be necessary, therefore, to say
# ǌƄčńNÎĄÌōƎĎŎEƈąƄōƄÍMǄLōhÉƩŰāłMNŋǅĄǍ
# KǄMƌĄŏMƌČŌĄǍNčǍŌMƎčLÄČŎČMMĎÅƄĄŎƌōƄ
# ǌƄńÎčǎD
# ÎōƄ
# MƄÍNČŎƄǎōƌąĄƍǎǍNĄ
# ƍǎčMƌǄNŇEAÎōƄ
# Ǆ	ĎńDƍNÎĄŌÍǍōŌōƌČŌĄčǄ
# ǎń
# ǌƄčNƌńČŌāDD	ń
# MƄčń	ŌMEōƌMƄńƍǍččǎǍMƌǄNÎÌLǌń
# ǎÎÍLČńŎƌōƄƍǎDǍƄMƌāōMƍNÎČŎÄÍ
# ÎōƄ
# ŎńčńŌNčLŎÎĄčNŌÎāŌƌŎōƌÌńƍǎč
# ÎōƄ
# ď­ŅĄƍǎ	ŌMEōƌMƄ
# KǄǌNÄǍNƌōƄčǄčńǍǎČąƁčNń	ÍLMƌǄŇƈÅƅDÌONÇčńŌNÍǍƄǍD
# ÎōƄ
# ŌōƄŌNÍu with 200,000 is that the latter were
# undisciplined."
#
# Teng Ming-shih informs us that the surname "Sun" was bestowed on Sun
# WuÉƘāĹƑĉűġıĉơŁĩƐāđǈā!ƩřĨāŁŉűĸāŹİāłMDÆņĆǅņćFƈÅƋŅƄ
# ÎōƄ
# ǎŐs father
# Sun PÉŉűĸŠāƑŹƙĨāơŸāđĨāĈāiŉűŉƙơĩƐāŹİāơĉơĨāŉŰāłMEĄMƌĄ
# ÎōƄ
# ǎÌńÎďMČńǌNÍang-chÉŉűĸŠāıšĩĠāơŸā¹ƨāŹŰāĉęęŹƩűƠāŹİāơŁĨāƑĩđĩššŉŹŰQƹŁŉęŀāƹĉƘāđĩŉűĸāıŹũĩűơĩĠāđǈāơŁĨāřŉűġƑĩĠāŹİā¢MLōƄ
# ǌƄŌŌĄ	ōMƌǅĄǌNÄčńƌNčŎ
# ÎōƄ
# NÄLÌÍǎōƎĄčōƅĄč
# ǌƄǌNÄčńǎMƌĎÍǍƄ
# LÍāÍǍƎÍLČŎMƌǄčNĄ
# ÎōƄ
# MƐs victory over Wei was gained in 341 B.C., may
# be dismissed as chronologically impossible. Whence these data were
# obtained by Teng Ming-shih I do not know, but of course no reliance
# whatever can be placed in them.
#
# An interesting document which has survived from the close of the Han
# ǎriod is the short preface written by the Great TsÉĉŸā¡ƚLMǅĄ
# ǌōD
# ǌƄŌčNčMǍƄ
# ÎōƄ
# MƄƎōčćMčĄǍNƌń
#
#
# I have heard that the ancients used bows and arrows to their advantage.
# [10] The _Lun Yu_ says: á¡ŁĩƑĨāũƩƙƠāđĨāĈāƙƩııŉęŉĩűęǈāŹİāũŉšŉơĉƑǈQƙơƑĩűĹơŀŲń
# ǌŌÎĎÁǌƄǍǎƌŎƍŌōƎąƄƌǄčńōLǍĄ
# ČŎČŎMƌĄarmyÈāŉűġŉęĉơĩƘāıŉƑũűĩƙƘāĉűĠQőƩƙơŉęĨǘāơŁĨāĩǁƁĩƑŉĩűęĩĠāšĩĉġĩƐāƹŉšŠāŁĉƱĨāĹŹŹĠāıŹƑơƩűĨŰĐā¡ŁĨāùŁŉŀQŁŉűĹøāƙĉǉƘǐĀđ¡ŁĨāYŉűĸāƑŹƙĨāũĉőĩƙơŉĘāŉŰāŁŉƘāƹƑĉơŀŠāĉűĠāŁĨāũĉƑƙŁĉššĩĠāŁŉƘQơƑŹŹƁƘŰĐā¡ŁĨāÉĩššŹƸā)ũƁĩƑŹƐŠā¢LMƌǄčÍǍŎ
# ǎń
# ǎČŎčǄÎŌÌÍǎŎčōNǌōƌŎNčMǍƅƄŎÄ
# NÄNƎÍai [11] on the one hand and Yen Wang on the
# ƌMŌńǌNÄƌMĄ In military matters, the SageÉƘāƑƩšĨāŉƘāűŹƑũĉššǈāơŸāřĩĩƀQơŁĨāƁĩĉęĨŠāĉűĠāơŸāũŹƱĨāŁŉƘāıŹƑęĩƘāŹűšǈāƹŁĩŰāŹęęĉƙŉŹŰāƑĩƉƩŉƑĩƘŰāAĨāƹŉšŠQűŹƠāƩƙĨāĉƑũĩĠāıŹƑęĨāƩűšĩƙƘāġƑŉƱĩŰāơŸāŉƠāđǈāűĩęĩƙƙŉơǈŰPQiĉűǈāđŹŹřƘāŁĉƱĨāHāƑĩĉĠāŹŰāơŁĨāƙƩđőĩęƠāŹİāƹĉƐāĉűĠāıŉĹŁơŉűĸǘāđƩƠāơŁĨāƹŹƑŘQęŹũƁŹƙĩĠāđǈāƩŰā¹ƨāŉƘāơŁĨāƁƑŹıŹƩűġĩƙƠāŹİāơŁĩŨāĉšŠŰāÙƩŰā¡ǕŨāƹĉƘāĈQűĉơŉƱĨāŹİāơŁĨāłMDÎČNČŅĄ
# ǎŅƄ	ńǎǎČńčńǈNāǌƄ
# ǌƄĎŅĄ	ÍMƌǄČŎÄƍǎ
# ČŌĄMƄNŏAǌŎÎĎǌNĎÅĄÎŎÍŌĄčÍu state and entered Ying the capital. In the
# ÍƍǎǍƄčǄńFÄÍNČŎÄǎMŎÄŉŰāŉŰāĉƹĨŰāŁƩűġƑĩĠāǉĩĉƑƘāĉűĠāũŹƑĨāĉıơĩƐāŁŉƘQơŉũĨŠāƩŰāŉŰāšŉƱĩĠŰāAĨāƹĉƘāĈāġĩƙęĩűġĉűƠāŹİā¹ƨűèāØƈƙèāIŰāŁŉƘāơƑĩĉơũĩűƠQŹİāġĩšŉđĩƑĉơŉŹŰāĉűĠāƁšĉűűŉűĸŠāơŁĨāŉũƁŹƑơĉűęĨāŹİāƑĉƁŉġŉơǈāŉŰāơĉřŉűĸāơŁĨQıŉĩšĠŠāØƈơèāęšĩĉƑűĩƙƘāŹİāęŹűęĩƁơŉŹŰŠāĉűĠāġĩƁơŀāŹİāġĩƙŉĹŰŠāƩŰā¡ǕŨQƙơĉűġƘāđĩǉŹűĠāơŁĨāƑĩĉęŀāŹİāęĉƑƁŉűĸāęƑŉơŉęŉƙŨŰāiǈāęŹűơĩũƁŹƑĉƑŉĩƘŠQŁŹƹĩƱĩƐŠāŁĉƱĨāıĉŉšĩĠāơŸāĹƑĉƙƀāơŁĨāıƩšŠāũĩĉűŉűĸāŹİāŁŉƘāŉűƙơƑƩęơŉŹűƘŠāĉűĠQƹŁŉšĨāƁƩơơŉűĸāŉűơŸāƁƑĉęơŉęĨāơŁĨāƙũĉššĩƐāġĩơĉŉšƘāŉŰāƹŁŉęŀāŁŉƘāƹŹƑŘQĉđŹƩűġƘŠāơŁĩǈāŁĉƱĨāŹƱĩƑšŹŹřĩĠāŉơƘāĩƙƙĩűơŉĉŠāƁƩƑƁŹƑƠŰā¡ŁĉƠāŉƘāơŁĨāũŹơŉƱĨQƹŁŉęŀāŁĉƘāšĩĠāũĨāơŸāŹƩơšŉűĨāĈāƑŹƩĹŀāĩǁƁšĉűĉơŉŹŰāŹİāơŁĨāƹŁŹšĨŰPQyűĨāơŁŉűĸāơŸāđĨāűŹơŉęĩĠāŉŰāơŁĨāĉđŹƱĨāŉƘāơŁĨāĩǁƁšŉęŉƠāƙơĉơĩũĩűƠāơŁĉƠāơŁĨPƈƘāęŁĉƁơĩƑƘāƹĩƑĨāƙƁĩęŉĉššǈāęŹũƁŹƙĩĠāıŹƐāYŉűĸāAŸāaƨŰā¡ŁŉƘāŉƘāƙƩƁƁŹƑơĩĠQđǈāơŁĨāŉűơĩƑűĉŠāĩƱŉġĩűęĨāŹİāHŰĂĸĀƈƨŠāŉŰāƹŁŉęŀāŉƠāƙĩĩũƘāęšĩĉƐāơŁĉƠāƙŹũĨQƑƩšĩƐāŉƘāĉġġƑĩƙƙĩĠŰPQIŰāơŁĨāđŉđšŉŹĹƑĉƁŁŉĘāƙĩęơŉŹŰāŹİāơŁĨāùAĉŰāŁƩøŠāơŁĩƑĨāŉƘāĉŰāĩűơƑǈāƹŁŉęŀQŁĉƘāĹŉƱĩŰāƑŉƙĨāơŸāũƩęŀāġŉƙęƩƙƙŉŹŰǐĀđ¡ŁĨāƹŹƑřƘāŹİāƩŰā¡ǕŨāŹİā¹ƨāŉŰĀǀƐQùƂMLōƋǄ
# ÎÎŅōŌÍien, or those
# MĐsimilar to the _Wen Shou-chieh refers to an edition of Sun TzŭÉƘQù	ƑƠāŹİā¹ĉƑøāŹİāƹŁŉęŀāơŁĨĀĐƈƘāęŁĉƁơĩƑƘĐāıŹƑũĩĠāơŁĨāıŉƑƙƠāùęŁƩĉűøŠQĉġġŉűĸāơŁĉƠāơŁĩƑĨāƹĩƑĨāơƹŸāŹơŁĩƐāùęŁƩĉűøāđĩƙŉġĩƘŰā¡ŁŉƘāŁĉƘāđƑŹƩĹŁƠQıŹƑơŀāĈāơŁĩŹƑǈŠāơŁĉƠāơŁĨāđƩšŘāŹİāơŁĩƙĨĀǀƐāęŁĉƁơĩƑƘāęŹűƙŉƙơĩĠāŹİāŹơŁĩƐQƹƑŉơŉűĹƘāŹİāƩŰā¡ǕŪĎǌńÍ
# Ta_, of which a specimen dealing with the Nine Situations [15] is
# Ǆ	ĎŅĄƍLŎǄǍNč	e _TÉƩűĸā¡ŉĩűøŠāĉűĠāĉűŹơŁĩƐāŉŰāAŸāŁŉŲNÄÍǍōŌōƎČNEƄ	NāNÄÎŌǌǌŎÎČŌĄčNĄŌƍǎń
# ÎōƄ
# MŎÌōČƄMƌĄčń	ÍMƌǅƄŎŎĎǌŌōƄŎĄLƎČŎǌNĎÄÍǍŎ
# ǌƄčńǊÎōƄńNŎč
# NÄŎǍNčANōǎČNčMǍƄƎǍńčńǊǎń_ČōÍun ChÉŉƨǑøĀđ¡ŁĨāYŉűĸāŹİā¹ƨāƙƩũũŹűĩĠāƩŰQ¡ǕŨŠāĉűĠāĉƙřĩĠāŁŉŨāƉƩĩƙơŉŹűƘāĉđŹƩƠāơŁĨāĉƑƠāŹİāƹĉƐŰā)ĉęŀāơŉũĨāŁĨāƙĩƠQıŹƑơŀāĈāęŁĉƁơĩƐāŹİāŁŉƘāƹŹƑŘŠāơŁĨāYŉűĸāęŹƩšĠāűŹƠāıŉűĠāƹŹƑġƘāĩűŹƩĹŀāơŸQƁƑĉŉƙĨāŁŉŨŰĐā	ƘāŁĨāƁŹŉűơƘāŹƩƠŠāŉİāơŁĨāƹŁŹšĨāƹŹƑŘāƹĉƘāĩǁƁŹƩűġĩĠāŹŰāơŁĨQƙĉũĨāƙęĉšĨāĉƘāŉŰāơŁĨāĉđŹƱĨũũĩűơŉŹűĩĠāıƑĉĹũĩűơƘŠāơŁĨāơŹơĉŠāűƩũđĩƐāŹİQęŁĉƁơĩƑƘāęŹƩšĠāűŹƠāıĉŉŠāơŸāđĨāęŹűƙŉġĩƑĉđšĨŰā¡ŁĩŰāơŁĨāűƩũĩƑŹƩƘāŹơŁĩƐQơƑĩĉơŉƙĩƘāĉơơƑŉđƩơĩĠāơŸāƩŰā¡ǕŨāũŉĹŁƠāđĨāŉűęšƩġĩĠŰā¡ŁĨāıĉęƠāơŁĉƠāơŁĨQùAĉŰāŁŉŁøāũĩűơŉŹűƘāűŸāƹŹƑŘāŹİāƩŰā¡ǕŨāĩǁęĩƁƠāơŁĨĀǀƐāùƂMLōƋǅĄǍŎŌNÁčń
# ÎōDMƌĄ
# Đang bibliographies give the titles of others in addition
# to the "13 chapters," is good proof, Pi I-hsun thinks, that all of
# these were contained in the 82 _pÉŉĩűøŰā¹ŉơŁŹƩƠāƁŉűűŉűĸāŹƩƐāıĉŉơŀāơŸQơŁĨāĉęęƩƑĉęǈāŹİāġĩơĉŉšƘāƙƩƁƁšŉĩĠāđǈāơŁĨāù¹ƨāËǡĩŀāłNōÍiu_, or
# admitting the genuineness of any of the treatises cited by Pi I-hsun,
# we may see in this theory a probable solution of the mystery. Between
# MŅƄÆFƋŁĎń	ŎŐs conjecture seems to be based on a passage which states: "Wei WuŉĩƘāơŸāŁĉƱĨāĹƑŹƹŰāƩƀāƩűġĩƐāơŁĨāũĉĹŉĘāűĉũĨāŹİāƩŰā¡ǕŨŠāĉűĠāơŁĨPǀƐāùƂMLōƋǄ
# Ti strung together Sun WuÉƘāù	ƑƠāŹİā¹ĉƑøŠĐāƹŁŉęŀāŉŰāơƩƑŰāũĉǈāŁĉƱĨQƑĩƙƩšơĩĠāıƑŹŨāĈāũŉƙƩűġĩƑƙơĉűġŉűĸāŹİāơŁĨāıŉűĉŠāƹŹƑġƘāŹİā¡ƚLMǄ	ÍMƌǐs
# preface. This, as Sun Hsing-yen points out, is only a modest way of
# saying that he made an explanatory paraphrase, or in other words, wrote
# a commentary on it. On the whole, this theory has met with very little
# acceptance. Thus, the _Ssu KÉƨāłNŌMƄ
# ǎLǍMƌMĄǍǎÅƄLČŎŌĄNĄ
# Ďń	ŎŐs assertion can certainly not be taken as
# proof."
#
# There is every reason to suppose, then, that the 13 chapters existed in
# the time of Ssu-ma ChÉŉĩŰāƁƑĉęơŉęĉššǈāĉƘāƹĨāŁĉƱĨāơŁĩŨāűŹƸŰā¡ŁĉƠāơŁĨQƹŹƑŘāƹĉƘāơŁĩŰāƹĩšŠāřűŹƹŰāŁĨāơĩššƘāƩƘāŉŰāƙŸāũĉűǈāƹŹƑġƘŰĀđƩŰā¡ǕŪNÄǆFÁÍNČŎËǄMƌĄ
# MƄÎČNČŌĄù	ƑƠāŹİā¹ĉƑøāĉƑĨāơŁĨāơƹŸāđŹŹřƘāơŁĉƠāƁĩŹƁšĨQęŹũũŹűšǈāƑĩıĩƐāơŸāŹŰāơŁĨāƙƩđőĩęƠāŹİāũŉšŉơĉƑǈāũĉơơĩƑƘŰāŹơŀāŹİāơŁĩŨāĉƑĨQƹŉġĩšǈāġŉƙơƑŉđƩơĩĠŠāƙŸāHāƹŉšŠāűŹƠāġŉƙęƩƙƘāơŁĩŨāŁĩƑĨŰĐāƩƠāĉƘāƹĨāĹŸQıƩƑơŁĩƐāđĉęŘŠāƙĩƑŉŹƩƘāġŉııŉęƩšơŉĩƘāđĩĹŉŰāơŸāĉƑŉƙĨŰā¡ŁĨāƙĉšŉĩűƠāıĉęƠQƹŁŉęŀāŁĉƘāơŸāđĨāıĉęĩĠāŉƘāơŁĉƠāơŁĨāù¡ƙŸāŁƩĉűøŠāơŁĨāĹƑĩĉơĩƙƠQęŹűơĩũƁŹƑĉƑǈāƑĩęŹƑĠŠāũĉřĩƘāűŸāũĩűơŉŹŰāƹŁĉơƙŹĩƱĩƐāŹİāƩŰā¹ƨŠāĩŉơŁĩƐāĉƘāĈQĹĩűĩƑĉŠāŹƐāĉƘāĈāƹƑŉơĩƐŰāIƠāŉƘāűĉơƩƑĉŠŠāŉŰāƱŉĩƸāŹİāơŁŉƘāĉƹřƹĉƑĠQęŉƑęƩũƙơĉűęĨŠāơŁĉƠāũĉűǈāƙęŁŹšĉƑƘāƙŁŹƩšĠāűŹƠāŹűšǈāęĉƙƠāġŹƩđƠāŹŰāơŁĨQƙơŹƑǈāŹİāƩŰā¹ƨāĉƘāĹŉƱĩŰāŉŰāơŁĨāùŁŉŀāŁŉøŠāđƩƠāĩƱĩŰāƙŁŹƸāơŁĩũƙĩšƱĩƘQıƑĉűřšǈāƙřĩƁơŉęĉŠāĉƘāơŸāơŁĨāĩǁŉƙơĩűęĨāŹİāơŁĨāũĉŰāĉƠāĉšŠŰā¡ŁĨāũŹƙƠQƁŹƹĩƑıƩŠāƁƑĩƙĩűơũĩűƠāŹİāơŁŉƘāƙŉġĨāŹİāơŁĨāęĉƙĨāŉƘāơŸāđĨāıŹƩűĠāŉŰāơŁĨQıŹššŹƹŉűĸāġŉƙƁŹƙŉơŉŹŰāđǈāÉĩŀāŁƩňũŁƙŉŰǐāØƈƹêāNĄ
# ÎÎŅōŌÍienÉƘāŁŉƙơŹƑǈāơŁĉƠāƩŰā¹ƨāƹĉƘāĈāűĉơŉƱĨāŹİāơŁĨQłMD
# čǏLŌĄDƌĄōŎ
# NÎčǎLŎÄÍǍƎČMMƅƁŎĄDŎƌŎNčand was a great general. But in TsoÉƘQŹũũĩűơĉƑǈāűŸāƩŰā¹ƨāĉƁƁĩĉƑƘāĉƠāĉšŠŰāIƠāŉƘāơƑƩĨāơŁĉƠā¡ƙźNÍǍōŌōƎČNAƌŌŌĄ
# NĄÎŌčLČńčNĄÎŌÍNÄMMƌǄ	Ðao-shu, [18] TsÉĉŸāYƩĩňŠāØƈǉèŠāŁƨāŁŉŀũƹƨāĉűĠQŁƩĉŰāŁĨũęŁƨāØƐƁèŰāIŰāơŁĨāęĉƙĨāŹİāƩŰā¹ƨŠāƹŁŹƙĨāıĉũĨāĉűĠāĉęŁŉĩƱĩũĩűơƘQƹĩƑĨāƙŸāđƑŉššŉĉűƠŠāơŁĨāŹũŉƙƙŉŹŰāŉƘāũƩęŀāũŹƑĨāĹšĉƑŉűĸŰā	ĹĉŉŰŠāġĩơĉŉšƘQĉƑĨāĹŉƱĩŰŠāŉŰāơŁĩŉƐāġƩĨāŹƑġĩƐŠāĉđŹƩƠāŁŉƘāęŹűơĩũƁŹƑĉƑŉĩƘā¹ƨāÉƩĉŰāĉűĠāơŁĨQiŉűŉƙơĩƐāLōEƄÆKń	NÄ
# ÎōƄ
# čNČŎNDÎďMČŅĄĄ
# ÎōƄ
# ď­Ős work belongs to the same school
# MƌÎŌčLČŅƁLōÄŎĎČŎďDŎŹøŠāØƐƙèāĉűĠāơŁĨāùËǡĩŀāÉƩøāØƐơèāĉűĠāũĉǈQŁĉƱĨāđĩĩŰāơŁĨāƁƑŹġƩęơŉŹŰāŹİāƙŹũĨāƁƑŉƱĉơĨāƙęŁŹšĉƐāšŉƱŉűĸāơŹƹĉƑġƘāơŁĨāĩűĠQŹİāơŁĨĀđƁƑŉűĸāĉűĠā	ƩơƩũŰĐāŹƐāơŁĨāđĩĹŉűűŉűĸāŹİāơŁĨĀđ¹ĉƑƑŉűĸāơĉơĩƘĐQƁĩƑŉŹĠŰāØƐƩèā¡ŁĨāƙơŹƑǈāơŁĉƠāŁŉƘāƁƑĩęĩƁơƘāƹĩƑĨāĉęơƩĉššǈāĉƁƁšŉĩĠāđǈāơŁĨQ¹ƨāơĉơĨŠāŉƘāũĩƑĩšǈāơŁĨāŹƩơęŹũĨāŹİāđŉĸāơĉšŘāŹŰāơŁĨāƁĉƑƠāŹİāŁŉƘQıŹššŹƹĩƑƘŰPQ1ƑŹŨāơŁĨāıšŹƩƑŉƙŁŉűĸāƁĩƑŉŹĠāŹİāơŁĨāŁŹƨāġǉűĉƙơǈāØƐƱèāġŹƹŰāơŸāơŁĨāơŉũĨQŹİāơŁĨĀđƁƑŉűĸāĉűĠā	ƩơƩũŰŠĐāĉšŠāũŉšŉơĉƑǈāęŹũũĉűġĩƑƘāƹĩƑĨāƙơĉơĩƙũĩŰāĉƘQƹĩšŠŠāĉűĠāơŁĨāęšĉƙƘāŹİāƁƑŹıĩƙƙŉŹűĉŠāĹĩűĩƑĉšƘŠāıŹƐāęŹűġƩęơŉűĸāĩǁơĩƑűĉŠQęĉũƁĉŉĹűƘŠāġŉĠāűŹƠāơŁĩŰāĩǁŉƙƠŰāIƠāƹĉƘāűŹƠāƩűơŉŠāơŁĨāƁĩƑŉŹĠāŹİāơŁĨĀđŉǀQơĉơĩƘĐāØƐƹèāơŁĉƠāơŁŉƘāęƩƙơŹŨāęŁĉűĹĩĠŰāqŹƸāĉšơŁŹƩĹŀā¹ƨāƹĉƘāĉŰQƩűęŉƱŉšŉǑĩĠāơĉơĨŠāŉƠāŉƘāęŹűęĩŉƱĉđšĨāơŁĉƠā¡ƙŸāƙŁŹƩšĠāŁĉƱĨāšĩıƠQƩűƑĩęŹƑġĩĠāơŁĨāıĉęƠāơŁĉƠāƩŰā¹ƨāƹĉƘāĈāĹƑĩĉƠāĹĩűĩƑĉŠāĉűĠāǉĩƠāŁĩšĠāűŸQęŉƱŉŠāŹııŉęĨǸā¹ŁĉƠāƹĨāĉƑĨāơŹšĠŠāơŁĩƑĩıŹƑĨŠāĉđŹƩƠāQĉűĸũęŁƨāØƐǁèāĉűĠāƩŰQ¹ƨŠāŉƘāűŹƠāĉƩơŁĩűơŉĘāũĉơơĩƐŠāđƩƠāơŁĨāƑĩęřšĩƙƘāıĉđƑŉęĉơŉŹŰāŹİāơŁĩŹƑŉǑŉűĸQƁƩűġŉơƘŰā¡ŁĨāƙơŹƑǈāŹİāAŸāaƪNÄŏŎMŌōƎĄ
# ÍōEōÍMƄŎŎÌōƎĎÄ
# ÎÎŅōŌÍien as having said that Sun Wu
# čǍNĎÅƄÌńŏĄƨāĉűĠāĩűơĩƑĩĠāÉŉűĸŰā¡ŁŉƘāŉƘāűŹƠāƉƩŉơĨāęŹƑƑĩęƠŰāqŸāġŹƩđƠāơŁĨQŉũƁƑĩƙƙŉŹŰāšĩıƠāŹŰāơŁĨāƑĩĉġĩƒNÄ
# KǄōNčŎčNĄƎćÄŎĄ
# ÎōƄ
# ÍƍǎǄčNĄōƎāčŎńNĄMčąƄ	ōǎōǎƌŎĄNÄǌń
# ǎńNŌMƄMƌĄ
# Ǆ
# ei both took
# part in the expedition, and also that its success was largely due to
# ǌƄčńsh and enterprise of Fu Kai, Ho LuÉƘāǉŹƩűĹĩƐāđƑŹơŁĩƐŠāŉƠāŉƘāűŹƠQĩĉƙǈāơŸāƙĩĨāŁŹƸāǉĩƠāĉűŹơŁĩƐāĹĩűĩƑĉŠāęŹƩšĠāŁĉƱĨāƁšĉǉĩĠāĈāƱĩƑǈāƁƑŹũŉűĩűƠQƁĉƑƠāŉŰāơŁĨāƙĉũĨāęĉũƁĉŉĹŰŰPQłLōÍōƅŎÎōƄ
# ƍǎČŇńƌNÎďD
#
# Military writers look upon Sun Wu as the father of their art. But the
# fact that he does not appear in the _Tso Chuan_, although he is said to
# have served under Ho Lu King of Wu, makes it uncertain what period he
# really belonged to.
#
#
# ƍǎčLÌŌLČńčNĄǎčLōNĄāŹİāƩŰā¹ƨāĉűĠā¹ƨāłMD
# ÍōEōÍMƄMƌÍen Chen-sun, while
# ƌMŌŅƄNÎÌŎÄōƌČŎĄčńČNČńĎLčNčMǍƌMčďDNÎÍLǍƌŌĄčǄčŁǍǎÄǍŉĩŲNÁ
# ǍƁÍen Chen-sun really misses its mark. He makes one of two points,
# however, which certainly tell in favour of the high antiquity of our "13
# chapters." "Sun Tzŭ," he says, "must have lived in the age of Ching
# Wang [519-476], because he is frequently plagiarized in subsequent
# works of the Chou, ChÉŉŰāĉűĠāAĉŰāġǉűĉƙơŉĩƘŰĐā¡ŁĨāơƹŸāũŹƙƠāƙŁĉũĩšĩƙƘQŹııĩűġĩƑƘāŉŰāơŁŉƘāƑĩƙƁĩęƠāĉƑĨā¹ƨāłMDMƌĄ	ŌMEōƌMƄ
# MƄčōNČOEƄÍǍƌLǌŎÄ
# ǌƄďDAÌōƎĎŎDLƎČŎčńMčČŌǌŌĄČNČń
# ÎōƄ
# MŅĄLÌÍǎčMƌǄčǄ	čNń	ÍLMƌǅāčNĄ
# ĎÌōƌǄ
# ǌÍÅĄŎÎČLčNÍŎÄDƌŎDÎĎǍƌǄMƎČŎMǎčǄčōńMčąĐin
# ƍǎĄńƍǎǍǎĎČōƄčNĄLōMMƅĄČƎōąĄčńĉšƑĩĉġǈāŉŰāĩǁŉƙơĩűęĨāơŹƹĉƑġƘQơŁĨāĩűĠāŹİāơŁĨĀƩơŀāęĩűơƩƑǈāűŰā1ƩƑơŁĩƐāƁƑŹŹİāŹİāƩŰā¡ǕŪNÄMƎčNNōNďD
# ǌƄčńƍLƎčÌōƎĎŎEƄōčǍƌǄčǄčńŌNďDNĄÎďMČń
# ǌƁÎōƄńĎČōŎĄčǄčNÎǎƌńčńŏ
# NÁƍǎĄƌNčǄÌŌōÅƄÍǍƎĎNEMƌĄ
# ōǌčLƍLŌāƍǎŅƄÆÆńNǌODAčńčMŌńMƌÍLōƎĄÏNÎČōń
# ǍƍďDǌNƌNń
# ÎōƄ
# ČNǌŁNąƄÍNMǎĎÄÄƌŎŌČMĄMƌÌŎÅĄ
# ǌƄƄďMƌNÎďEƄ	ńÎŌMÎÄNÄD
# ǎčŎčMƄDǌǍƜƍLČŋǄǌĎŌÎčMǍƄNńÌōƎÍLďAčMōMƍNÍŌąƄ
# čǎÎĄÌNŎÌŅNÄƍǎLōĆǆÁNÄNčLÎōČNďDōƍčMÌōďEĄƍǎ
# ÍōEōÍMƐs theory, that the
# author was a literary recluse, that seems to me quite untenable. If one
# thing is more apparent than another after reading the maxims of Sun
# Tzŭ, it is that their essence has been distilled from a large store of
# personal observation and experience. They reflect the mind not only of
# a born strategist, gifted with a rare faculty of generalization, but
# also of a practical soldier closely acquainted with the military
# conditions of his time. To say nothing of the fact that these sayings
# have been accepted and endorsed by all the greatest captains of Chinese
# history, they offer a combination of freshness and sincerity, acuteness
# and common sense, which quite excludes the idea that they were
# artificially concocted in the study. If we admit, then, that the 13
# chapters were the genuine production of a military man living towards
# ǌƄčńǊĎÍÍŌMƋǅĄčǄLÌÌŎĄŋǄŎMǌąĄNńǌń
# DǌŎńƌMĎÌńMƌĄōƎĎŎÎĎǍǎčGǄơŉƑĩơǈǸāIŰāƱŉĩƸāŹİāŁŉƘāŁŉĹŀāƑĩƁƩơĨāĉƘāĈāƙŹđĩƐāŁŉƙơŹƑŉĉŰŠāũƩƙƠāƹĨQűŹƠāŁĩƙŉơĉơĨāơŸāĉƙƙƩũĨāơŁĉƠāơŁĨāƑĩęŹƑġƘāŁĨāġƑĩƸāƩƁŹŰāıŹƐāƩŰā¹ƪNÁMǌǎN
# ƌŌǌNčNƌŅƄĄ	DƌŌNĄ
# ǎŎąƄŌĄĄƌNNÄ	DMńNǌNŅĄ
# čŎńNńĎǍǄNÎÌLǌŎÁMƄ
# ÎōƄ
# ǎNDLƌƌMNÅƄÍǍƎČōŎ
# MƁƉEƄǄG
#
# Though according to my estimate the soldiers of Yüeh exceed our own in
# number, that shall advantage them nothing in the matter of victory. I
# say then that victory can be achieved.
#
#
# ǎÍNčMǍƅƄNČńōŌōďDƌMĎŌLČńNÄŎƍLČōƌÌńāĉŰāĉƑũǈāęĉŰāđĨāũĉġĨāơŸāŉũŉơĉơĨāơŁĨāùƙŁƩĉňũőĉűøŠāHāƙŁŹƩšĠQĉűƙƹĩƐŠāÉĩƘŰā1ŹƐāơŁĨāũĩŰāŹİā¹ƨāĉűĠāơŁĨāũĩŰāŹİāËǡĩŀāĉƑĨāĩűĩũŉĩƘǘāǉĩƠāŉİQơŁĩǈāĉƑĨāęƑŹƙƙŉűĸāĈāƑŉƱĩƐāŉŰāơŁĨāƙĉũĨāđŹĉƠāĉűĠāĉƑĨāęĉƩĹŁƠāđǈāĈāƙơŹƑŨŠQơŁĩǈāƹŉšŠāęŹũĨāơŸāĩĉęŀāŹơŁĩƒNÄNÎÍNÎČMƌÌń
# ǌƄčńÎĎŌǌǍČńŎĎǌŌōƁǎńMƌĄ_ČōƄ
# ǌÌŎƌŌĄD
# ǌƄMNčŁÎŌčLMčNďDǎŎÍďD
# ǌƄŌčNČNAōƌōŏDńǎŌNĄĨŰā	ƘāƹĨāŁĉƱĨāƙĩĩŰāĉđŹƱĨŠāơŁĨQıŉƑƙƠāƁŹƙŉơŉƱĨāġĉơĨāĹŉƱĩŰāŉŰāęŹűűĩęơŉŹŰāƹŉơŀāƩŰā¹ƨāŉƘĀƨƈƐāűŰāAĨāŉƘQơŁĩŰāƙƁŹřĩŰāŹİāĉƘāĈāĹĩűĩƑĉŠŠāĉęơŉűĸāĉƘāęŹűıŉġĩűơŉĉŠāĉġƱŉƙĩƐāơŸāAŸāaƨŠQƙŸāơŁĉƠāŁŉƘāĉššĩĹĩĠāŉűơƑŹġƩęơŉŹŰāơŸāơŁĉƠāũŹűĉƑęŀāŁĉĠāĉšƑĩĉġǈāơĉřĩŰQƁšĉęĨŠāĉűĠāŹİāęŹƩƑƙĨāơŁĨĀƈƘāęŁĉƁơĩƑƘāũƩƙƠāŁĉƱĨāđĩĩŰāƹƑŉơơĩŰāĩĉƑšŉĩƐQƙơŉšŠŰāƩƠāĉƠāơŁĉƠāơŉũĨŠāĉűĠāıŹƐāƙĩƱĩƑĉŠāǉĩĉƑƘāĉıơĩƐŠāġŹƹŰāơŸāơŁĨQęĉƁơƩƑĨāŹİāÉŉűĸāŉŰĀƨƀưŠāłNńMƌĄ
# ǎŅƄ
# čńĎǍǄÎČNČŎÅÍu and Wu, had been constantly at war
# for over half a century, [31] whereas the first war between Wu and Yüeh
# was waged only in 510, [32] and even then was no more than a short
# MƄčńFÄÍNČŎÄNĄMčąƄe midst of the fierce struggle with ChÉƨŰāqŹƸQłNń
# ǌƄĄŌÍǍŌńčńMŌŁMƎČLǍǍƍNÎĄĎČōƄNĄDčMŌńǍōƄ_Čō
# NÅĄLƎČŎÍu had suffered the great
# humiliation of 506. At this point, a table of dates may be found
# useful.
#
#
# B.C.
# 514	Accession of Ho Lu.
# ǍƄ_ČōƄÎŌÌÌŎÎÌƎōĄNĎČLÍÄđƩƠāŉƘāġŉƙƙƩĉġĩĠāıƑŹŨāĩűơĩƑŉűĸāÉŉűĸŠQơŁĨāęĉƁŉơĉŠŰāŁŉŀāŁňāũĩűơŉŹűƘāƩŰā¹ƨāĉƘāĹĩűĩƑĉŠŰPƨƈƈI	űŹơŁĩƐāĉơơĉęŘāŹŰāłNŅƁņFJǎń
# ǎņHÍu invades Wu, but is signally defeated at Yu-chang.
# 506	Ho Lu attacks ChÉƨāƹŉơŀāơŁĨāĉŉĠāŹİā¢LMƌǄMƌĄ
# ĎÐai.
# Decisive battle of Po-chu, and capture of Ying. Last
# mention of Sun Wu in Shih Chi.
# 505	Yüeh makes a raid on Wu in the absence of its army. Wu
# is beaten by ChÉŉŰāĉűĠāĩƱĉęƩĉơĩƘāÉŉűĸŰPƨƀƠIAŸāaƨāƙĩűġƘā1ƨāłLMDčǄNĎČLÍÍu.
# 497	Kou Chien becomes King of Yüeh.
# 496	Wu attacks Yüeh, but is defeated by Kou Chien at Tsui-li.
# Ho Lu is killed.
# ǍƄ4	Fu ChÉĉňāġĩıĩĉơƘāYŹƨāŁŉĩŰāŉŰāơŁĨāĹƑĩĉƠāđĉơơšĨāŹİā1ƨŨQęŁĉŉŸŠāĉűĠāĩűơĩƑƘāơŁĨāęĉƁŉơĉŠāŹİāËǡĩŀŰPƠǀƨāŹƐĀƠǀƠIYŹƨāŁŉĩŰāƑĩűġĩƑƘāŁŹũĉĹĨāơŸā¹ƨŰā!ĩĉơŀāŹİā¹ƨā¡ǕŨũŁƙƨŰPƠǀƐIYŹƨāŁŉĩŰāŉűƱĉġĩƘā¹ƨāŉŰāơŁĨāĉđƙĩűęĨāŹİā1ƨāłLMEƁĆǇčǄĆǆƁHƎŎčŎNĎČLÍÎÄD_Čō
# ǌƄMĄÍLŌǌńčǄčńÌN
# ǌƄƁĆǆÁHƍMƌMĄČŌƌŌNĄMƌĄŏčMƌÎčMǍƄ
# ǎŅƁčńÌōƎČōƌÌńNōǎČŌĄLǎƌńƎǍń
# LĄĎŎƌŌĄLǌMMƎÎĄŎÄNčŎčǄ
# ǎÎčMčNčLŎÅĄŌōƄĎŎMƌǄčńŎMǌĄņŅņćFƅĄǍōƄčŎńǌNÄD
# NĎÄÎŎōŌńŌƌƍǎāLǌMMƎÎÍu. On the other hand, if we choose to disregard the
# ǎǄčōƄčLĄčńčMƄōƅDǌNÄÉƘāűĉũĨāƹŉơŀāAŸāaƨŠāŉƠāũŉĹŁƠāĩƉƩĉššǈāƹĩšŠQŁĉƱĨāƙĩĩŰāơŁĨāšŉĹŁƠāđĩơƹĩĩŰĀƠǈưāĉűĠĀƠǈƠŠāŹƐāƁŹƙƙŉđšǈāŉŰāơŁĨāƁĩƑŉŹĠPƠǀƐŨƠƸƘŠāƹŁĩŰāËǡĩŀāƹĉƘāŹűęĨāĉĹĉŉŰāđĩęŹũŉűĸāĈāƱĩƑǈāƙĩƑŉŹƩƘāũĩűĉęĨŰāØƘƙèQ¹ĨāũĉǈāıĩĩŠāıĉŉƑšǈāęĩƑơĉŉŰāơŁĉƠāơŁĨāĉƩơŁŹƐŠāƹŁŹĩƱĩƐāŁĨāũĉǈāŁĉƱĨāđĩĩŰŠQƹĉƘāűŹƠāĈāũĉŰāŹİāĉűǈāĹƑĩĉƠāĩũŉűĩűęĨāŉŰāŁŉƘāŹƹŰāġĉǈŰāyŰāơŁŉƘāƁŹŉűƠāơŁĨQűĩĹĉơŉƱĨāơĩƙơŉũŹűǈāŹİāơŁĨāù¡ƙŸāŁƩĉűøāıĉƐāŹƩơƹĩŉĹŁƘāĉűǈāƙŁƑĩĠāŹİQĉƩơŁŹƑŉơǈāƙơŉšŠāĉơơĉęŁŉűĸāơŸāơŁĨāùŁŉŀāŁŉøŠāŉİāŹűęĨāŉơƘāŹơŁĩƐāıĉęơƘQĉƑĨāġŉƙęƑĩġŉơĩĠŰāƩŰāAƙŉűĸũǉĩŰŠāŁŹƹĩƱĩƐŠāũĉřĩƘāĈāıĩĩđšĨāĉơơĩũƁƠāơŸQĩǁƁšĉŉŰāơŁĨāŹũŉƙƙŉŹŰāŹİāŁŉƘāűĉũĨāıƑŹŨāơŁĨāĹƑĩĉƠāęŹũũĩűơĉƑǈŰāIƠāƹĉƘā¹ƨQ¡ǕŨũŁƙƨŠāŁĨāƙĉǉƘŠāƹŁŸāĹŹƠāĉšŠāơŁĨāęƑĩġŉƠāŹİāƩŰā¹ƪNÄŏ
# ÎōƄ
# Ǆ	ĎŐs reign; it made a deep and lasting impression on
# all the surrounding states, and raised Wu to the short-lived zenith of
# her power. Hence, what more natural, as time went on, than that the
# acknowledged master of strategy, Sun Wu, should be popularly identified
# with that campaign, at first perhaps only in the sense that his brain
# conceived and planned it; afterwards, that it was actually carried out
# ǍƄÍǍƍŌÎĎŎŅƄMčōǎÎĄǍwith Wu Yuan, [34] Po PÉĩňāĉűĠā1ƨāYĉňǸPQIƠāŉƘāŹđƱŉŹƩƘāơŁĉƠāĉűǈāĉơơĩũƁƠāơŸāƑĩęŹűƙơƑƩęƠāĩƱĩŰāơŁĨāŹƩơšŉűĨāŹİāƩŰQ¡ǕŪNÄ
# Ǆ	ĎŐs accession, and gathered experience, though
# only in the capacity of a subordinate officer, during the intense
# MƄčńƍǍččǎǍMƌǄLŌNƄ_Čōs attack at this criticalprinceÉƘāƑĩŉĹŰŰQØƘƩèāIİāŁĨāƑŹƙĨāơŸāđĨāĈāĹĩűĩƑĉŠāĉƠāĉšŠŠāŁĨāęĩƑơĉŉűšǈāƹĉƘāűĩƱĩƐāŹŰāĉŰQĩƉƩĉŠāıŹŹơŉűĸāƹŉơŀāơŁĨāơŁƑĩĨāĉđŹƱĨāũĩűơŉŹűĩĠŰāAĨāƹĉƘāġŹƩđơšĩƙƘāƁƑĩƙĩűƠQĉƠāơŁĨāŉűƱĩƙơũĩűƠāĉűĠāŹęęƩƁĉơŉŹŰāŹİāÉŉűĸŠāĉűĠāƹŉơűĩƙƙĩĠā¹ƪNÄÎŌČČōƁÍǍčČNÌń
# juncture, when her rival was embarrassed on every side, seems to have
# convinced him that this upstart kingdom was the great enemy against
# whom every effort would henceforth have to be directed. Sun Wu was thus
# a well-seasoned warrior when he sat down to write his famous book,
# which according to my reckoning must have appeared towards the end,
# ǍƄǌNƁčńNČŎinning of Ho LuÉƘāƑĩŉĹŰŰā¡ŁĨāƙơŹƑǈāŹİāơŁĨāƹŹũĩŰāũĉǈQƁŹƙƙŉđšǈāŁĉƱĨāĹƑŹƹŰāŹƩƠāŹİāƙŹũĨāƑĩĉŠāŉűęŉġĩűƠāŹęęƩƑƑŉűĸāĉđŹƩƠāơŁĨāƙĉũĨQơŉũĨŰā	ƘāƹĨāŁĩĉƐāűŸāũŹƑĨāŹİāƩŰā¹ƨāĉıơĩƐāơŁŉƘāıƑŹŨāĉűǈāƙŹƩƑęĨŠāŁĨāŉƘQŁĉƑġšǈāšŉřĩšǈāơŸāŁĉƱĨāƙƩƑƱŉƱĩĠāŁŉƘāƁĉơƑŹŰāŹƐāơŸāŁĉƱĨāơĉřĩŰāƁĉƑƠāŉŰāơŁĨQġĩĉơŀũƙơƑƩĹĹšĨāƹŉơŀāËǡĩŀŠāƹŁŉęŀāđĩĹĉŰāƹŉơŀāơŁĨāġŉƙĉƙơĩƐāĉƠā¡ƙƩňũšňŰPQIİāơŁĩƙĨāŉűıĩƑĩűęĩƘāĉƑĨāĉƁƁƑŹǁŉũĉơĩšǈāęŹƑƑĩęƠŠāơŁĩƑĨāŉƘāĈāęĩƑơĉŉŰāŉƑŹűǈQŉŰāơŁĨāıĉơĨāƹŁŉęŀāġĩęƑĩĩĠāơŁĉƠāŁŉűĊNÄ
# ǌƄĄ
# ÎōƄ
# ǌƄčǎDǎŎĄčńǄǍČŌMƄ
# ÎōƄ
# ď­Ős
# text. The quotations that occur in early authors go to show that the
# LÍNŌNŌĄƎǍńčNĄčMŌŁǍƎǌNĄÍǄǎŌNąĄŎÎŌÍLMčďDĎŎMƌǄčńƙĉũĨQĉƘāơŁŹƙĨāűŹƸāĩǁơĉűƠŰā¹ĨāŁĉƱĨāŁŉƘāƹŹƑĠāıŹƐāŉƠāơŁĉƠāơŁĩǈāƹĩƑĨāƹŉġĩšǈQęŉƑęƩšĉơĩĠāŉŰāŁŉƘāġĉǈŠāĉűĠāęĉŰāŹűšǈāƑĩĹƑĩƠāơŁĉƠāŁĨāƑĩıƑĉŉűĩĠāıƑŹŨQġŉƙęƩƙƙŉűĸāơŁĩŨāŹŰāơŁĉƠāĉęęŹƩűƠŰāƩŰāAƙŉűĸũǉĩŰāƙĉǉƘāŉŰāŁŉƘāƁƑĩıĉęĨǒāĎŎMƌǄčÍin and Han dynasties Sun TzŭÉƘāù	ƑƠāŹİā¹ĉƑøāƹĉƘāŉŰQĹĩűĩƑĉŠāƩƙĨāĉũŹűĹƙƠāũŉšŉơĉƑǈāęŹũũĉűġĩƑƘŠāđƩƠāơŁĩǈāƙĩĩŨāơŸāŁĉƱĨāơƑĩĉơĩĠQŉƠāĉƘāĈāƹŹƑŘāŹİāũǉƙơĩƑŉŹƩƘāŉũƁŹƑƠŠāĉűĠāƹĩƑĨāƩűƹŉššŉűĸāơŸāĩǁƁŹƩűĠāŉƠāıŹƐQơŁĨāđĩűĩıŉƠāŹİāƁŹƙơĩƑŉơǈŰā¡ŁƩƘāŉƠāęĉũĨāĉđŹƩƠāơŁĉƠā¹ĩňā¹ƨāƹĉƘāơŁĨāıŉƑƙƠQơŸāƹƑŉơĨāĈāęŹũũĩűơĉƑǈāŹŰāŉƠŰPPQ	ƘāƹĨāŁĉƱĨāĉšƑĩĉġǈāƙĩĩŰŠāơŁĩƑĨāŉƘāűŸāƑĩĉƙŹűĉđšĨāĹƑŹƩűĠāơŸāƙƩƁƁŹƙĨāơŁĉƠQ¡ƚLMǄ	ÎōƌǄČMŎŎŌĄǍNččńČŏąŎĄčńČŏĄ
# Đang and Sung dynasties, that
# it would be surprising if numerous corruptions had not managed to creep
# in. Towards the middle of the Sung period, by which time all the chief
# commentaries on Sun Tzŭ were in existence, a certain Chi TÉŉĩŰũƁĉŸQƁƩđšŉƙŁĩĠāĈāƹŹƑŘāŉŰĀƈƨāùęŁƩĉűøāĩűơŉơšĩĠĀđƩŰā¡ǕŨāƹŉơŀāơŁĨāęŹššĩęơĩĠQęŹũũĩűơĉƑŉĩƘāŹİāơĩŰāƹƑŉơĩƑƘŰĐā¡ŁĩƑĨāƹĉƘāĉűŹơŁĩƐāơĩǁƠŠāƹŉơŀāƱĉƑŉĉűƠQƑĩĉġŉűĹƘāƁƩƠāıŹƑƹĉƑĠāđǈāŁƨā1ƨāŹİā¡ĈũŁƙŉűĸŠāƹŁŉęŀāĉšƙŸāŁĉĠāƙƩƁƁŹƑơĩƑƘQĉũŹűĸāơŁĨāƙęŁŹšĉƑƘāŹİāơŁĉƠāƁĩƑŉŹĠǘāđƩƠāŉŰāơŁĨāiŉűĸāĩġŉơŉŹűƘŠāƩŰQAƙŉűĸũǉĩŰāơĩššƘāƩƘŠāơŁĩƙĨāƑĩĉġŉűĹƘāƹĩƑĨāıŹƐāƙŹũĨāƑĩĉƙŹŰāŹƐāŹơŁĩƐāűŸQšŹűĹĩƐāƁƩƠāŉűơŸāęŉƑęƩšĉơŉŹŰŰā¡ŁƩƘŠāƩűơŉŠāơŁĨāĩűĠāŹİāơŁĨĀƈǁơŀāęĩűơƩƑǈŠQơŁĨāơĩǁƠāŉŰāƙŹšĨāƁŹƙƙĩƙƙŉŹŰāŹİāơŁĨāıŉĩšĠāƹĉƘāŹűĨāġĩƑŉƱĩĠāıƑŹŨāŁňQ¢MLōƅŎMǐs edition, although no actual copy of that important work was
# known to have survived. That, therefore, is the text of Sun Tzŭ which
# appears in the War section of the great Imperial encyclopedia printed
# ǎńMƌÍin dynasties"ŏąĄǍNčÍčLǍĄƌNLNčMǍƎÅĄDNĄ
# [1758]. And the Chinese printed in Capt. CalthropÉƘāıŉƑƙƠāĩġŉơŉŹŰāŉƘQĩƱŉġĩűơšǈāĈāƙŉũŉšĉƐāƱĩƑƙŉŹŰāƹŁŉęŀāŁĉƘāıŉšơĩƑĩĠāơŁƑŹƩĹŀāQĉƁĉűĩƙĨQęŁĉűűĩšƘŰāŸāơŁŉűĹƘāƑĩũĉŉűĩĠāƩűơŉŠāƩŰāAƙŉűĸũǉĩŰāØƈƸƨƐŨƈǀƈǁèŠāĈQġŉƙơŉűĹƩŉƙŁĩĠāĉűơŉƉƩĉƑŉĉŰāĉűĠāęšĉƙƙŉęĉŠāƙęŁŹšĉƐŠāƹŁŸāęšĉŉũĩĠāơŸāđĨāĉŰQĉęơƩĉŠāġĩƙęĩűġĉűƠāŹİāƩŰā¹ƨŠāØƘƱèāĉęęŉġĩűơĉššǈāġŉƙęŹƱĩƑĩĠāĈāęŹƁǈāŹİāŁňQ¢MLōƅŎMǐs long-lost work, when on a visit to the library of the
# Hua-yin temple. [37] Appended to it was the _I Shuo_ of Cheng Yu-Hsien,
# ǌƄMƎÄÍČMMńčǄÌŎĄŌƍǎŁŎÄčńČŏĄšƙŸāđĩšŉĩƱĩĠāơŸāŁĉƱĨāƁĩƑŉƙŁĩĠŰā¡ŁŉƘQŉƘāƹŁĉƠāƩŰāAƙŉűĸũǉĩŰāġĩƙŉĹűĉơĩƘāĉƘāơŁĨĀđŹƑŉĹŉűĉŠāĩġŉơŉŹŰĀŁŹƐāơĩǁƠňĒČANčŎ
# ÎōƄ
# DĎÄNÎčMƌńŎNďEÍ
# Đien-pao was a
# careless compiler, and appears to have been content to reproduce the
# somewhat debased version current in his day, without troubling to
# collate it with the earliest editions then available. Fortunately, two
# versions of Sun Tzŭ, even older than the newly discovered work, were
# MƄčńǊĐai PÉŉűĸāÉƨQaĉűøāĩűęǉęšŹƁĩġŉĈŰāIŰāđŹơŀāơŁĨāęŹũƁšĩơĨāơĩǁƠāŉƘāơŸāđĨāıŹƩűĠŠāơŁŹƩĹŀQƙƁšŉƠāƩƀāŉűơŸāıƑĉĹũĩűơƘŠāŉűơĩƑũŉǁĩĠāƹŉơŀāŹơŁĩƐāũĉơơĩƐŠāĉűĠāƙęĉơơĩƑĩĠQƁŉĩęĩũĩĉŠāŹƱĩƐāĈāűƩũđĩƐāŹİāġŉııĩƑĩűƠāƙĩęơŉŹűƘŰāŹűƙŉġĩƑŉűĸāơŁĉƠāơŁĨāùÉƨQaĉűøāơĉřĩƘāƩƘāđĉęŘāơŸāơŁĨāǉĩĉƐĀǈǀƘŠāĉűĠāơŁĨāù¢NōƌǄ
# ǌƄčńLǎŎĄLŌNÄƎŎčŎÎčMčąĄčǄčń
# Đang dynasty, the value of
# these early transcripts of Sun Tzŭ can hardly be overestimated. Yet the
# idea of utilizing them does not seem to have occurred to anyone until
# Sun Hsing-yen, acting under Government instructions, undertook a
# NōƌŌĄčNĄŌĄMƌĄÍǎŌÎČŌĄčǎŌǍ is his own account: PQĩęĉƩƙĨāŹİāơŁĨāűƩũĩƑŹƩƘāũŉƙơĉřĩƘāŉŰāơŁĨāơĩǁƠāŹİāƩŰā¡ǕŨāƹŁŉęŀāŁŉƘQĩġŉơŹƑƘāŁĉĠāŁĉűġĩĠāġŹƹŰŠāơŁĨā9ŹƱĩƑűũĩűƠāŹƑġĩƑĩĠāơŁĉƠāơŁĨāĉűęŉĩűƠQĩġŉơŉŹŰāÙŹİāŁňā¢MLōƅŎMǋńÍ
# ǎń	ƍLōƅōŅĄčŁǍǎƌŎƍǎ
# ǌƄčńČŏĄďDŌōƄČǍǍÄƍǎōMčNČND
# ÎōƄ
# ď­ńMǎčǄ
# ÎōƄ	ÍMƌǅŏLōƐs commission, but we are
# left in doubt as to the work they really accomplished. At any rate, the
# new edition, when ultimately produced, appeared in the names of Sun
# Hsing-yen and only one co-editor Wu Jen-shi. They took the "original
# edition" as their basis, and by careful comparison with older versions,
# as well as the extant commentaries and other sources of information
# such as the _I Shuo_, succeeded in restoring a very large number of
# doubtful passages, and turned out, on the whole, what must be accepted
# NĎÄƌNƍǎŎƄČōƌÌńƌÍNÌńƌNÍĄÎōōōMƌǄŎver likely to get to Sun TzŭÉƘQŹƑŉĹŉűĉŠāƹŹƑŘŰā¡ŁŉƘāŉƘāƹŁĉƠāƹŉšŠāŁĩƑĩĉıơĩƐāđĨāġĩűŹũŉűĉơĩĠāơŁĨĀđƙơĉűġĉƑĠQơĩǁƠŰĐPQ¡ŁĨāęŹƁǈāƹŁŉęŀāHāŁĉƱĨāƩƙĩĠāđĩšŹűĹƘāơŸāĈāƑĩŉƙƙƩĨāġĉơĩĠĀƈǀƸƸŰāIƠāŉƘāŉŰĀưQùƁĩűøŠāıŹƑũŉűĸāƁĉƑƠāŹİāĈāƹĩšŠũƁƑŉűơĩĠāƙĩƠāŹİĀƐƘāĩĉƑšǈāƁŁŉšŹƙŹƁŁŉęĉŠQƹŹƑřƘāŉŰĀǀƘāùƁĩűøŰāØƘǁèāIƠāŹƁĩűƘāƹŉơŀāĈāƁƑĩıĉęĨāđǈāƩŰāAƙŉűĸũǉĩŰPŁšĉƑĹĩšǈāƉƩŹơĩĠāŉŰāơŁŉƘāŉűơƑŹġƩęơŉŹŰňŠāƱŉűġŉęĉơŉűĸāơŁĨāơƑĉġŉơŉŹűĉŠāƱŉĩƸQŹİāƩŰā¡ǕŪNÄ
# NÄƍǍččǎǌŌĄD
# ĎÐao
# KungÉƘāƁƑĩıĉęĨāơŸāŁŉƘāĩġŉơŉŹŰŠāĉűĠāơŁĨāđŉŹĹƑĉƁŁǈāŹİāƩŰā¡ǕŨāıƑŹŨāơŁĨQùŁŉŀāŁŉøŠāđŹơŀāơƑĉűƙšĉơĩĠāĉđŹƱĨŰā¡ŁĩŰāęŹũĨŠāıŉƑƙơšǈŠāŁĩűĸāÉƨũŁƙŉĩŲNÁǉD
# ǎs preface, and next, a short miscellany of
# historical and bibliographical information entitled _Sun Tzŭ Hsu Lu_,
# compiled by Pi I-hsun. As regards the body of the work, each separate
# sentence is followed by a note on the text, if required, and then by
# the various commentaries appertaining to it, arranged in chronological
# order. These we shall now proceed to discuss briefly, one by one.
#
#
#
# The Commentators
#
# Sun Tzŭ can boast an exceptionally long distinguished roll of
# commentators, which would do honour to any classic. Ou-yang Hsiu remarks
# on this fact, though he wrote before the tale was complete, and rather
# ingeniously explains it by saying that the artifices of war, being
# inexhaustible, must therefore be susceptible of treatment in a great
# variety of ways.
#
# ǎ TSÉ	xā¡HIǄ
# ĎÐao Kung, afterwards known as Wei Wu Ti [A.D.
# 155-220]. There is hardly any room for doubt that the earliest
# commentary on Sun Tzŭ actually came from the pen of this extraordinary
# man, whose biography in the _San Kuo Chih_ reads like a romance. One of
# the greatest military geniuses that the world has seen, and Napoleonic
# in the scale of his operations, he was especially famed for the
# marvelous rapidity of his marches, which has found expression in the
# line "Talk of TsÉĉŸā¡ƚLMǅĄMƌĄ
# ĎÐao TsÉĉŸāƹŉšŠāĉƁƁĩĉƐŰĐāyƨũǉĉűĸāAƙŉƨQƙĉǉƘāŹİāŁŉŨāơŁĉƠāŁĨāƹĉƘāĈāĹƑĩĉƠāęĉƁơĉŉŰāƹŁŸĀđũĩĉƙƩƑĩĠāŁŉƘāƙơƑĩűĹơŀQĉĹĉŉűƙƠā¡ƩűĸāŁŸŠāaƨāƨāĉűĠāơŁĨāơƹŸāÉƩĉŰŠāıĉơŁĩƐāĉűĠāƙŹŰŠāĉűĠQƱĉűƉƩŉƙŁĩĠāơŁĩŨāĉšŠǘāƹŁĩƑĩƩƁŹŰāŁĨāġŉƱŉġĩĠāơŁĨā)ũƁŉƑĨāŹİāAĉŰāƹŉơŀā¹ƨāĉűĠQŁƨŠāĉűĠāũĉġĨāŁŉũƙĩšİāřŉűĸŰāIƠāŉƘāƑĩęŹƑġĩĠāơŁĉƠāƹŁĩűĩƱĩƐāĈāęŹƩűęŉŠāŹİQƹĉƐāƹĉƘāŁĩšĠāđǈā¹ĩňāŹŰāơŁĨāĩƱĨāŹİāĈāıĉƐũƑĩĉęŁŉűĸāęĉũƁĉŉĹŰŠāŁĨāŁĉĠāĉšŠQŁŉƘāęĉšęƩšĉơŉŹűƘāƑĩĉġǈǘāơŁŹƙĨāĹĩűĩƑĉšƘāƹŁŸāũĉġĨāƩƙĨāŹİāơŁĩŨāġŉĠāűŹƠQšŹƙĨāŹűĨāđĉơơšĨāŉŰāơĩŰǘāơŁŹƙĨāƹŁŸāƑĉŰāęŹƩűơĩƐāơŸāơŁĩŨāŉŰāĉűǈāƁĉƑơŉęƩšĉƐQƙĉƸāơŁĩŉƐāĉƑũŉĩƘāŉűęŹűơŉűĩűơšǈāđĩĉơĩŰāĉűĠāƁƩƠāơŸāıšŉĹŁƠŰĐā¡ƚLMǄ	Îōƌǐs
# notes on Sun Tzŭ, models of austere brevity, are so thoroughly
# characteristic of the stern commander known to history, that it is hard
# indeed to conceive of them as the work of a mere _littérateur_.
# Sometimes, indeed, owing to extreme compression, they are scarcely
# intelligible and stand no less in need of a commentary than the text
# itself. [40]
#
# 2. MENG SHIH. The commentary which has come down to us under this name
# is comparatively meager, and nothing about the author is known. Even
# ŁNŌNÄNÄ	ŌōƌǄng-wu also assigns him to the TÉĉűĸQġǉűĉƙơǈŠāØƠƉèāđƩƠāơŁŉƘāŉƘāĈāũŉƙơĉřĨŰāIŰāƩŰāAƙŉűĸũǉĩŲNÄŌƌLÌŅĄ
# MńǍNč	ŌōƌǄ	Ðang of the 3rd century. He is named in one
# work as the last of the "Five Commentators," the others being Wei Wu
# MƄÍǍƎÎČMƎĄŎÌńčǎǍƄčǄčńŎÌōƎāČOEƄŎāBJňIƄ
# čńǊĐung Chih_ mentions "Lives of famous generals from the Chou
# to the TÉĉűĸāġǉűĉƙơǈĐāĉƘāƹƑŉơơĩŰāđǈāŁŉŨŰāØƠƑèā	ęęŹƑġŉűĸāơŸāłLMǁÎōƌǅŎǎńMƌĄčńǊĐien-i-ko_ catalogue, he followed a variant of the
# text of Sun Tzŭ which differs considerably from those now extant. His
# notes are mostly short and to the point, and he frequently illustrates
# his remarks by anecdotes from Chinese history.
#
# 4. TU YU (died 812) did not publish a separate commentary on Sun Tzŭ,
# his notes being taken from the _TÉƩűĸā¡ŉĩűøŠāơŁĨāĩűęǉęšŹƁĩġŉĘāơƑĩĉơŉƙĨQŹŰāơŁĨāŹűƙơŉơƩơŉŹŰāƹŁŉęŀāƹĉƘāŁŉƘāšŉıĨũƹŹƑŘŰā¡ŁĩǈāĉƑĨāšĉƑĹĩšǈQƑĩƁĩơŉơŉŹűƘāŹİā¡ƚLMǄ	ÎōƌǄMƌĄ	ŌōƌǄ
# ǌƄčńMƌÍLōƎĄÍǍōŌōƎČNLŎÄ
# ǌƄǊĐung Tien_, he has to explain eachƎĄ
# passage on its merits, apart from the context, and sometimes his own
# NÄǎMƌĎÍǍƄ does not agree with that of TsÉĉŸāYƩűĸŠāƹŁŹŨāŁĨāĉšƹĉǉƘQƉƩŹơĩƘāıŉƑƙƠŰā¡ŁŹƩĹŀāűŹƠāƙơƑŉęơšǈāơŸāđĨāƑĩęřŹűĩĠāĉƘāŹűĨāŹİāơŁĨĀđ¡ĩŰQŹũũĩűơĉơŹƑƘŠĐāŁĨāƹĉƘāĉġġĩĠāơŸāơŁĩŉƐāűƩũđĩƐāđǈāŁňā¢MLōƅŎMǅĄōMƌǁǎǍƌǍďD
# Ďń	ŎŅƁŅƄ
# ǌŎĐa bright starÎĄ
# LĄōČNÌŌĄÍMƌÌńńƎŎčŎČŌÍČNŌĄčNĄMčĄčńŹơĩƘŠāơŁĩƑĩıŹƑĨŠāĉƑĨāƹĩšŠāƹŹƑơŀāĉơơĩűơŉŹŰŰā¡ŁĩǈāĉƑĨāƱĩƑǈāęŹƁŉŹƩƘŠāĉűĠQƑĩƁšĩơĨāƹŉơŀāŁŉƙơŹƑŉęĉŠāƁĉƑĉššĩšƘŰā¡ŁĨāĹŉƙƠāŹİāƩŰā¡ǕŪNÄǍǎÄ
# ÎōƄ
# ď­Ős death would, upon examination,
# be found to uphold and corroborate, in every particular, the maxims
# NÄMĎŌLďDŌōƄÍǍƎÍLČŎŌĄōĎÌŎǍŎŅƁƅÉEN HAO appears to have been a contemporary of Tu Mu. ChÉĉŸQYƩűĸũƹƨāƙĉǉƘāơŁĉƠāŁĨāƹĉƘāŉũƁĩššĩĠāơŸāƹƑŉơĨāĈāűĩƸāęŹũũĩűơĉƑǈāŹŰāƩŰā¡ǕŨQđĩęĉƩƙĨā¡ƚLMǄ	Îōƌǐs on the one hand was too obscure and subtle, and
# that of Tu Mu on the other too long-winded and diffuse. Ou-yang Hsiu,
# ǍƄƄÍǍōŌōƎČNčǎÄiddle of the 11th century, calls TsÉĉŸāYƩűĸŠā¡ƨāiƨāĉűĠQłLōƄ	MǄčńčŌńÍ
# ÎōƄ
# ǍƄÍǍōŌōƎČNDÍen Hao is continually attacking Tu MuÉƘāƙŁŹƑơęŹũŉűĹƘŰāAŉƘQęŹũũĩűơĉƑǈŠāơŁŹƩĹŀāűŹƠāšĉęřŉűĸāŉŰāũĩƑŉƠŠāũƩƙƠāƑĉűŘāđĩšŹƸāơŁŹƙĨāŹİāŁŉƘQƁƑĩġĩęĩƙƙŹƑƘŰPPƸŰāAāaIpāŉƘāřűŹƹŰāơŸāŁĉƱĨāšŉƱĩĠāƩűġĩƐāơŁĨā¢LMƌǄďMƌNÎďEĄƍǎ
# ÎōƄ
# MƄčńǊĐang Shu_ and was
# afterwards republished by Chi Hsieh of the same dynasty together with
# those of Meng Shih and Tu Yu. It is of somewhat scanty texture, and in
# point of quality, too, perhaps the least valuable of the eleven.
#
# ōNÎŌLĄYAO-CHÉ)pĀŀƈƀƀƐŨƈƀưƀňŠāęŹũũŹűšǈāřűŹƹŰāđǈāŁŉƘĀđƙơǉšĨĐāĉƘāiĩňQŁĩűĸũǉƨŠāƹĉƘŠāšŉřĨā¡ƨāiƨŠāĈāƁŹĩƠāŹİāġŉƙơŉűęơŉŹŰŰāAŉƘāęŹũũĩűơĉƑǈāƹĉƘQƁƩđšŉƙŁĩĠāƹŉơŀāĈāšĉƩġĉơŹƑǈāƁƑĩıĉęĨāđǈāơŁĨāĹƑĩĉƠāyƨũǉĉűĸāAƙŉƨŠāıƑŹŨQƹŁŉęŀāƹĨāũĉǈāęƩšŠāơŁĨāıŹššŹƹŉűĸǒāČNČŎÌÍ
# ÎōƄ
# ǍƌŅŎÍLČŌĄƍLŎǎÅƄMƌǄčǁŌMÌńčōńÎNŌNńǍNččōN
# NƌńǎƌŌĄŎNŌMĄčǄčŁČNÍÅƄ	ŏDƎLōƌĄ
# ōNÎČMÌŅƄ	MƁNĎČōŎčMƌǄčǄǎƍLČńDÎNčLÌMĄÍǍōŌōƎČNDƍǎ
# ÎōƄ
# ď­Ős work, he does
# not lose sight of the fact that these sayings were intended for states
# engaged in internecine warfare; that the author is not concerned with
# the military conditions prevailing under the sovereigns of the three
# ancient dynasties, [43] nor with the nine punitive measures prescribed
# to the Minister of War. [44] Again, Sun Wu loved brevity of diction,
# but his meaning is always deep. Whether the subject be marching an
# army, or handling soldiers, or estimating the enemy, or controlling the
# forces of victory, it is always systematically treated; the sayings are
# bound together in strict logical sequence, though this has been
# obscured by commentators who have probably failed to grasp their
# meaning. In his own commentary, Mei Sheng-yu has brushed aside all the
# obstinate prejudices of these critics, and has tried to bring out the
# true meaning of Sun Tzŭ himself. In this way, the clouds of confusion
# have been dispersed and the sayings made clear. I am convinced that the
# present work deserves to be handed down side by side with the three
# great commentaries; and for a great deal that they find in the sayings,
# coming generations will have constant reason to thank my friend
# Sheng-yu.
#
#
# Making some allowance for the exuberance of friendship, I am inclined
# to endorse this favourable judgment, and would certainly place him above
# ǌƄƁÍǍōŌōƎČNDǍNččNĄōLČŅƄ	ńŰā¹	q8āAHŠāĉšƙŸāŹİāơŁĨāƩűĸāġǉűĉƙơǈŠāŉƘāġĩęŉġĩġšǈāŹƑŉĹŉűĉŠāŉŰāƙŹũĨāŹİQŁŉƘāŉűơĩƑƁƑĩơĉơŉŹűƘŠāđƩƠāũƩęŀāšĩƙƘāőƩġŉęŉŹƩƘāơŁĉŰāiĩňāÉĉŸũęłLōƅĄMƌĄ
# ĎÐao Kung, but the comparison is not often
# ǄANÄ	ŌNÄÍMŎÌōƎĎŎEĄŎĄrom ChÉĉŸāYƩűĸũƹƨāơŁĉƠā¹ĉűĸāAƙňāƑĩƱŉƙĩĠQơŁĨāĉűęŉĩűƠāơĩǁƠāŹİāƩŰā¡ǕŨŠāıŉššŉűĸāƩƀāšĉęƩűĉĨāĉűĠāęŹƑƑĩęơŉűĸQũŉƙơĉřĩƘŰāØƠƩèPPƈƀŰāAxāÉ)pũAHāŹİāơŁĨāƩűĸāġǉűĉƙơǈŰā¡ŁĨāƁĩƑƙŹűĉŠāűĉũĨāŹİāơŁŉƘQęŹũũĩűơĉơŹƐāŉƘāĹŉƱĩŰāĉƘāĉđŹƱĨāđǈāŁĩűĸāłMLMǄ
# MƄčńǋNń	MKǅĄMƌĄ	ŌD
# ĎŌMƅōčMƄNōǎČŎÍao Kung-wu as
# saying that his personal name is unknown. There seems to be no reason
# Íu-fei, theMƌĄčǄźNÄÎČNČōŌōƎąĄ
# author of a short treatise on war, who lived in the latter part of the
# ǎčŎÍǎŎÌŎÅƁFEIƈǄJŅƄNÎčLÄǈŠāŉŰāơŁĨāƹŹƑġƘāŹİāơŁĨāù¢MLōƅōEōÍǋǁÌNČMčǌǎŌŅĄÍǍƎČMMƎÄ
# ǌƄčNĄĄƎČNčǎƌMčNďDŎNÅĄŎĄǍLƎČŌĄǍNčLčōNLČń
# ĎÐao Kung, whose terse
# sentences he contrives to expand and develop in masterly fashion.
# MƄčńƌŌĄMƌāčŎŌƍǎńƌMĎŌōČŎÎÅƄ	 that much of TsÉĉŸāYƩűĺNÁÍǍōŌōƎČNDǍǎōČĄ
# ǌƄčMŌŅÍao Kung-wu accounts forāAĉŉøŠāđƩƠāŉƠāıŉűġƘāĈāűŉęŁĨāŉŰāơŁĨāù¢NōƌǁÍ
# it by saying: "During the early years of the Sung dynasty the Empire
# enjoyed a long spell of peace, and men ceased to practice the art of
# war. but when [Chao] Yuan-haoÉƘāƑĩđĩššŉŹŰāęĉũĨāØƈƀƘǀŨƠƑèāĉűĠāơŁĨQıƑŹűơŉĩƐāĹĩűĩƑĉšƘāƹĩƑĨāġĩıĩĉơĩĠāơŉũĨāĉıơĩƐāơŉũĨŠāơŁĨāŹƩƑƠāũĉġĨQƙơƑĩűƩŹƩƘāŉűƉƩŉƑǈāıŹƐāũĩŰāƙřŉššĩĠāŉŰāƹĉƐŠāĉűĠāũŉšŉơĉƑǈāơŹƁŉęƘāđĩęĉũĨQơŁĨāƱŹĹƩĨāĉũŹűĹƙƠāĉšŠāơŁĨāŁŉĹŀāŹııŉęŉĉšƘŰāAĩűęĨāŉƠāŉƘāơŁĉƠāơŁĨQęŹũũĩűơĉơŹƑƘāŹİāƩŰā¡ǕŨāŉŰāŹƩƐāġǉűĉƙơǈāđĩšŹűĸāũĉŉűšǈāơŸāơŁĉƠāƁĩƑŉŹĠŰQØƠƹèPQĩƙŉġĩƘāơŁĩƙĨāĩšĩƱĩŰāęŹũũĩűơĉơŹƑƘŠāơŁĩƑĨāĉƑĨāƙĩƱĩƑĉŠāŹơŁĩƑƘāƹŁŹƙĨāƹŹƑŘQŁĉƘāűŹƠāęŹũĨāġŹƹŰāơŸāƩƘŰā¡ŁĨāùƩňāŁƩøāũĩűơŉŹűƘāıŹƩƐŠāűĉũĩšǈā¹ĉűĸāaŉűĸPŁŹıơĩŰāƉƩŹơĩĠāđǈā¡ƨāÉƨāĉƘā¹ĉűĸā¡ǕŨňǘāŁĉűĸā¡ǕŨũƙŁĉűĸǘāŁŉĈāAƙƨāŹİā¹ĩňǘQØƠǁèāĉűĠāŁĩŰāÉƨāŹİā¹ƨŰā¡ŁĨāù¢LMƌǄ
# ÍŋǄLČĎÄ
# ÎōƄ	MǅĄMƌĄčńǊĐung
# ǌƄƎčMǍƌŌĄLǎƌŅƁNŌÍLNčMǍƎÄŁƩøāũĩűơŉŹűƘāĈāiŉűĸāęŹũũĩűơĉơŹƐŠāAƩĉűĸQQƩŰũǉƨŰāIƠāŉƘāƁŹƙƙŉđšĨāơŁĉƠāƙŹũĨāŹİāơŁĩƙĨāũĉǈāŁĉƱĨāđĩĩŰāũĩƑĩšǈQęŹššĩęơŹƑƘāĉűĠāĩġŉơŹƑƘāŹİāŹơŁĩƐāęŹũũĩűơĉƑŉĩƘŠāšŉřĨāŁňā¢MLōƅŎMǄMƌāÍ
# ÎōƄ
# ď­ŁÎōƄ
# MƌPs greatest men. Among the famous generals who are known to have
# studied his pages with enthusiasm may be mentioned Han Hsin (_d_. 196
# B.C.), [49] Feng I (_d_. 34 A.D.), [50] Lu Meng (_d_. 219), [51] and Yo
# NNčMǍƄčǄÍŎMĄŎÎÌONÄThe opinion of TsÉĉŸāYƩűĸŠāƹŁŸāġŉƙƁƩơĩƘāƹŉơŀāAĉŰQAƙŉŰāơŁĨāŁŉĹŁĩƙƠāƁšĉęĨāŉŰāŁŉűĩƙĨāũŉšŉơĉƑǈāĉűűĉšƘŠāŁĉƘāĉšƑĩĉġǈāđĩĩŰQƑĩęŹƑġĩĠŰāØƨƙèāơŉšŠāũŹƑĨāƑĩũĉƑřĉđšĨŠāŉŰāŹűĨāƹĉǈŠāŉƘāơŁĨāơĩƙơŉũŹűǈāŹİQƁƩƑĩšǈāšŉơĩƑĉƑǈāũĩŰŠāƙƩęŀāĉƘāƨāAƙƩŰĀŁơŁĨāıĉơŁĩƐāŹİāƨā¡ƩűĸũƂMǅEĄǍ
# ÎōƄ
# ď­ŅƄ
# NÄŎÌŎƌŌāMƄčńǋNń	MGǄÆņċŐ
#
# ǌƄčńÌMŌńÎČMŎNÄĉƠāŉŰāƹĉƐāŹűĨāęĉűűŹƠāũĉřĨāęĩƑơĉŉŰāŹİāęŹűƉƩĩƑŉűĸŠQØƨƩèāŉƘāƱĩƑǈāġŉııĩƑĩűƠāŉűġĩĩĠāıƑŹŨāƹŁĉƠāŹơŁĩƐāđŹŹřƘāơĩšŠāƩƘŰāØƨƱèā¹ƨQłMDǌNÄD
# ÎōƄ
# ǎōČNÎŌŌÍNÄÎōƄMƌĄ
# ǎŅƄŎĄ
# ǎŇǌNČōƁǌƄ	čNČŎNĎŎńÍōƌǄ	ŌōƎĎÄŉƘāƑƩšĩƘāĉƑĨāƑŹƩĹŁĩƐQĉűĠāũŹƑĨāęƑƩġĩšǈāƙơĉơĩĠŠāĉűĠāơŁĩƑĨāŉƘāűŹƠāơŁĨāƙĉũĨāƩűŉơǈāŹİāƁšĉŰāĉƘāŉŰQƩŰā¡ǕŪNÄǍǎÅĄǍŎńčńÎďMČń
#
# LÎōǎŎÄMƌĄōōMƌōƎčďDLÎčLÌMąƄąĄÍMŎŁĨāƙơĉƁšĨāĉűĠāđĉƙĨāŹİāĉšŠāũŉšŉơĉƑǈQũĩŲNÄĎMMƍMƌǅĄŎĄMĎÍǄÍǍŎōĄčń
# ǌƄ	ŌōƌÍNŎÅĄ	ÎōƄ	Ðuang and Yang Chu, all fall below the level
# of Sun Tzŭ.
#
#
# Chu Hsi, commenting on this, fully admits the first part of the
# criticism, although he dislikes the audacious comparison with the
# venerated classical works. Language of this sort, he says, "encourages
# MƄčńŎMǌĄǍōÍin was entering upon herĠāƑĩęřšĩƙƘāũŉšŉơĉƑŉƙŨŰĐPPPQ	ƁŹšŹĹŉĩƘāıŹƐā¹ĉƐPQ	ęęƩƙơŹũĩĠāĉƘāƹĨāĉƑĨāơŸāơŁŉűŘāŹİāŁŉűĈāĉƘāơŁĨāĹƑĩĉơĩƙƠāƁĩĉęĨũšŹƱŉűĸQűĉơŉŹŰāŹŰāĩĉƑơŀŠāƹĨāĉƑĨāŉŰāƙŹũĨāġĉűĹĩƐāŹİāıŹƑĹĩơơŉűĸāơŁĉƠāŁĩƐQĩǁƁĩƑŉĩűęĨāŹİāƹĉƐāŉŰāĉšŠāŉơƘāƁŁĉƙĩƘāŁĉƘāĉšƙŸāđĩĩŰāƙƩęŀāĉƘāűŸāũŹġĩƑŰQơĉơĨāęĉŰāƁĉƑĉššĩŠŰāAĩƐāšŹűĸāũŉšŉơĉƑǈāĉűűĉšƘāƙơƑĩơęŀāđĉęŘāơŸāĈāƁŹŉűƠāĉƠQƹŁŉęŀāơŁĩǈāĉƑĨāšŹƙƠāŉŰāơŁĨāũŉƙơƘāŹİāơŉũĨŰāŁĨāŁĉĠāđƩŉšƠāơŁĨā9ƑĩĉƠā¹ĉšŠQĉűĠāƹĉƘāũĉŉűơĉŉűŉűĸāĈāŁƩĹĨāƙơĉűġŉűĸāĉƑũǈāĉšŹűĸāŁĩƐāıƑŹűơŉĩƐāęĩűơƩƑŉĩƘQđĩıŹƑĨāơŁĨāıŉƑƙƠāŹũĉŰāšĩĹŉŹűĉƑǈāƹĉƘāƙĩĩŰāŹŰāơŁĨā!ĉűƩđĨŰā¹ŁĉƠāƹŉơŀāơŁĨQƁĩƑƁĩơƩĉŠāęŹššŉƙŉŹűƘāŹİāơŁĨāĉűęŉĩűƠāıĩƩġĉŠāơĉơĩƘŠāơŁĨāĹƑŉŨāęŹűıšŉęơƘQƹŉơŀāAƩűƘŠā¡ƩƑřƘāĉűĠāŹơŁĩƐāŉűƱĉġĩƑƘāĉıơĩƐāơŁĨāęĩűơƑĉšŉǑĉơŉŹŰāŹİQĹŹƱĩƑűũĩűƠŠāơŁĨāơĩƑƑŉıŉĘāƩƁŁĩĉƱĉšƘāƹŁŉęŀāĉęęŹũƁĉűŉĩĠāơŁĨāŹƱĩƑơŁƑŹƸāŹİQƙŸāũĉűǈāġǉűĉƙơŉĩƘŠāđĩƙŉġĩƘāơŁĨāęŹƩűơšĩƙƘāƑĩđĩššŉŹűƘāĉűĠāũŉűŹƐQġŉƙơƩƑđĉűęĩƘāơŁĉƠāŁĉƱĨāıšĉũĩĠāƩƀāĉűĠāıšŉęřĩƑĩĠāŹƩƠāĉĹĉŉŰāŹűĨāđǈāŹűĨŠāŉƠQŉƘāŁĉƑġšǈāơŹŸāũƩęŀāơŸāƙĉǈāơŁĉƠāơŁĨāęšĉƙŀāŹİāĉƑũƘāŁĉƘāűĩƱĩƐāęĩĉƙĩĠāơŸQƑĩƙŹƩűĠāŉŰāŹűĨāƁŹƑơŉŹŰāŹƐāĉűŹơŁĩƐāŹİāơŁĨā)ũƁŉƑĨŰPQqŸāšĩƙƘāƑĩũĉƑřĉđšĨāŉƘāơŁĨāƙƩęęĩƙƙŉŹŰāŹİāŉššƩƙơƑŉŹƩƘāęĉƁơĉŉűƘāơŸāƹŁŹŨQŁŉűĈāęĉŰāƁŹŉűƠāƹŉơŀāƁƑŉġĨŰā	ƘāŉŰāĉšŠāęŹƩűơƑŉĩƘŠāơŁĨāĹƑĩĉơĩƙƠāĉƑĨāıŹűĠQŹİāĩũĩƑĹŉűĸāĉƠāơŁĨāũŹƙƠāıĉơĩıƩŠāęƑŉƙĩƘāŹİāŁĩƐāŁŉƙơŹƑǈŰā¡ŁƩƘŠāŸāłMAÎČMƌĎÄ
# final struggle with the remaining independent states. The stormy years
# which followed the break-up of the ChÉŉŰāġǉűĉƙơǈāĉƑĨāŉššƩũŉűĉơĩĠāđǈāơŁĨQơƑĉűƙęĩűġĩűƠāĹĩűŉƩƘāŹİāAĉŰāAƙŉŰŰā¹ŁĩŰāơŁĨāAŹƩƙĨāŹİāAĉŰāŉŰāơƩƑŰāŉƘQơŹơơĩƑŉűĸāơŸāŉơƘāıĉšŠŠāơŁĨāĹƑĩĉƠāĉűĠāđĉšĩıƩŠāıŉĹƩƑĨāŹİā¡ƚLMǄ
# ĎÐao
# dominates the scene. And in the establishment of the TÉĉűĸāġǉűĉƙơǈŠāŹűĨQŹİāơŁĨāũŉĹŁơŉĩƙƠāơĉƙřƘāĉęŁŉĩƱĩĠāđǈāũĉŰŠāơŁĨāƙƩƁĩƑŁƩũĉŰāĩűĩƑĹǈāŹİāaňQŁŉŀũũŉŰĀŁĉıơĩƑƹĉƑġƘāơŁĨā)ũƁĩƑŹƐā¢LMD
# MƌŎÌńÌōƎčMŌōƎąĄƎǍń	ČMǄǎŌNČŎÎĄNČŌǏD
# ōČąƄƍLŎǄƍǎčĄMƌĄĎMƎÍČNČńDƌŎǄNÎÌLǌŎÄ
# čńƍǍččǎǍMƌǅĄD
# ÎÎŅōŌÍien, shows that for all his
# ardent admiration of Confucius, he was yet no advocate of peace at any
# price: PQiŉšŉơĉƑǈāƹĩĉƁŹűƘāĉƑĨāơŁĨāũĩĉűƘāƩƙĩĠāđǈāơŁĨāĉĹĨāơŸāƁƩűŉƙŀāƱŉŹšĩűęĨāĉűĠQęƑƩĩšơǈŠāơŸāĹŉƱĨāƁĩĉęĨāơŸāơƑŹƩđšŹƩƘāơŉũĩƘŠāơŸāƑĩũŹƱĨāġŉııŉęƩšơŉĩƘāĉűĠQġĉűĹĩƑƘŠāĉűĠāơŸāƙƩęęŹƩƐāơŁŹƙĨāƹŁŸāĉƑĨāŉŰāƁĩƑŉŠŰā)ƱĩƑǈāĉűŉũĉŠāƹŉơŀāđšŹŹĠQŉŰāŉơƘāƱĩŉűƘāĉűĠāŁŹƑűƘāŹŰāŉơƘāŁĩĉĠāƹŉšŠāıŉĹŁƠāƹŁĩŰāŉƠāŉƘāĉơơĉęřĩĠŰāAŹƸQũƩęŀāũŹƑĨāƙŸāƹŉšŠāũĉŰŠāƹŁŸāęĉƑƑŉĩƘāŉŰāŁŉƘāđƑĩĉƙƠāơŁĨāıĉęƩšơŉĩƘāŹİāšŹƱĨQĉűĠāŁĉơƑĩĠŠāőŹǈāĉűĠāĉűĹĩƐĈā¹ŁĩŰāŁĨāŉƘāƁšĩĉƙĩĠŠāĈāıĩĩšŉűĸāŹİāĉııĩęơŉŹŰQƙƁƑŉűĹƘāƩƀāƹŉơŁŉŰāŁŉŨǘāƹŁĩŰāĉűĹƑǈŠāŁŉƘāƁŹŉƙŹűĩĠāƙơŉűĸāŉƘāđƑŹƩĹŁƠāŉűơŸQƁšĉǈŰā¡ŁĉƠāŉƘāơŁĨāűĉơƩƑĉŠāšĉƸāƹŁŉęŀāĹŹƱĩƑűƘāŁŉƘāđĩŉűĺƅƄ
# ǍƎÇǄČNDǌŌNMČńƍǎŎōČNÄLǎŎĄƍNĎŌńMƌĄÍNƍMčONčMǍƅĄÍǍƌČōōƍMƌǄčŁŎÌń
# NƌńČMÌōƄŎƄƎŎÌńčǁōǌčLƏDčńǌƄČŎNčǎDMƌĄǌōƌŎMĄōƌƌŌŌČōŌōƎąƄLŎĄčŏD
# MƄčńÌMƍƍǎāńčNÎōƎÌŌĄǍNč
# NÄČMÌōƄƎǍńMǎŎÅƄÆŇŁčńDÍǍŌŅĄƍǍǍčNÍ
# Ďń	ŎŐs preface to his commentary on Sun
# ǌƁĎMNčǎÐthis is also work which is done by officials. The objects ofĹŹƱĩƑűũĩűƠŰāIƠāƹĉƘāơŁĨāƁƑŹıĩƙƙŉŹŰāŹİāŁƩűĸāÉƨāĉűĠāQĉŰāłMNŅĄǎččNÌÍN
# the rack and of military weapons are essentially the same. There is no
# intrinsic difference between the punishment of flogging and cutting off
# heads in war. For the lesser infractions of law, which are easily dealt
# with, only a small amount of force need be employed: hence the use of
# military weapons and wholesale decapitation. In both cases, however,
# ...
# ǌƄčńōƌōŏPs spies we learn theÍMǍƄDčNĄǌŁNńLČńčǄLÎNōNńMƌĄōŎ
# ǎńďMƌNÎďAǌNÄĎŌńčǄ	ğĄLAÉĎńŅĄčńNÌńÍƁƠāơŁĨāęŹűƱĩƑơĩĠāƙƁǈQŉűơŸāŹƩƐāƙĩƑƱŉęĨŠāđĩęĉƩƙĨāŉƠāŉƘāŁĨāơŁĉƠāřűŹƹƘāƹŁŉęŀāŹİāơŁĨāšŹęĉŠQŉűŁĉđŉơĉűơƘāĉƑĨāĹƑĩĩġǈāŹİāĹĉŉŰŠāĉűĠāƹŁŉęŀāŹİāơŁĨāŹııŉęŉĉšƘāĉƑĨāŹƁĩŰāơŸQęŹƑƑƩƁơŉŹŰŰđèPPPƐƘŰāIƠāŉƘāŹƹŉűĸāơŸāŁŉƘāŉűıŹƑũĉơŉŹŰŠāĉĹĉŉŰŠāơŁĉƠāƹĨāęĉŰāęĉƩƙĨāơŁĨāġŹŹũĩĠQƙƁǈāơŸāęĉƑƑǈāıĉšƙĨāơŉġŉűĹƘāơŸāơŁĨāĩűĩũǈŰPQÙŁĉűĸāÉƨāƙĉǉƘŠĀđđĩęĉƩƙĨāơŁĨāęŹűƱĩƑơĩĠāƙƁǈāřűŹƹƘāŁŹƸāơŁĨāĩűĩũǈāęĉŰāđĩƙƠQđĨāġĩęĩŉƱĩĠŰđèPPPƐƠŰāaĉƙơšǈŠāŉƠāŉƘāđǈāŁŉƘāŉűıŹƑũĉơŉŹŰāơŁĉƠāơŁĨāƙƩƑƱŉƱŉűĸāƙƁǈāęĉŰāđĨāƩƙĩĠQŹŰāĉƁƁŹŉűơĩĠāŹęęĉƙŉŹűƘŰPPƐƨŰā¡ŁĨāĩűĠāĉűĠāĉŉŨāŹİāƙƁǉŉűĸāŉŰāĉšŠāŉơƘāıŉƱĨāƱĉƑŉĩơŉĩƘāŉƘāřűŹƹšĩġĹĨāŹİQơŁĨāĩűĩũǈǘāĉűĠāơŁŉƘāřűŹƹšĩġĹĨāęĉŰāŹűšǈāđĨāġĩƑŉƱĩĠŠāŉŰāơŁĨāıŉƑƙƠQŉűƙơĉűęĨŠāıƑŹŨāơŁĨāęŹűƱĩƑơĩĠāƙƁǈŰPQÙ	ƘāĩǁƁšĉŉűĩĠāŉŰĂĺĸĀƐƐŨƐƠŰāAĨāűŹƠāŹűšǈāđƑŉűĹƘāŉűıŹƑũĉơŉŹŰāŁŉũƙĩšİŠāđƩƠQũĉřĩƘāŉƠāƁŹƙƙŉđšĨāơŸāƩƙĨāơŁĨāŹơŁĩƐāřŉűġƘāŹİāƙƁǈāơŸāĉġƱĉűơĉĹĨűèPPQAĩűęĨāŉƠāŉƘāĩƙƙĩűơŉĉŠāơŁĉƠāơŁĨāęŹűƱĩƑơĩĠāƙƁǈāđĨāơƑĩĉơĩĠāƹŉơŀāơŁĨāƩơũŹƙƠQšŉđĩƑĉšŉơǈŰPPƐưŰāyİāŹšĠŠāơŁĨāƑŉƙĨāŹİāơŁĨāÉŉŰāġǉűĉƙơǈPQÙƩŰā¡ǕŨāũĩĉűƘāơŁĨāŁĉűĸāġǉűĉƙơǈŠāıŹƩűġĩĠāŉŰĀƈƸưưāűŰāIơƘāűĉũĨāƹĉƘQęŁĉűĹĩĠāơŸāÉŉŰāđǈāLMƄ	ÌōƌǄ
# ǎƌŎčǎǅƄĎÄčńďNMƎÍ
# ÍƍǎǍƄNÄ
# Đai Kung, a title
# bestowed on him by Wen Wang, he is said to have composed a treatise on
# MŅƄŌĄ	ĄÍǎōČĄĄƎÎĄčǍǎƌŎƍŌōƎąƄ	ÍLAÍǎōČĄĉŹøűèPPQƹŁŸāŁĉĠāƙĩƑƱĩĠāƩűġĩƐāơŁĨāÉŉŰŰPQÙ¡ŁĩƑĨāŉƘāšĩƙƘāƁƑĩęŉƙŉŹŰāŉŰāơŁĨāŁŉűĩƙĨāơŁĉŰāHāŁĉƱĨāơŁŹƩĹŁƠāŉƠāƹĩšŠāơŸQŉűơƑŹġƩęĨāŉűơŸāũǈāơƑĉűƙšĉơŉŹŰŠāĉűĠāơŁĨāęŹũũĩűơĉƑŉĩƘāŹŰāơŁĨāƁĉƙƙĉĹĨāĉƑĨQđǈāűŸāũĩĉűƘāĩǁƁšŉęŉƠŰāƩƠŠāŁĉƱŉűĸāƑĩĹĉƑĠāơŸāơŁĨāęŹűơĩǁƠŠāƹĨāęĉŰāŁĉƑġšǈQġŹƩđƠāơŁĉƠāƩŰā¡ǕŨāŉƘāŁŹšġŉűĸāƩƀāHāŁŉŀāĉűĠāaƨāÉĈāĉƘāŉššƩƙơƑŉŹƩƘQĩǁĉũƁšĩƘāŹİāơŁĨāęŹűƱĩƑơĩĠāƙƁǈŠāŹƐāƙŹũĩơŁŉűĸāęšŹƙĩšǈāĉűĉšŹĹŹƩƘŰāAŉƘQƙƩĹĹĩƙơŉŹŰāŉƘŠāơŁĉƠāơŁĨāAƙŉĈāĉűĠāÉŉŰāġǉűĉƙơŉĩƘāƹĩƑĨāƩƁƙĩƠāŹƹŉűĸāơŸāơŁĨQŉűơŉũĉơĨāřűŹƹšĩġĹĨāŹİāơŁĩŉƐāƹĩĉřűĩƙƙĩƘāĉűĠāƙŁŹƑơęŹũŉűĸāƹŁŉęŀāơŁĩƙĨQıŹƑũĩƐāũŉűŉƙơĩƑƘāƹĩƑĨāĉđšĨāơŸāŉũƁĉƑƠāơŸāơŁĨāŹơŁĩƐāƙŉġĨŰāiĩňāÉĉŸũęłLōƁNŌNÄčǄŎÌōƎĄMƏDÎŌÍNÎŎÍMǍƄ
# ǄŅƄ	ńōǎǌŎńMčĄƍǎčńǍǍǌĄ
# LŎÇǄLÎČŌĄNÄÍǍōōǍƁÎ
# ÎōƄ
# ď­Ős mention of them simply means that the proper use of
# the five classes of spies is a matter which requires men of the highest
# mental caliber like I and Lu, whose wisdom and capacity qualified them
# for the task. The above words only emphasize this point." Ho Shih
# believes then that the two heroes are mentioned on account of their
# supposed skill in the use of spies. But this is very weak.]
#
#
# 27. Hence it is only the enlightened ruler and the wise general who
# will use the highest intelligence of the army for purposes of spying
# and thereby they achieve great results.
#
# [Tu Mu closes with a note of warning: "Just as water, which carries a
# boat from bank to bank, may also be the means of sinking it, so
# reliance on spies, while production of great results, is oft-times the
# cause of utter destruction."]
#
#
# Spies are a most important element in war, because on them depends an
# ƍǎĄǎČŌÎČŌĄDāńōƌMŌŌąƁÎŌNčMƌǄčńǍǎÎÄƎǍńMƎĄŌčNčMǍƎÄƘāšŉřĨāĈāũĉŰāƹŉơŁŹƩƠāĩĉƑƘāŹƐQĩǉĩƘűèPPQØƉèĀđ	ŉġƘāơŸāęŹƩơŉűĸŠĐāƀŰĀƐŰPQØƑèĀđiĉƑƙŁĉŠā¡ƩƑĩűűĨŠĐāƀŰĀƘƈƈŰPPPŐŐŐā)q āy0ā¡A(āyQ) ā9©¡)q)8ā)yyXā¡A(ā	 āy0ā¹	ĀŐŐŐPPPĀĀĀĀPQ©ƁġĉơĩĠāĩġŉơŉŹűƘāƹŉšŠāƑĩƁšĉęĨāơŁĨāƁƑĩƱŉŹƩƘāŹűĪĎčń
# ǎǍƎÄDčNĄLǍāČNǄ
# ōƍNČŌĄ
# MƄčńÌńǍǎÎÅāÍǄčƍǎōƌČNčMǍƄMƌĄMǎńEDÌMƄÍǎDMƌĄčNÎĎLŎČń
# ǎŎĄOMMƌǄÍǎNLǍāǏLMĎčLŎÅƄ
# MƄčǌōƌŎMĄÌŎĄƍǎč
# ǌƄŎÄ
# ďDčǄÍǎMMƌǄMƌĄčNÎĎLŎčMƌǄ
# MƄčńLÎčLÌMčďIƋJĉ	IƈǄic works to protect the PROJECT GUTENBERGĐQęŹűęĩƁƠāĉűĠāơƑĉġĩũĉƑŘŰāƑŹőĩęƠā9ƩơĩűđĩƑĸāŉƘāĈāƑĩĹŉƙơĩƑĩĠāơƑĉġĩũĉƑŘŠQĉűĠāũĉǈāűŹƠāđĨāƩƙĩĠāŉİāǉŹƨāęŁĉƑĹĨāıŹƐāĉŰāĩŹŹŘŠāĩǁęĩƁƠāđǈāıŹššŹƹŉűĸQơŁĨāơĩƑũƘāŹİāơŁĨāơƑĉġĩũĉƑŘāšŉęĩűƙĨŠāŉűęšƩġŉűĸāƁĉǉŉűĸāƑŹǉĉšơŉĩƘāıŹƐāƩƙĨQŹİāơŁĨāƑŹőĩęƠā9ƩơĩűđĩƑĸāơƑĉġĩũĉƑŘŰāIİāǉŹƨāġŸāűŹƠāęŁĉƑĹĨāĉűǉơŁŉűĸāıŹƐQęŹƁŉĩƘāŹİāơŁŉƘāĩŹŹŘŠāęŹũƁšǉŉűĸāƹŉơŀāơŁĨāơƑĉġĩũĉƑŘāšŉęĩűƙĨāŉƘāƱĩƑǈQĩĉƙǈŰāÉŹƨāũĉǈāƩƙĨāơŁŉƘāĩŹŹŘāıŹƐāűĩĉƑšǈāĉűǈāƁƩƑƁŹƙĨāƙƩęŀāĉƘāęƑĩĉơŉŹŰQŹİāġĩƑŉƱĉơŉƱĨāƹŹƑřƘŠāƑĩƁŹƑơƘŠāƁĩƑıŹƑũĉűęĩƘāĉűĠāƑĩƙĩĉƑęŀŰāƑŹőĩęƠQ9ƩơĩűđĩƑĸāĩŹŹřƘāũĉǈāđĨāũŹġŉıŉĩĠāĉűĠāƁƑŉűơĩĠāĉűĠāĹŉƱĩŰāĉƹĉǊďMǎń
# ōƍNČŌĄ
# ƍǎĄǎČŌÎČŌāDÎÄ
# ČNǅƄÍǎNLǍĄ
# NÄÎŌŌÎĄčǄčńĎLČōŌNÁčLÌōƎÌŅĄŎÎŌÍLMčďDÍǍōŌŎÍLMĄŌčNÎĎLŎčMǍƅƁÊĈJćƊŉĉĄ	ĉHÈŉƊÈŁƊŉĉĄ
#
# ǉňÊǊŊĈŉƈŊǄ	ĉHÈŉƊÈŁ	ĈňJÈń
# ňHĄ
# ĉ	JňƉǊńIǊĉJÊĊHŊĈń	Ǌ
# ŊÈń
# ĉ	JÄ
# ǉǊÁčǄǎČŌÎĄčń
# ǍŌÎǎŎČōƌŎǐĢ mission of promoting the free
# distribution of electronic works, by using or distributing this work
# ǌƄčƎōčāǍŌÎǎŎČōƌŎǐĢ License available with this file or online atŅEĄMǎńLǎŌńčǄÍǍŎ
# www.gutenberg.org/license.
#
# ǌƄÄČŎÎĎǏDMčĄÍǎMƌĄŎĎŎƄńČŎŎÄNLǍąDLǎŌōŌōƎąƄ	LƄMǎńčǄbergĐQĩšĩęơƑŹűŉĘāƹŹƑřƘPPƈŰāǈāƑĩĉġŉűĸāŹƐāƩƙŉűĸāĉűǈāƁĉƑƠāŹİāơŁŉƘāƑŹőĩęƠā9ƩơĩűđĩƑĺ$ōČŌÎĎǍƍLÄǍǎÅĄMǎń
# ǍŌÎǎŎČōƌŎǐĢ electronic works in your
# possession. If you paid a fee for obtaining a copy of or access to a
# Project GutenbergĐāĩšĩęơƑŹűŉĘāƹŹƑŘāĉűĠāǉŹƨāġŸāűŹƠāĉĹƑĩĨāơŸāđĨāđŹƩűĠQđǈāơŁĨāơĩƑũƘāŹİāơŁŉƘāĉĹƑĩĩũĩűƠŠāǉŹƨāũĉǈāŹđơĉŉŰāĈāƑĩıƩűĠāıƑŹŨāơŁĨāƁĩƑƙŹŰQŹƐāĩűơŉơǈāơŸāƹŁŹŨāǉŹƨāƁĉŉĠāơŁĨāıĩĨāĉƘāƙĩƠāıŹƑơŀāŉŰāƁĉƑĉĹƑĉƁŀĀƈű(ŰǀŰPPƈűŰĂĊǍŌÎǎŎČōƌŎǐ is a registered trademark. It may only be
# used on or associated in any way with an electronic work by people who
# agree to be bound by the terms of this agreement. There are a few
# ōĎŎÌŎƌńƎŌńƎŎĎŎńLÌÌŎÎÄčǄoject GutenbergĐāĩšĩęơƑŹűŉĘāƹŹƑřƘQĩƱĩŰāƹŉơŁŹƩƠāęŹũƁšǉŉűĸāƹŉơŀāơŁĨāıƩšŠāơĩƑũƘāŹİāơŁŉƘāĉĹƑĩĩũĩűƠŰāĩĨQƁĉƑĉĹƑĉƁŀĀƈűāđĩšŹƸŰā¡ŁĩƑĨāĉƑĨāĈāšŹƠāŹİāơŁŉűĹƘāǉŹƨāęĉŰāġŸāƹŉơŀāƑŹőĩęƠQ9ƩơĩűđĩƑĺ$ōČŌÎĎǍƍLÄǍǎÎÄ
# ǍŌÎǎŎČōƌŎǐĢ
# electronic works. See paragraph 1.E below.
#
# ǎC. The Project Gutenberg Literary Archive Foundation (áơŁĨQ1ŹƩűġĉơŉŹŲń
# MƄčńÍǍčČŌÎčMǍƁǌƄ
# ǍŌÎǎŎČōƌŎǐĢ electronic works. Nearly all the individual
# works in the collection are in the public domain in the United
# States. If an individual work is unprotected by copyright law in the
# United States and you are located in the United States, we do not
# claim a right to prevent you from copying, distributing, performing,
# displaying or creating derivative works based on the work as long as
# all references to Project Gutenberg are removed. Of course, we hope
# MƌǄčŁǍŌÎǎŎČōƌŎǐĢ name associated with the work. You can easilyĉęęĩƙƘāơŸāĩšĩęơƑŹűŉĘāƹŹƑřƘāđǈāıƑĩĩšǈāƙŁĉƑŉűĸāƑŹőĩęƠā9ƩơĩűđĩƑĺ$ǍǎÎÄ
# comply with the terms of this agreement by keeping this work in the
# same format with its attached full Project GutenbergĐāaŉęĩűƙĨāƹŁĩŰQǉŹƨāƙŁĉƑĨāŉƠāƹŉơŁŹƩƠāęŁĉƑĹĨāƹŉơŀāŹơŁĩƑƘŰPPƈű Űā¡ŁĨāęŹƁǉƑŉĹŁƠāšĉƹƘāŹİāơŁĨāƁšĉęĨāƹŁĩƑĨāǉŹƨāĉƑĨāšŹęĉơĩĠāĉšƙŸāĹŹƱĩƑŰQƹŁĉƠāǉŹƨāęĉŰāġŸāƹŉơŀāơŁŉƘāƹŹƑŘŰāŹƁǉƑŉĹŁƠāšĉƹƘāŉŰāũŹƙƠāęŹƩűơƑŉĩƘāĉƑĨQŉŰāĈāęŹűƙơĉűƠāƙơĉơĨāŹİāęŁĉűĹĨŰāIİāǉŹƨāĉƑĨāŹƩơƙŉġĨāơŁĨā©űŉơĩĠāơĉơĩƘŠQęŁĩęŘāơŁĨāšĉƹƘāŹİāǉŹƩƐāęŹƩűơƑǈāŉŰāĉġġŉơŉŹŰāơŸāơŁĨāơĩƑũƘāŹİāơŁŉƘQĉĹƑĩĩũĩűƠāđĩıŹƑĨāġŹƹűšŹĉġŉűĸŠāęŹƁǉŉűĸŠāġŉƙƁšĉǉŉűĸŠāƁĩƑıŹƑũŉűĸŠQġŉƙơƑŉđƩơŉűĸāŹƐāęƑĩĉơŉűĸāġĩƑŉƱĉơŉƱĨāƹŹƑřƘāđĉƙĩĠāŹŰāơŁŉƘāƹŹƑŘāŹƐāĉűǈQŹơŁĩƐāƑŹőĩęƠā9ƩơĩűđĩƑĺ$ǍǎÅƄ
# ǎčŎčMƄčńMǍƎÄÍǍƌÌŎƍMƌǄčńÍǎNLǍĄÎČNĎŎÄ
# ōƍNČŌĄ
# ÎČNČŎÅƁEƈŅƄ
# NƌńōōǎƌŌĄMčĄŌƌŎōƌÌŎÄčǄ
# ǍŌÎǎŎČōƌŎǇEƈŅƆEƄ
# ǎčŎMōŌŌčLNČńLÌÌŎÎÄčǅĄčńƎōčĄ
# ǍŌÎǎŎČōƌŎǐĢ License must appear
# prominently whenever any copy of a Project GutenbergĐāƹŹƑŘĀŁĉűǈāƹŹƑŘQŹŰāƹŁŉęŀāơŁĨāƁŁƑĉƙĨĂĊǍŌÎǎŎČōƌŎǐ appears, or with which the
# ǎčNÎĎLŎČŌćŎǌŌąĄÍǎ
# MƄčńǍƌńMƏNǍŎń
# ōƍNČŌĄ
# ǌƄčńŎčńČŎŎÁNĎÍǌŎƌŎƄMǎń
# MƄčńĄNĄǎǎǅƌǎŎČōƌŎǅƍǎǅƄ	LƄMǎŁNń
# ōƍNČŌĄ
# MƌčNƍLĎŌMĄEƈŅƆƄ	LƄMƄNń
# ǍŌÎǎŎČōƌŎǐĢ electronic work is
# derived from texts not protected by U.S. copyright law (does not
# contain a notice indicating that it is posted with permission of the
# copyright holder), the work can be copied and distributed to anyone in
# the United States without paying any fees or charges. If you are
# ǌƄčńǍǎÄMƌĄčńƄƍǎčńŎÌńss to a work with the phrase áƑŹőĩęƠQ9ƩơĩűđĩƑĺńNÎÍǌÍLNČŌĄǍNč
# ǍŌÎǎŎČōƌŎǐĢ
# trademark as set forth in paragraphs 1.E.8 or 1.E.9.
#
# ǎōōǎƌńčńƎōčĄŌǍMƍƍMƌǄect GutenbergĐāĩšĩęơƑŹűŉĘāƹŹƑŘāŉƘāƁŹƙơĩĠQƹŉơŀāơŁĨāƁĩƑũŉƙƙŉŹŰāŹİāơŁĨāęŹƁǉƑŉĹŁƠāŁŹšġĩƐŠāǉŹƩƐāƩƙĨāĉűĠāġŉƙơƑŉđƩơŉŹŰQũƩƙƠāęŹũƁšǈāƹŉơŀāđŹơŀāƁĉƑĉĹƑĉƁŁƘĀƈű(ŰƈāơŁƑŹƩĹŀĀƈű(ŰƸāĉűĠāĉűǈQĉġġŉơŉŹűĉŠāơĩƑũƘāŉũƁŹƙĩĠāđǈāơŁĨāęŹƁǉƑŉĹŁƠāŁŹšġĩƐŰā	ġġŉơŉŹűĉŠāơĩƑũƘQƹŉšŠāđĨāšŉűřĩĠāơŸāơŁĨāƑŹőĩęƠā9ƩơĩűđĩƑĺ$	čLÌōƎÌńƍǎMčĄǍǎÎÁ
# ǍŌÎǎŎČōƌŎǐĢ
# License terms from this work, or any files containing a part of this
# ǌƄDNÎĎLŎČńÍǎÌÌŎÎÁčǄÎÍMƌǄčed with Project GutenbergĐŰPPƈű(ŰƨŰā!ŸāűŹƠāęŹƁǈŠāġŉƙƁšĉǈŠāƁĩƑıŹƑŨŠāġŉƙơƑŉđƩơĨāŹƐāƑĩġŉƙơƑŉđƩơĨāơŁŉƘQĩšĩęơƑŹűŉĘāƹŹƑŘŠāŹƐāĉűǈāƁĉƑƠāŹİāơŁŉƘāĩšĩęơƑŹűŉĘāƹŹƑŘŠāƹŉơŁŹƩƠQƁƑŹũŉűĩűơšǈāġŉƙƁšĉǉŉűĸāơŁĨāƙĩűơĩűęĨāƙĩƠāıŹƑơŀāŉŰāƁĉƑĉĹƑĉƁŀĀƈű(ŰƈāƹŉơŀQĉęơŉƱĨāšŉűřƘāŹƐāŉũũĩġŉĉơĨāĉęęĩƙƘāơŸāơŁĨāıƩšŠāơĩƑũƘāŹİāơŁĨāƑŹőĩęƠQ9ƩơĩűđĩƑĺ$	čLÌōƎÌŅƁEƈŅƆƅƄMǎń
# ǍŌÎǎŎČōƌŎǐĢ work in a format
# ǌƌƍLÍLMĄƌŎÍMǍƄŰā±ĉűŉššĈā	IJń
# ǍŌÎǎŎČōƌŎǐĢ website
# (www.gutenberg.org), you must, at no additional cost, fee or expense
# to the user, provide a copy, a means of exporting a copy, or a means
# MƌÍĎŌČńčŁƎōčĄČŎƌNČńƍǎŌNĄ, of the work in its original ášĉŉŰQ±ĉűŉššĈā	IJń
# ǍŌÎǎŎČōƌŎǐĢ License as specified in paragraph 1.E.1.
#
# 1.E.7. Do not charge a fee for access to, viewing, displaying,
# performing, copying or distributing any Project GutenbergĐāƹŹƑřƘQƩűšĩƙƘāǉŹƨāęŹũƁšǈāƹŉơŀāƁĉƑĉĹƑĉƁŀĀƈű(ŰǀāŹƐĀƈű(ŰǈŰPPƈű(ŰǀŰāÉŹƨāũĉǈāęŁĉƑĹĨāĈāƑĩĉƙŹűĉđšĨāıĩĨāıŹƐāęŹƁŉĩƘāŹİāŹƐāƁƑŹƱŉġŉűĸQĉęęĩƙƘāơŸāŹƐāġŉƙơƑŉđƩơŉűĸāƑŹőĩęƠā9ƩơĩűđĩƑĺ$ōČŌÎĎǍƍLÄǍǎÎÁǎƍLČŌĄčNć" You pay a royalty fee of 20% of the gross profits you derive from
# čǄčńNLǎŌŌĄčǄčǍƌNČńǏLMĎčLŎÄōƌČŎčĉšęƩšĉơĩĠāƩƙŉűĸāơŁĨāũĩơŁŹĠPĀĀĀĀĀĀĀāǉŹƨāĉšƑĩĉġǈāƩƙĨāơŸāęĉšęƩšĉơĨāǉŹƩƐāĉƁƁšŉęĉđšĨāơĉǁĩƘŰā¡ŁĨāıĩĨāŉƘāŹƹĩĠPĀĀĀĀĀĀĀāơŸāơŁĨāŹƹűĩƐāŹİāơŁĨāƑŹőĩęƠā9ƩơĩűđĩƑĺ$ĎLČōŌNÅĄŎĄ
# NƌƍǎōƌČNčMǍƅƄŎČōƌŎǄ	čNČŎNNÍ
# ČŌǌMčďDŎNōNŌĄčǄŎNŅDMǎŎŎMǌčLÄČOŎĎŎƎÅƄ
# ŌNÌŌĄNÄÎŌÍMƌĄÌōƎĄčǄčń
# MƁǍƄNĄčńLČĎŎÎÄÎŌÍLƍLŌĄ
# ÌŌÎčMǍƄąĄInformation about donations to the Project Gutenberg
# ǌƄčńƎōčĄǄčńČŎŎÄčǌŎÄon.èPĀĀĀĀPĀĀĀĂMǎńǎƍLČńDƎōčĄŌƎōƌĄ
# ǍŌÎǎŎČōƌŎǐĢ
#         License. You must require such a user to return or destroy all
#         copies of the works possessed in a physical medium and discontinue
# ǌƄčńǍǎÅƁ" You comply with all other terms of this agreement for freeŹƑřƘŰPĀĀĀĀPĀĀĀĂMǎńǎƍLČŅĄ
# MƄǎNčMƌǁƎǍńčńčMƁNńÌŎĄƍǎčbergĐāƹŹƑřƘŰPĀĀĀĀPPƈű(ŰǈŰāIİāǉŹƨāƹŉƙŀāơŸāęŁĉƑĹĨāĈāıĩĨāŹƐāġŉƙơƑŉđƩơĨāĈāƑŹőĩęƠQ9ƩơĩűđĩƑĺ$ōČŌÎĎǍƍLÄǍǎÄ
# ǌƁčńNčMǍƅĄčńŎNNÍ
# ǍŌÎǎŎČōƌŎǐĢ trademark. Contact the Foundation as set
# forth in Section 3 below.
#
# 1.F.
#
# 1.F.1. Project Gutenberg volunteers and employees expend considerable
# effort to identify, do copyright research on, transcribe and proofread
# works not protected by U.S. copyright law in creating the Project
# ŌOAÍǍƎČMMƄDefects,èāƙƩęŀāĉƘŠāđƩƠāűŹƠāšŉũŉơĩĠāơŸŠāŉűęŹũƁšĩơĨŠāŉűĉęęƩƑĉơĨQŹƐāęŹƑƑƩƁƠāġĉơĈŠāơƑĉűƙęƑŉƁơŉŹŰāĩƑƑŹƑƘŠāĈāęŹƁǉƑŉĹŁƠāŹƐāŹơŁĩƐQŉűơĩššĩęơƩĉŠāƁƑŹƁĩƑơǈāŉűıƑŉűĹĩũĩűƠŠāĈāġĩıĩęơŉƱĨāŹƐāġĉũĉĹĩĠāġŉƙŘāŹƐQŹơŁĩƐāũĩġŉƩŨŠāĈāęŹũƁƩơĩƐāƱŉƑƩƘŠāŹƐāęŹũƁƩơĩƐāęŹġĩƘāơŁĉƠāġĉũĉĹĨāŹƐQęĉűűŹƠāđĨāƑĩĉĠāđǈāǉŹƩƐāĩƉƩŉƁũĩűƠŰPPƈű0ŰƐŰāaIiI¡) ā¹		q¡ÈŠā!Ia	Ii)āy0ā!	i	9)ĀŨā)ǁęĩƁƠāıŹƐāơŁĨĂĊLǍāǌƄ
# ǎÌōŌōƎĄ
# ŌƎōƌĐ described in paragraph 1.F.3, the Project
# Gutenberg Literary Archive Foundation, the owner of the Project
# ČŌǌMāƌŌŎÅƄIǊHǊňńńMčāčLLMčNďDčǄMǎńƍǎČMŌLǌŎÅĄÍǎÎĎÄMƌĄŏōƎÌŎÅĄōČŌÎĎǍƍLÄǍǎÄōƌČŎč
# JĄIǊńJƈń	ƉǄ
# ŉňňĉHŊƉǊ	ƈňǉĉHǈŉƈÈŅĄ
# ÊĊHÊāĉHHIĉJċEňHÉ	ǈƄ
# ǈJIƊċD	ǊňHÉ	ǈÉǉƊĊHÊÈŊ
# Ą
# ĉ	ǊÈŁ
# ǊƉHĈňĄ	IƄ
# JHǊJ	EƈƅƆÅƄIǊHǊňń
# JĄ
# ƉǊŉƈĈJĉIǉƅĄ
# ŁĊHĈŉňJÄ	ǊǉƈŊIƈIƋĉJÊĊHŊĉǊ
# ŉƈĈŊ
# ĉ	JHǊňŉňŉƊĄ
# ǉIĉĄ	ƉǊŁĉHHĈń
# ĉǄIǊƉǊHÊĊňIąĉJňÊąĄ	IƈĉJňÊąÉǉƊÈŊJňŉƊĉHIąĄ
#
# ŉƉJĉJƈń	ǊIƈÉHĈŉƊĈIĈIňHǈŊŊƈŉƄ	HƄIǊǉJƈń	ƉǊĉHÈń	ǈƄ
# ń
# 	ǊÊÉHIĉJċD	ǈƄ
# ÊňÉĈIňHǈŅƁEƈƅƆÅƄ	ĉIŉJĈňĄ
# Hǉ
# Ą	ǈƄ
# Ŋ	ĈHÈŉňŉƊĄ	Ǌ
# ČMƌNčMǍƅƄčMǎŎǎNĎČōƄŏŌÌōNƌŌĄčńǍǎÄƎǍŅƄ	LƄMǎŁŌÌōNƌŌĄčńǍǎÄ
# ǌƄLǎŌōŌōƎąĄMƌĄMƏDƍǍĎōƎČŌŎÄNÎÍǌÍLNČŌĄǍNččŁǌĎŌÎčMǍƅĄǍōǎčMǍƄMƌĄčNÎĎLŎčMǍƄ©!Iq8ā© āqy QaIiI¡) ā¡xā¹		q¡I)āy0āi)A	q¡	IaI¡Èāyā1I¡q)ā1yā	qÈā©y(ŰPPƈű0ŰƨŰāŹũĨāƙơĉơĩƘāġŸāűŹƠāĉššŹƸāġŉƙęšĉŉũĩƑƘāŹİāęĩƑơĉŉŰāŉũƁšŉĩĠQƹĉƑƑĉűơŉĩƘāŹƐāơŁĨāĩǁęšƩƙŉŹŰāŹƐāšŉũŉơĉơŉŹŰāŹİāęĩƑơĉŉŰāơǉƁĩƘāŹİQġĉũĉĹĩƘŰāIİāĉűǈāġŉƙęšĉŉũĩƐāŹƐāšŉũŉơĉơŉŹŰāƙĩƠāıŹƑơŀāŉŰāơŁŉƘāĉĹƑĩĩũĩűƠQƱŉŹšĉơĩƘāơŁĨāšĉƸāŹİāơŁĨāƙơĉơĨāĉƁƁšŉęĉđšĨāơŸāơŁŉƘāĉĹƑĩĩũĩűƠŠāơŁĨQĉĹƑĩĩũĩűƠāƙŁĉšŠāđĨāŉűơĩƑƁƑĩơĩĠāơŸāũĉřĨāơŁĨāũĉǁŉũƩŨāġŉƙęšĉŉũĩƐāŹƐQšŉũŉơĉơŉŹŰāƁĩƑũŉơơĩĠāđǈāơŁĨāĉƁƁšŉęĉđšĨāƙơĉơĨāšĉƸŰā¡ŁĨāŉűƱĉšŉġŉơǈāŹƐQƩűĩűıŹƑęĩĉđŉšŉơǈāŹİāĉűǈāƁƑŹƱŉƙŉŹŰāŹİāơŁŉƘāĉĹƑĩĩũĩűƠāƙŁĉšŠāűŹƠāƱŹŉĠāơŁĨQƑĩũĉŉűŉűĸāƁƑŹƱŉƙŉŹűƘŰPPƈű0ŰưŰāIq!)iqI¡ÈĀŨāÉŹƨāĉĹƑĩĨāơŸāŉűġĩũűŉıǈāĉűĠāŁŹšĠāơŁĨā1ŹƩűġĉơŉŹŰŠāơŁĨQơƑĉġĩũĉƑŘāŹƹűĩƐŠāĉűǈāĉĹĩűƠāŹƐāĩũƁšŹǉĩĨāŹİāơŁĨā1ŹƩűġĉơŉŹŰŠāĉűǉŹűĨQƁƑŹƱŉġŉűĸāęŹƁŉĩƘāŹİāƑŹőĩęƠā9ƩơĩűđĩƑĺ$ōČŌÎĎǍƍLÄǍǎÎÄ
# ǍŌÎǎŎČōƌŎǐĢ
# electronic works, harmless from all liability, costs and expenses,
# including legal fees, that arise directly or indirectly from any of
# the following which you do or cause to occur: (a) distribution of this
# ǌƄ any Project GutenbergĐāƹŹƑŘŠĀŁĐňāĉšơĩƑĉơŉŹŰŠāũŹġŉıŉęĉơŉŹŰŠāŹƐQĉġġŉơŉŹűƘāŹƐāġĩšĩơŉŹűƘāơŸāĉűǈāƑŹőĩęƠā9ƩơĩűđĩƑĺ$ǍǎÅĄMƌĄÅDMƏAČŌƌŌÎĄMǎńÌNŎÌŅƁÌŌÎčMǍƄƄ	MƌƍǎŌNčMǍƄLǎŎĄčń	ōNÎÍMǍƄ
# ǍŌÎǎŎČōƌŎǐĢ
#
# Project GutenbergĐāŉƘāƙǉűŹűǉũŹƩƘāƹŉơŀāơŁĨāıƑĩĨāġŉƙơƑŉđƩơŉŹŰāŹİQĩšĩęơƑŹűŉĘāƹŹƑřƘāŉŰāıŹƑũĉơƘāƑĩĉġĉđšĨāđǈāơŁĨāƹŉġĩƙƠāƱĉƑŉĩơǈāŹİQęŹũƁƩơĩƑƘāŉűęšƩġŉűĸāŹđƙŹšĩơĨŠāŹšĠŠāũŉġġšĨũĉĹĩĠāĉűĠāűĩƸāęŹũƁƩơĩƑƘŰāIƠQĩǁŉƙơƘāđĩęĉƩƙĨāŹİāơŁĨāĩııŹƑơƘāŹİāŁƩűġƑĩġƘāŹİāƱŹšƩűơĩĩƑƘāĉűĠāġŹűĉơŉŹűƘQıƑŹŨāƁĩŹƁšĨāŉŰāĉšŠāƹĉšřƘāŹİāšŉıĨŰPQ±ŹšƩűơĩĩƑƘāĉűĠāıŉűĉűęŉĉŠāƙƩƁƁŹƑƠāơŸāƁƑŹƱŉġĨāƱŹšƩűơĩĩƑƘāƹŉơŀāơŁĨQĉƙƙŉƙơĉűęĨāơŁĩǈāűĩĩĠāĉƑĨāęƑŉơŉęĉŠāơŸāƑĩĉęŁŉűĸāƑŹőĩęƠā9ƩơĩűđĩƑĺ$s
# goals and ensuring that the Project GutenbergĐāęŹššĩęơŉŹŰāƹŉšŠQƑĩũĉŉŰāıƑĩĩšǈāĉƱĉŉšĉđšĨāıŹƐāĹĩűĩƑĉơŉŹűƘāơŸāęŹũĨŰāIŰĀƐƀƀƈŠāơŁĨāƑŹőĩęƠQ9ƩơĩűđĩƑĸāaŉơĩƑĉƑǈā	ƑęŁŉƱĨā1ŹƩűġĉơŉŹŰāƹĉƘāęƑĩĉơĩĠāơŸāƁƑŹƱŉġĨāĈāƙĩęƩƑĨQĉűĠāƁĩƑũĉűĩűƠāıƩơƩƑĨāıŹƐāƑŹőĩęƠā9ƩơĩűđĩƑĺ$MƌĄƎŎĎŎŁǌōƌŎNčMǍƎÅƄ
# ōǎńLǎŎĄčń
# MƌƍǎŌNčMǍƄLǌńNĄǎǎǅƌǎŎČōƌŎǅƍǎǅƁÌŌÎčMǍƄÅƄ	MƌƍǎŌNčMǍƄLǎŎĄčń
# NƌƍǎōƌČNčMǍƁčńŎNNÍ
# DMƌĄǎMƎČŌĄČOŏōŎĄÎČNĎŎÄDčń	MƎČŎƌMāŎƌōƎŌń
# ÌŎƍLÌŅƄ
# čƍǎōƌČNčMǍƐs EIN or federal tax identification
# number is 64-6221541. Contributions to the Project Gutenberg Literary
# Archive Foundation are tax deductible to the full extent permitted by
# čǌÌNČŌĄNĄD	ƍǎčFņr stateÉƘāšĉƹƘŰPQ¡ŁĨā1ŹƩűġĉơŉŹŲNÄŎÍMƌŎÎÄ
# ǌŎÎąāÌMĎĄ	ČMÌÍNďEĄ
# MƌƍǎŌNčMǍƄÌMƄńƍǎōƌĄNĄčƍǎōƌČNčMǍƐs website
# and official page at www.gutenberg.org/contact
#
# Section 4. Information about Donations to the Project Gutenberg
# Literary Archive Foundation
#
# Project GutenbergĐāġĩƁĩűġƘāƩƁŹŰāĉűĠāęĉűűŹƠāƙƩƑƱŉƱĨāƹŉơŁŹƩƠāƹŉġĩƙƁƑĩĉĠQƁƩđšŉĘāƙƩƁƁŹƑƠāĉűĠāġŹűĉơŉŹűƘāơŸāęĉƑƑǈāŹƩƠāŉơƘāũŉƙƙŉŹŰāŹİQŉűęƑĩĉƙŉűĸāơŁĨāűƩũđĩƐāŹİāƁƩđšŉĘāġŹũĉŉŰāĉűĠāšŉęĩűƙĩĠāƹŹƑřƘāơŁĉƠāęĉŰāđĨQıƑĩĩšǈāġŉƙơƑŉđƩơĩĠāŉŰāũĉęŁŉűĨũƑĩĉġĉđšĨāıŹƑŨāĉęęĩƙƙŉđšĨāđǈāơŁĨāƹŉġĩƙƠQĉƑƑĉǈāŹİāĩƉƩŉƁũĩűƠāŉűęšƩġŉűĸāŹƩơġĉơĩĠāĩƉƩŉƁũĩűƠŰāiĉűǈāƙũĉšŠāġŹűĉơŉŹűƘPŀĠƈāơŸĀĠƨŠƀƀƀňāĉƑĨāƁĉƑơŉęƩšĉƑšǈāŉũƁŹƑơĉűƠāơŸāũĉŉűơĉŉűŉűĸāơĉǀāĩǁĩũƁƠQƙơĉơƩƘāƹŉơŀāơŁĨāIŰPQ¡ŁĨā1ŹƩűġĉơŉŹŰāŉƘāęŹũũŉơơĩĠāơŸāęŹũƁšǉŉűĸāƹŉơŀāơŁĨāšĉƹƘāƑĩĹƩšĉơŉűĸQęŁĉƑŉơŉĩƘāĉűĠāęŁĉƑŉơĉđšĨāġŹűĉơŉŹűƘāŉŰāĉšŠĀƨƀāƙơĉơĩƘāŹİāơŁĨā©űŉơĩĠQơĉơĩƘŰāŹũƁšŉĉűęĨāƑĩƉƩŉƑĩũĩűơƘāĉƑĨāűŹƠāƩűŉıŹƑŨāĉűĠāŉƠāơĉřĩƘāĈQęŹűƙŉġĩƑĉđšĨāĩııŹƑƠŠāũƩęŀāƁĉƁĩƑƹŹƑŘāĉűĠāũĉűǈāıĩĩƘāơŸāũĩĩƠāĉűĠāřĩĩƀāƩƀQƹŉơŀāơŁĩƙĨāƑĩƉƩŉƑĩũĩűơƘŰā¹ĨāġŸāűŹƠāƙŹšŉęŉƠāġŹűĉơŉŹűƘāŉŰāšŹęĉơŉŹűƘQƹŁĩƑĨāƹĨāŁĉƱĨāűŹƠāƑĩęĩŉƱĩĠāƹƑŉơơĩŰāęŹűıŉƑũĉơŉŹŰāŹİāęŹũƁšŉĉűęĨŰā¡Ÿā)q Q!yq	¡IyqāŹƐāġĩơĩƑũŉűĨāơŁĨāƙơĉơƩƘāŹİāęŹũƁšŉĉűęĨāıŹƐāĉűǈāƁĉƑơŉęƩšĉƐāƙơĉơĨQƱŉƙŉƠāƹƹƸűĹƩơĩűđĩƑĸűŹƑĸŹġŹűĉơĨŰPQ¹ŁŉšĨāƹĨāęĉűűŹƠāĉűĠāġŸāűŹƠāƙŹšŉęŉƠāęŹűơƑŉđƩơŉŹűƘāıƑŹŨāƙơĉơĩƘāƹŁĩƑĨāƹĨQŁĉƱĨāűŹƠāũĩƠāơŁĨāƙŹšŉęŉơĉơŉŹŰāƑĩƉƩŉƑĩũĩűơƘŠāƹĨāřűŹƸāŹİāűŸāƁƑŹŁŉđŉơŉŹŰQĉĹĉŉűƙƠāĉęęĩƁơŉűĸāƩűƙŹšŉęŉơĩĠāġŹűĉơŉŹűƘāıƑŹŨāġŹűŹƑƘāŉŰāƙƩęŀāƙơĉơĩƘāƹŁŸQĉƁƁƑŹĉęŀāƩƘāƹŉơŀāŹııĩƑƘāơŸāġŹűĉơĨŰPQIűơĩƑűĉơŉŹűĉŠāġŹűĉơŉŹűƘāĉƑĨāĹƑĉơĩıƩššǈāĉęęĩƁơĩĠŠāđƩƠāƹĨāęĉűűŹƠāũĉřĨQĉűǈāƙơĉơĩũĩűơƘāęŹűęĩƑűŉűĸāơĉǀāơƑĩĉơũĩűƠāŹİāġŹűĉơŉŹűƘāƑĩęĩŉƱĩĠāıƑŹŨQŹƩơƙŉġĨāơŁĨā©űŉơĩĠāơĉơĩƘŰā¨űŰāšĉƹƘāĉšŹűĨāƙƹĉũƀāŹƩƐāƙũĉšŠāƙơĉıİŰPQšĩĉƙĨāęŁĩęŘāơŁĨāƑŹőĩęƠā9ƩơĩűđĩƑĸāƹĩĐāƁĉĹĩƘāıŹƐāęƩƑƑĩűƠāġŹűĉơŉŹŰQũĩơŁŹġƘāĉűĠāĉġġƑĩƙƙĩƘŰā!ŹűĉơŉŹűƘāĉƑĨāĉęęĩƁơĩĠāŉŰāĈāűƩũđĩƐāŹİāŹơŁĩƐQƹĉǉƘāŉűęšƩġŉűĸāęŁĩęřƘŠāŹűšŉűĨāƁĉǉũĩűơƘāĉűĠāęƑĩġŉƠāęĉƑĠāġŹűĉơŉŹűƘŰā¡ŸQġŹűĉơĨŠāƁšĩĉƙĨāƱŉƙŉƠǐāƹƹƸűĹƩơĩűđĩƑĸűŹƑĸŹġŹűĉơĨŰPQĩęơŉŹŰĀƨŰā9ĩűĩƑĉŠāIűıŹƑũĉơŉŹŰā	đŹƩƠāƑŹőĩęƠā9ƩơĩűđĩƑĺ$ōČŌÎĎǍƍLÄǍǎÎÁǌƌŎÎÍǎ	ōLÍLōĄ
# ǌƄčńNčǎÄčń
# ǍŌÎāǎŎČōƌŎǐĢ concept of a library of electronic works that could be
# freely shared with anyone. For forty years, he produced and
# MƁčńǎČŌÎČŌĄDÍǎNLǍĄMƎČŌāŌčNčMǍƎÅĄMčĄāĈāšŹŹƙĨāűĩơƹŹƑŘāŹİQƱŹšƩűơĩĩƐāƙƩƁƁŹƑƠŰPQƑŹőĩęƠā9ƩơĩűđĩƑĺ$ňǍǍÎÄNń
# MƌÍĎŌČŌąƄÎÄDÍǎNLǍĄ
# ŌMMƄčńÍNČńǍƏDNčLÎōČNNŎŌčNčMǍƅƁōǎÎĄōǎ
# MƌƍǎŌNčMǍƄLǎŎĄǎǎǅƌǎŎČōƌŎǅƍǎǅƁč
# ǍŌÎǎŎČōƌŎǐĢ,
# including how to make donations to the Project Gutenberg Literary
# Archive Foundation, how to help produce our new eBooks, and how to
# subscribe to our email newsletter to hear about new eBooks.

# %% [markdown]
# ## 6. References
#
# 1. Stephane Beauregard, _Circuit for Shor's algorithm using 2n+3 qubits,_ [arXiv:quant-ph/0205095](https://arxiv.org/abs/quant-ph/0205095)
#
# 2. M. Nielsen and I. Chuang, _Quantum Computation and Quantum Information,_ Cambridge Series on Information and the Natural Sciences (Cambridge University Press, Cambridge, 2000). (Page 633)
